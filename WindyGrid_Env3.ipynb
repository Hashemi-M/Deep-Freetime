# %%
# https://stable-baselines3.readthedocs.io/en/master/guide/rl.html
# https://spinningup.openai.com/en/latest/spinningup/rl_intro2.html#a-taxonomy-of-rl-algorithms

# %% [markdown]
# # 1. Import dependencies

# %%
import torch as torch
torch._C._cuda_getDeviceCount() > 0
# Out:
# True

# %%
import os
import gym 
from stable_baselines3 import DQN
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy

# %% [markdown]
# # 2. Load and Test Environment

# %%
#environment_name = "Pong-v0"
#rewards = [[1,0,5], [1,10,4], [1,4,6]]
#rewards = [[1,0,8], [1,10,3]]
#rewards = [[1,7,5],[1,0,4]]
rewards = [[2,0,10],[1,0,0]]

# %%
#env = gym.make(environment_name)
from GridEnv import WindyGridworld
env = WindyGridworld(
        height=20,
        width=11,
        rewards=rewards,
        wind=True,
        allowed_actions=['L', 'R', 'C'],
        reward_terminates_episode=False
    )

# %%
episodes = 5
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0 
    
    while not done:
        env.render()
        action = env.action_space.sample()
        n_state, reward, done, info = env.step(action)
        score+=reward
    print('Episode:{} Score:{}'.format(episode, score))
env.close()
# Out:
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
#
# QObject::moveToThread: Current thread (0x55e8747203b0) is not the object's thread (0x55e8743e1830).
# Cannot move to target thread (0x55e8747203b0)
# Episode:1 Score:0
# Episode:2 Score:0
# Episode:3 Score:0
# Episode:4 Score:0
# Episode:5 Score:0

# %% [markdown]
# # 3. Train an RL Model

# %%
from stable_baselines3.common.evaluation import evaluate_policy

# %%
log_path = os.path.join('Training','Logs')

# %%
from stable_baselines3.common.callbacks import EvalCallback, StopTrainingOnRewardThreshold

# %%
save_path = os.path.join('Training', 'Saved Models')
log_path = os.path.join('Training', 'Logs')

# %%
from GridEnv import WindyGridworld
env = env = WindyGridworld(
        height=20,
        width=11,
        rewards=rewards,
        wind=True,
        allowed_actions=['L', 'R', 'C'],
        reward_terminates_episode=False
    )

print(env.rewards)

from stable_baselines3.common.atari_wrappers import WarpFrame

#env = WarpFrame(env)
# Out:
# [[2, 0, 10], [1, 0, 0]]

# %%
stop_callback = StopTrainingOnRewardThreshold(reward_threshold=1, verbose=1)
eval_callback = EvalCallback(env, 
                             callback_on_new_best=stop_callback, 
                             eval_freq=10000, 
                             best_model_save_path=save_path, 
                             verbose=1)

# %%
# try 0.2 exploration period
model = DQN('CnnPolicy', env, exploration_fraction=0.1,
  exploration_final_eps=0.4,learning_starts=100000, verbose = 1, buffer_size = 50000,target_update_interval=1000, tensorboard_log=log_path)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.

# %%
model.learn(total_timesteps=8000000,callback=eval_callback, tb_log_name='Env3_Exp0.4_8M')
# Out:
# Logging to Training/Logs/Env3_Exp0.4_8M_3
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.2     |
# |    ep_rew_mean      | 0.25     |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 3017     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 65       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.6     |
# |    ep_rew_mean      | 0.125    |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 3178     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 133      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.1     |
# |    ep_rew_mean      | 0.167    |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 3186     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 181      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.8     |
# |    ep_rew_mean      | 0.125    |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 3234     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 252      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.8     |
# |    ep_rew_mean      | 0.1      |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 3236     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 297      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.5     |
# |    ep_rew_mean      | 0.0833   |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 3238     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 347      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.9     |
# |    ep_rew_mean      | 0.0714   |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 3260     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 418      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.7     |
# |    ep_rew_mean      | 0.0625   |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 3265     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 471      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.9     |
# |    ep_rew_mean      | 0.0556   |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 3278     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 537      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.9     |
# |    ep_rew_mean      | 0.1      |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 3289     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 598      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.8     |
# |    ep_rew_mean      | 0.114    |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 3292     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 650      |
# ----------------------------------
# /usr/local/lib/python3.9/site-packages/stable_baselines3/common/callbacks.py:345: UserWarning: Training and eval env are not of the same type<stable_baselines3.common.vec_env.vec_transpose.VecTransposeImage object at 0x7ff280195a60> != <stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7ff336902700>
#   warnings.warn("Training and eval env are not of the same type" f"{self.training_env} != {self.eval_env}")
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.4     |
# |    ep_rew_mean      | 0.104    |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 3287     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 689      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.8     |
# |    ep_rew_mean      | 0.135    |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 3305     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 769      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.6     |
# |    ep_rew_mean      | 0.125    |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 3304     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 815      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14       |
# |    ep_rew_mean      | 0.117    |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 3297     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 842      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14       |
# |    ep_rew_mean      | 0.109    |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 3302     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 893      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.3     |
# |    ep_rew_mean      | 0.103    |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 3316     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 972      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.5     |
# |    ep_rew_mean      | 0.0972   |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 3317     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1046     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.7     |
# |    ep_rew_mean      | 0.105    |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 3323     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1117     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.3     |
# |    ep_rew_mean      | 0.1      |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 3314     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1145     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14       |
# |    ep_rew_mean      | 0.0952   |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 3310     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1178     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.9     |
# |    ep_rew_mean      | 0.0909   |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 3310     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1223     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.8     |
# |    ep_rew_mean      | 0.109    |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 3311     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1273     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.6     |
# |    ep_rew_mean      | 0.104    |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              |
|
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000565 |
# |    n_updates        | 24670    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.2     |
# |    ep_rew_mean      | 0.05     |
# |    exploration_rate | 0.851    |
# | time/               |          |
# |    episodes         | 13464    |
# |    fps              | 1368     |
# |    time_elapsed     | 145      |
# |    total_timesteps  | 198763   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.19e-06 |
# |    n_updates        | 24690    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.1     |
# |    ep_rew_mean      | 0.07     |
# |    exploration_rate | 0.851    |
# | time/               |          |
# |    episodes         | 13468    |
# |    fps              | 1367     |
# |    time_elapsed     | 145      |
# |    total_timesteps  | 198806   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000467 |
# |    n_updates        | 24701    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.4     |
# |    ep_rew_mean      | 0.08     |
# |    exploration_rate | 0.851    |
# | time/               |          |
# |    episodes         | 13472    |
# |    fps              | 1367     |
# |    time_elapsed     | 145      |
# |    total_timesteps  | 198886   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000113 |
# |    n_updates        | 24721    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.8     |
# |    ep_rew_mean      | 0.08     |
# |    exploration_rate | 0.851    |
# | time/               |          |
# |    episodes         | 13476    |
# |    fps              | 1367     |
# |    time_elapsed     | 145      |
# |    total_timesteps  | 198966   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000115 |
# |    n_updates        | 24741    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.8     |
# |    ep_rew_mean      | 0.08     |
# |    exploration_rate | 0.851    |
# | time/               |          |
# |    episodes         | 13480    |
# |    fps              | 1366     |
# |    time_elapsed     | 145      |
# |    total_timesteps  | 199012   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000121 |
# |    n_updates        | 24752    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.8     |
# |    ep_rew_mean      | 0.08     |
# |    exploration_rate | 0.851    |
# | time/               |          |
# |    episodes         | 13484    |
# |    fps              | 1366     |
# |    time_elapsed     | 145      |
# |    total_timesteps  | 199084   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000576 |
# |    n_updates        | 24770    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.4     |
# |    ep_rew_mean      | 0.08     |
# |    exploration_rate | 0.851    |
# | time/               |          |
# |    episodes         | 13488    |
# |    fps              | 1366     |
# |    time_elapsed     | 145      |
# |    total_timesteps  | 199161   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000325 |
# |    n_updates        | 24790    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.3     |
# |    ep_rew_mean      | 0.08     |
# |    exploration_rate | 0.851    |
# | time/               |          |
# |    episodes         | 13492    |
# |    fps              | 1366     |
# |    time_elapsed     | 145      |
# |    total_timesteps  | 199225   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000117 |
# |    n_updates        | 24806    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.3     |
# |    ep_rew_mean      | 0.06     |
# |    exploration_rate | 0.851    |
# | time/               |          |
# |    episodes         | 13496    |
# |    fps              | 1365     |
# |    time_elapsed     | 145      |
# |    total_timesteps  | 199293   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000227 |
# |    n_updates        | 24823    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.3     |
# |    ep_rew_mean      | 0.06     |
# |    exploration_rate | 0.85     |
# | time/               |          |
# |    episodes         | 13500    |
# |    fps              | 1365     |
# |    time_elapsed     | 145      |
# |    total_timesteps  | 199355   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000119 |
# |    n_updates        | 24838    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.1     |
# |    ep_rew_mean      | 0.06     |
# |    exploration_rate | 0.85     |
# | time/               |          |
# |    episodes         | 13504    |
# |    fps              | 1365     |
# |    time_elapsed     | 146      |
# |    total_timesteps  | 199401   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000244 |
# |    n_updates        | 24850    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.9     |
# |    ep_rew_mean      | 0.06     |
# |    exploration_rate | 0.85     |
# | time/               |          |
# |    episodes         | 13508    |
# |    fps              | 1365     |
# |    time_elapsed     | 146      |
# |    total_timesteps  | 199429   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000119 |
# |    n_updates        | 24857    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.1     |
# |    ep_rew_mean      | 0.07     |
# |    exploration_rate | 0.85     |
# | time/               |          |
# |    episodes         | 13512    |
# |    fps              | 1364     |
# |    time_elapsed     | 146      |
# |    total_timesteps  | 199502   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000338 |
# |    n_updates        | 24875    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.4     |
# |    ep_rew_mean      | 0.07     |
# |    exploration_rate | 0.85     |
# | time/               |          |
# |    episodes         | 13516    |
# |    fps              | 1364     |
# |    time_elapsed     | 146      |
# |    total_timesteps  | 199582   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000118 |
# |    n_updates        | 24895    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.2     |
# |    ep_rew_mean      | 0.07     |
# |    exploration_rate | 0.85     |
# | time/               |          |
# |    episodes         | 13520    |
# |    fps              | 1364     |
# |    time_elapsed     | 146      |
# |    total_timesteps  | 199651   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000135 |
# |    n_updates        | 24912    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.5     |
# |    ep_rew_mean      | 0.07     |
# |    exploration_rate | 0.85     |
# | time/               |          |
# |    episodes         | 13524    |
# |    fps              | 1364     |
# |    time_elapsed     | 146      |
# |    total_timesteps  | 199704   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000238 |
# |    n_updates        | 24925    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.5     |
# |    ep_rew_mean      | 0.07     |
# |    exploration_rate | 0.85     |
# | time/               |          |
# |    episodes         | 13528    |
# |    fps              | 1363     |
# |    time_elapsed     | 146      |
# |    total_timesteps  | 199783   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000132 |
# |    n_updates        | 24945    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.7     |
# |    ep_rew_mean      | 0.07     |
# |    exploration_rate | 0.85     |
# | time/               |          |
# |    episodes         | 13532    |
# |    fps              | 1363     |
# |    time_elapsed     | 146      |
# |    total_timesteps  | 199847   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000221 |
# |    n_updates        | 24961    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.6     |
# |    ep_rew_mean      | 0.07     |
# |    exploration_rate | 0.85     |
# | time/               |          |
# |    episodes         | 13536    |
# |    fps              | 1363     |
# |    time_elapsed     | 146      |
# |    total_timesteps  | 199872   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00034  |
# |    n_updates        | 24967    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.5     |
# |    ep_rew_mean      | 0.08     |
# |    exploration_rate | 0.85     |
# | time/               |          |
# |    episodes         | 13540    |
# |    fps              | 1363     |
# |    time_elapsed     | 146      |
# |    total_timesteps  | 199934   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0159   |
# |    n_updates        | 24983    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.3     |
# |    ep_rew_mean      | 0.08     |
# |    exploration_rate | 0.85     |
# | time/               |          |
# |    episodes         | 13544    |
# |    fps              | 1363     |
# |    time_elapsed     | 146      |
# |    total_timesteps  | 199976   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000247 |
# |    n_updates        | 24993    |
# ----------------------------------
# Eval num_timesteps=200000, episode_reward=1.00 +/- 0.89
# Episode length: 20.00 +/- 0.00
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 20       |
# |    mean_reward      | 1        |
# | rollout/            |          |
# |    exploration_rate | 0.85     |
# | time/               |          |
# |    total_timesteps  | 200000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00023  |
# |    n_updates        | 24999    |
# ----------------------------------
# New best mean reward!
# Stopping training because the mean reward 1.00  is above the threshold 1

# %%
save_path = os.path.join('Training', 'Saved Models', 'Env3_Exp0.4_8M')
#load_path = os.path.join('Training', 'Saved Models', 'DQN_model_GridWorld')
model.save(save_path)

# %%
evaluate_policy(model, env, n_eval_episodes=30, render=True)

# %%
env.close()
