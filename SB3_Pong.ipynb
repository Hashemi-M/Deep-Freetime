# %%
# https://stable-baselines3.readthedocs.io/en/master/guide/rl.html
# https://spinningup.openai.com/en/latest/spinningup/rl_intro2.html#a-taxonomy-of-rl-algorithms

# %% [markdown]
# # 1. Import dependencies

# %%
import os
import gym 
from stable_baselines3 import DQN
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy

# %% [markdown]
# # 2. Load and Test Environment

# %%
environment_name = "Pong-v4"

# %%
env = gym.make(environment_name)

# %%
episodes = 5
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0 
    
    while not done:
        env.render()
        action = env.action_space.sample()
        n_state, reward, done, info = env.step(action)
        score+=reward
    print('Episode:{} Score:{}'.format(episode, score))
env.close()
# Out:
# /usr/local/lib/python3.9/site-packages/gym/envs/atari/environment.py:267: UserWarning: WARN: We strongly suggest supplying `render_mode` when constructing your environment, e.g., gym.make(ID, render_mode='human'). Using `render_mode` provides access to proper scaling, audio support, and proper framerates.
#   logger.warn(
# Episode:1 Score:-21.0
# Episode:2 Score:-21.0
# Episode:3 Score:-20.0
# Episode:4 Score:-21.0
# Episode:5 Score:-20.0

# %% [markdown]
# # 3. Train an RL Model

# %%
log_path = os.path.join('Training','Logs')
training_log_path = os.path.join(log_path, 'DQN_Pong')

# %%
from stable_baselines3.common.callbacks import EvalCallback, StopTrainingOnRewardThreshold
import os
from stable_baselines3.common.atari_wrappers import AtariWrapper

# %%
save_path = os.path.join('Training', 'Saved Models')
log_path = os.path.join('Training', 'Logs')

# %%
env = gym.make(environment_name)
env = AtariWrapper(env)

# %%
stop_callback = StopTrainingOnRewardThreshold(reward_threshold=20, verbose=1)
eval_callback = EvalCallback(env, 
                             callback_on_new_best=stop_callback, 
                             eval_freq=10000, 
                             best_model_save_path=save_path, 
                             verbose=1)

# %%
model_pong = DQN('CnnPolicy', env, verbose = 1,
            buffer_size = 100000,
            learning_rate = 0.0001, 
            batch_size = 32,
            learning_starts = 100000,
            target_update_interval = 1000,
            train_freq = 4,
            gradient_steps =  1,
            exploration_fraction = 0.1,
            exploration_final_eps = 0.01,
            optimize_memory_usage = False,
            tensorboard_log=log_path)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.

# %%
model_pong.learn(total_timesteps=10000000, callback=eval_callback)
# Out:
# 2022-08-18 23:37:10.159773: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# Logging to Training/Logs/DQN_24
# /usr/local/lib/python3.9/site-packages/stable_baselines3/common/callbacks.py:345: UserWarning: Training and eval env are not of the same type<stable_baselines3.common.vec_env.vec_transpose.VecTransposeImage object at 0x7f807eef4df0> != <stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f807eedbf40>
#   warnings.warn("Training and eval env are not of the same type" f"{self.training_env} != {self.eval_env}")
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 305      |
# |    ep_rew_mean      | -20.5    |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 506      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 1221     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 300      |
# |    ep_rew_mean      | -20.2    |
# |    exploration_rate | 0.998    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 665      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 2398     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 292      |
# |    ep_rew_mean      | -20.5    |
# |    exploration_rate | 0.997    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 740      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 3508     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 289      |
# |    ep_rew_mean      | -20.6    |
# |    exploration_rate | 0.995    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 787      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 4629     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 289      |
# |    ep_rew_mean      | -20.6    |
# |    exploration_rate | 0.994    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 817      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 5779     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 288      |
# |    ep_rew_mean      | -20.6    |
# |    exploration_rate | 0.993    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 841      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 6924     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 287      |
# |    ep_rew_mean      | -20.7    |
# |    exploration_rate | 0.992    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 860      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 8041     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 290      |
# |    ep_rew_mean      | -20.6    |
# |    exploration_rate | 0.991    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 876      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 9269     |
# ----------------------------------
# /usr/local/lib/python3.9/site-packages/stable_baselines3/common/evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Eval num_timesteps=10000, episode_reward=-13.00 +/- 16.00
# Episode length: 298.20 +/- 99.97
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 298      |
# |    mean_reward      | -13      |
# | rollout/            |          |
# |    exploration_rate | 0.99     |
# | time/               |          |
# |    total_timesteps  | 10000    |
# ----------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 296      |
# |    ep_rew_mean      | -20.8    |
# |    exploration_rate | 0.989    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 676      |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 10669    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 299      |
# |    ep_rew_mean      | -20.6    |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 699      |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 11962    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 296      |
# |    ep_rew_mean      | -20.7    |
# |    exploration_rate | 0.987    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 715      |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 13023    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 297      |
# |    ep_rew_mean      | -20.7    |
# |    exploration_rate | 0.986    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 732      |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 14242    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 297      |
# |    ep_rew_mean      | -20.7    |
# |    exploration_rate | 0.985    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 747      |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 15453    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 298      |
# |    ep_rew_mean      | -20.6    |
# |    exploration_rate | 0.983    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 761      |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 16675    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 297      |
# |    ep_rew_mean      | -20.6    |
# |    exploration_rate | 0.982    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 772      |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 17836    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 296      |
# |    ep_rew_mean      | -20.6    |
# |    exploration_rate | 0.981    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 781      |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 18961    |
# ----------------------------------
# Eval num_timesteps=20000, episode_reward=-19.60 +/- 2.80
# Episode length: 232.40 +/- 37.21
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 232      |
# |    mean_reward      | -19.6    |
# | rollout/            |          |
# |    exploration_rate | 0.98     |
# | time/               |          |
# |    total_timesteps  | 20000    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 299      |
# |    ep_rew_mean      | -20.7    |
# |    exploration_rate | 0.98     |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 739      |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 20330    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 299      |
# |    ep_rew_mean      | -20.7    |
# |    exploration_rate | 0.979    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 749      |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 21552    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 299      |
# |    ep_rew_mean      | -20.7    |
# |    exploration_rate | 0.978    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 758      |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 22716    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 301      |
# |    ep_rew_mean      | -20.6    |
# |    exploration_rate | 0.976    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 768      |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 24099    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 300      |
# |    ep_rew_mean      | -20.6    |
# |    exploration_rate | 0.975    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 776      |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 25199    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 299      |
# |    ep_rew_mean      | -20.6    |
# |    exploration_rate | 0.974    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 782      |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 26333    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 299      |
# |    ep_rew_mean      | -20.7    |
# |    exploration_rate | 0.973    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 788      |
# |    time_elapsed     | 34       |
# |    total_timesteps  | 27471    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 299      |
# |    ep_rew_mean      | -20.7    |
# |    exploration_rate | 0.972    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 795      |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 28675    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 299      |
# |    ep_rew_mean      | -20.6    |
# |    exploration_rate | 0.97     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 801      |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 29928    |
# ----------------------------------
# Eval num_timesteps=30000, episode_reward=-20.60 +/- 0.80
# Episode length: 242.60 +/- 15.40
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 243      |
# |    mean_reward      | -20.6    |
# | rollout/            |          |
# |    exploration_rate | 0.97     |
# | time/               |          |
# |    total_timesteps  | 30000    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 299      |
# |    ep_rew_mean      | -20.6    |
# |    exploration_rate | 0.969    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 770      |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 31136    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 299      |
# |    ep_rew_mean      | -20.7    |
# |    exploration_rate | 0.968    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 775      |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 32306    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 300      |
# |    ep_rew_mean      | -20.6    |
# |    exploration_rate | 0.967    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 780      |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 33507    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 301      |
# |    ep_rew_mean      | -20.6    |
# |    exploration_rate | 0.966    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 785      |
# |    time_elapsed     | 44       |
# |    total_timesteps  | 34689    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 301      |
# |    ep_rew_mean      | -20.6    |
# |    exploration_rate | 0.965    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 790      |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 35844    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 302      |
# |    ep_rew_mean      | -20.6    |
# |    exploration_rate | 0.963    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 795      |
# |    time_elapsed     | 46       |
# |    total_timesteps  | 37124    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 303      |
# |    ep_rew_mean      | -20.6    |
# |    exploration_rate | 0.962    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 798      |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 38336    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 303      |
# |    ep_rew_mean      | -20.6    |
# |    exploration_rate | 0.961    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 803      |
# |    time_elapsed     | 49       |
# |    total_timesteps  | 39616    |
# ----------------------------------
# Eval num_timesteps=40000, episode_reward=-19.40 +/- 3.20
# Episode length: 227.60 +/- 42.86
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 228      |
# |    mean_reward      | -19.4    |
# | rollout/            |          |
# |    exploration_rate | 0.96     |
# | time/               |          |
# |    total_timesteps  | 40000    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 301      |
# |    ep_rew_mean      | -20.6    |
# |    exploration_rate | 0.96     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 780      |
# |    time_elapsed     | 52       |
# |    total_timesteps  | 40808    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 299      |
# |    ep_rew_mean      | -20.6    |
# |    exploration_rate | 0.959    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 784      |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 41906    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 302      |
# |    ep_rew_mean      | -20.6    |
# |    exploration_rate | 0.957    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 788      |
# |    time_elapsed     | 54       |
# |    total_timesteps  | 43223    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 301      |
# |    ep_rew_mean      | -20.6    |
# |    exploration_rate | 0.956    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 792      |
# |    time_elapsed     | 55       |
# |    total_timesteps  | 44353    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 302      |
# |    ep_rew_mean      | -20.6    |
# |    exploration_rate | 0.955    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 796      |
# |    time_elapsed     | 57       |
# |    total_timesteps  | 45646    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 301      |
# |    ep_rew_mean      | -20.6    |
# |    exploration_rate | 0.954    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 799      |
# |    time_elapsed     | 58       |
# |    total_timesteps  | 46821    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 303      |
# |    ep_rew_mean      | -20.6    |
# |    exploration_rate | 0.952    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 803      |
# |    time_elapsed     | 59       |
# |    total_timesteps  | 48102    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 303      |
# |    ep_rew_mean      | -20.6    |
# |    exploration_rate | 0.951    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 806      |
# |    time_elapsed     | 61       |
# |    total_timesteps  | 49295    |
# ----------------------------------
# Eval num_timesteps=50000, episode_reward=-18.60 +/- 4.80
# Episode length: 221.60 +/- 61.43
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 222      |
# |    mean_reward      | -18.6    |
# | rollout/            |          |
# |    exploration_rate | 0.951    |
# | time/               |          |
# |    total_timesteps  | 50000    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 303      |
# |    ep_rew_mean      | -20.6    |
# |    exploration_rate | 0.95     |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 788      |
# |    time_elapsed     | 64       |
# |    total_timesteps  | 50597    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 302      |
# |    ep_rew_mean      | -20.6    |
# |    exploration_rate | 0.949    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 791      |
# |    time_elapsed     | 65       |
# |    total_timesteps  | 51794    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 302      |
# |    ep_rew_mean      | -20.6    |
# |    exploration_rate | 0.948    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 794      |
# |    time_elapsed     | 66       |
# |    total_timesteps  | 52916    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 300      |
# |    ep_rew_mean      | -20.6    |
# |    exploration_rate | 0.946    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 797      |
# |    time_elapsed     | 67       |
# |    total_timesteps  | 54061    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 301      |
# |    ep_rew_mean      | -20.6    |
# |    exploration_rate | 0.945    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 800      |
# |    time_elapsed     | 69       |
# |    total_timesteps  | 55259    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 302      |
# |    ep_rew_mean      | -20.6    |
# |    exploration_rate | 0.944    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 802      |
# |    time_elapsed     | 70       |
# |    total_timesteps  | 56527    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 302      |
# |    ep_rew_mean      | -20.6    |
# |    exploration_rate | 0.943    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 805      |
# |    time_elapsed     | 71       |
# |    total_timesteps  | 57696    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 302      |
# |    ep_rew_mean      | -20.6    |
# |    exploration_rate | 0.942    |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 807      |
# |    time_elapsed     | 72       |
# |    total_timesteps  | 58861    |
# ----------------------------------
# Eval num_timesteps=60000, episode_reward=-18.20 +/- 5.60
# Episode length: 215.60 +/- 67.38
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 216      |
# |    mean_reward      | -18.2    |
# | rollout/            |          |
# |    exploration_rate | 0.941    |
# | time/               |          |
# |    total_timesteps  | 60000    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 304      |
# |    ep_rew_mean      | -20.8    |
# |    exploration_rate | 0.94     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 793      |
# |    time_elapsed     | 75       |
# |    total_timesteps  | 60296    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 304      |
# |    ep_rew_mean      | -20.8    |
# |    exploration_rate | 0.939    |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 796      |
# |    time_elapsed     | 77       |
# |    total_timesteps  | 61530    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 304      |
# |    ep_rew_mean      | -20.8    |
# |    exploration_rate | 0.938    |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 799      |
# |    time_elapsed     | 78       |
# |    total_timesteps  | 62703    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 303      |
# |    ep_rew_mean      | -20.8    |
# |    exploration_rate | 0.937    |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 801      |
# |    time_elapsed     | 79       |
# |    total_timesteps  | 63807    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 303      |
# |    ep_rew_mean      | -20.8    |
# |    exploration_rate | 0.936    |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 804      |
# |    time_elapsed     | 80       |
# |    total_timesteps  | 65030    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 304      |
# |    ep_rew_mean      | -20.8    |
# |    exploration_rate | 0.934    |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 806      |
# |    time_elapsed     | 82       |
# |    total_timesteps  | 66259    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 303      |
# |    ep_rew_mean      | -20.8    |
# |    exploration_rate | 0.933    |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 808      |
# |    time_elapsed     | 83       |
# |    total_timesteps  | 67462    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 303      |
# |    ep_rew_mean      | -20.8    |
# |    exploration_rate | 0.932    |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 811      |
# |    time_elapsed     | 84       |
# |    total_timesteps  | 68641    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 302      |
# |    ep_rew_mean      | -20.8    |
# |    exploration_rate | 0.931    |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 812      |
# |    time_elapsed     | 85       |
# |    total_timesteps  | 69779    |
# ----------------------------------
# Eval num_timesteps=70000, episode_reward=-17.40 +/- 7.20
# Episode length: 205.00 +/- 90.51
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 205      |
# |    mean_reward      | -17.4    |
# | rollout/            |          |
# |    exploration_rate | 0.931    |
# | time/               |          |
# |    total_timesteps  | 70000    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 303      |
# |    ep_rew_mean      | -20.9    |
# |    exploration_rate | 0.93     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 799      |
# |    time_elapsed     | 88       |
# |    total_timesteps  | 71110    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 304      |
# |    ep_rew_mean      | -20.9    |
# |    exploration_rate | 0.928    |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 800      |
# |    time_elapsed     | 90       |
# |    total_timesteps  | 72285    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 302      |
# |    ep_rew_mean      | -20.9    |
# |    exploration_rate | 0.927    |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 802      |
# |    time_elapsed     | 91       |
# |    total_timesteps  | 73403    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 302      |
# |    ep_rew_mean      | -20.9    |
# |    exploration_rate | 0.926    |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 804      |
# |    time_elapsed     | 92       |
# |    total_timesteps  | 74551    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 302      |
# |    ep_rew_mean      | -20.9    |
# |    exploration_rate | 0.925    |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 806      |
# |    time_elapsed     | 94       |
# |    total_timesteps  | 75822    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 301      |
# |    ep_rew_mean      | -20.9    |
# |    exploration_rate | 0.924    |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 808      |
# |    time_elapsed     | 95       |
# |    total_timesteps  | 76926    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 300      |
# |    ep_rew_mean      | -20.9    |
# |    exploration_rate | 0.923    |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 809      |
# |    time_elapsed     | 96       |
# |    total_timesteps  | 78098    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 299      |
# |    ep_rew_mean      | -21      |
# |    exploration_rate | 0.922    |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 810      |
# |    time_elapsed     | 97       |
# |    total_timesteps  | 79206    |
# ----------------------------------
# Eval num_timesteps=80000, episode_reward=-17.80 +/- 6.40
# Episode length: 213.80 +/- 78.93
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 214      |
# |    mean_reward      | -17.8    |
# | rollout/            |          |
# |    exploration_rate | 0.921    |
# | time/               |          |
# |    total_timesteps  | 80000    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 300      |
# |    ep_rew_mean      | -21      |
# |    exploration_rate | 0.92     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 799      |
# |    time_elapsed     | 100      |
# |    total_timesteps  | 80627    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 301      |
# |    ep_rew_mean      | -21      |
# |    exploration_rate | 0.919    |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 801      |
# |    time_elapsed     | 102      |
# |    total_timesteps  | 81894    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 303      |
# |    ep_rew_mean      | -21      |
# |    exploration_rate | 0.918    |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 804      |
# |    time_elapsed     | 103      |
# |    total_timesteps  | 83201    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 303      |
# |    ep_rew_mean      | -21      |
# |    exploration_rate | 0.916    |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 806      |
# |    time_elapsed     | 104      |
# |    total_timesteps  | 84363    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 302      |
# |    ep_rew_mean      | -21      |
# |    exploration_rate | 0.915    |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 808      |
# |    time_elapsed     | 105      |
# |    total_timesteps  | 85481    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 301      |
# |    ep_rew_mean      | -21      |
# |    exploration_rate | 0.914    |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 810      |
# |    time_elapsed     | 106      |
# |    total_timesteps  | 86650    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 301      |
# |    ep_rew_mean      | -21      |
# |    exploration_rate | 0.913    |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 812      |
# |    time_elapsed     | 108      |
# |    total_timesteps  | 87774    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 301      |
# |    ep_rew_mean      | -21      |
# |    exploration_rate | 0.912    |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 814      |
# |    time_elapsed     | 109      |
# |    total_timesteps  | 88942    |
# ----------------------------------
# Eval num_timesteps=90000, episode_reward=-18.00 +/- 6.00
# Episode length: 219.00 +/- 62.52
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 219      |
# |    mean_reward      | -18      |
# | rollout/            |          |
# |    exploration_rate | 0.911    |
# | time/               |          |
# |    total_timesteps  | 90000    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 300      |
# |    ep_rew_mean      | -21      |
# |    exploration_rate | 0.911    |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 804      |
# |    time_elapsed     | 112      |
# |    total_timesteps  | 90268    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 300      |
# |    ep_rew_mean      | -21.1    |
# |    exploration_rate | 0.909    |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 807      |
# |    time_elapsed     | 113      |
# |    total_timesteps  | 91513    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 300      |
# |    ep_rew_mean      | -21      |
# |    exploration_rate | 0.908    |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 809      |
# |    time_elapsed     | 114      |
# |    total_timesteps  | 92712    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 301      |
# |    ep_rew_mean      | -21      |
# |    exploration_rate | 0.907    |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 811      |
# |    time_elapsed     | 115      |
# |    total_timesteps  | 93878    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 301      |
# |    ep_rew_mean      | -21      |
# |    exploration_rate | 0.906    |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 812      |
# |    time_elapsed     | 116      |
# |    total_timesteps  | 95098    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 300      |
# |    ep_rew_mean      | -21      |
# |    exploration_rate | 0.905    |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 814      |
# |    time_elapsed     | 118      |
# |    total_timesteps  | 96300    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 300      |
# |    ep_rew_mean      | -21      |
# |    exploration_rate | 0.903    |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 816      |
# |    time_elapsed     | 119      |
# |    total_timesteps  | 97495    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 300      |
# |    ep_rew_mean      | -21      |
# |    exploration_rate | 0.902    |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 818      |
# |    time_elapsed     | 120      |
# |    total_timesteps  | 98683    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 301      |
# |    ep_rew_mean      | -21      |
# |    exploration_rate | 0.901    |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 820      |
# |    time_elapsed     | 121      |
# |    total_timesteps  | 99896    |
# ----------------------------------
# Eval num_timesteps=100000, episode_reward=-19.40 +/- 3.20
# Episode length: 233.00 +/- 40.12
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 233      |
# |    mean_reward      | -19.4    |
# | rollout/            |          |
# |    exploration_rate | 0.901    |
# | time/               |          |
# |    total_timesteps  | 100000   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 301      |
# |    ep_rew_mean      | -20.9    |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 803      |
# |    time_elapsed     | 125      |
# |    total_timesteps  | 101204   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0297   |
# |    n_updates        | 300      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 300      |
# |    ep_rew_mean      | -20.9    |
# |    exploration_rate | 0.899    |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 798      |
# |    time_elapsed     | 128      |
# |    total_timesteps  | 102313   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0453   |
# |    n_updates        | 578      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 301      |
# |    ep_rew_mean      | -20.9    |
# |    exploration_rate | 0.898    |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 794      |
# |    time_elapsed     | 130      |
# |    total_timesteps  | 103460   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0685   |
# |    n_updates        | 864      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 300      |
# |    ep_rew_mean      | -20.9    |
# |    exploration_rate | 0.896    |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 789      |
# |    time_elapsed     | 132      |
# |    total_timesteps  | 104594   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0292   |
# |    n_updates        | 1148     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 300      |
# |    ep_rew_mean      | -20.9    |
# |    exploration_rate | 0.895    |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 784      |
# |    time_elapsed     | 134      |
# |    total_timesteps  | 105826   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.029    |
# |    n_updates        | 1456     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 300      |
# |    ep_rew_mean      | -20.9    |
# |    exploration_rate | 0.894    |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 780      |
# |    time_elapsed     | 137      |
# |    total_timesteps  | 106950   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0129   |
# |    n_updates        | 1737     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 300      |
# |    ep_rew_mean      | -20.9    |
# |    exploration_rate | 0.893    |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 776      |
# |    time_elapsed     | 139      |
# |    total_timesteps  | 108147   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0396   |
# |    n_updates        | 2036     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 301      |
# |    ep_rew_mean      | -20.9    |
# |    exploration_rate | 0.892    |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 772      |
# |    time_elapsed     | 141      |
# |    total_timesteps  | 109320   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0309   |
# |    n_updates        | 2329     |
# ----------------------------------
# Eval num_timesteps=110000, episode_reward=-19.00 +/- 2.53
# Episode length: 267.80 +/- 27.41
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 268      |
# |    mean_reward      | -19      |
# | rollout/            |          |
# |    exploration_rate | 0.891    |
# | time/               |          |
# |    total_timesteps  | 110000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0285   |
# |    n_updates        | 2499     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 300      |
# |    ep_rew_mean      | -20.8    |
# |    exploration_rate | 0.89     |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 758      |
# |    time_elapsed     | 145      |
# |    total_timesteps  | 110637   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0174   |
# |    n_updates        | 2659     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 299      |
# |    ep_rew_mean      | -20.8    |
# |    exploration_rate | 0.889    |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 754      |
# |    time_elapsed     | 148      |
# |    total_timesteps  | 111771   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00579  |
# |    n_updates        | 2942     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 300      |
# |    ep_rew_mean      | -20.8    |
# |    exploration_rate | 0.888    |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 750      |
# |    time_elapsed     | 150      |
# |    total_timesteps  | 113173   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0277   |
# |    n_updates        | 3293     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 299      |
# |    ep_rew_mean      | -20.8    |
# |    exploration_rate | 0.887    |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 747      |
# |    time_elapsed     | 152      |
# |    total_timesteps  | 114252   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0237   |
# |    n_updates        | 3562     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 299      |
# |    ep_rew_mean      | -20.9    |
# |    exploration_rate | 0.886    |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 744      |
# |    time_elapsed     | 154      |
# |    total_timesteps  | 115401   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0227   |
# |    n_updates        | 3850     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 299      |
# |    ep_rew_mean      | -20.8    |
# |    exploration_rate | 0.885    |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 742      |
# |    time_elapsed     | 157      |
# |    total_timesteps  | 116579   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0167   |
# |    n_updates        | 4144     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 300      |
# |    ep_rew_mean      | -20.8    |
# |    exploration_rate | 0.883    |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 739      |
# |    time_elapsed     | 159      |
# |    total_timesteps  | 117761   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0052   |
# |    n_updates        | 4440     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 301      |
# |    ep_rew_mean      | -20.8    |
# |    exploration_rate | 0.882    |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 736      |
# |    time_elapsed     | 161      |
# |    total_timesteps  | 119003   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0036   |
# |    n_updates        | 4750     |
# ----------------------------------
# Eval num_timesteps=120000, episode_reward=-18.80 +/- 3.12
# Episode length: 279.60 +/- 32.40
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 280      |
# |    mean_reward      | -18.8    |
# | rollout/            |          |
# |    exploration_rate | 0.881    |
# | time/               |          |
# |    total_timesteps  | 120000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0183   |
# |    n_updates        | 4999     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 300      |
# |    ep_rew_mean      | -20.7    |
# |    exploration_rate | 0.881    |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 724      |
# |    time_elapsed     | 166      |
# |    total_timesteps  | 120269   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00312  |
# |    n_updates        | 5067     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 299      |
# |    ep_rew_mean      | -20.7    |
# |    exploration_rate | 0.88     |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 721      |
# |    time_elapsed     | 168      |
# |    total_timesteps  | 121396   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00818  |
# |    n_updates        | 5348     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 299      |
# |    ep_rew_mean      | -20.7    |
# |    exploration_rate | 0.879    |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 718      |
# |    time_elapsed     | 170      |
# ...
# | rollout/            |          |
# |    ep_len_mean      | 1.2e+03  |
# |    ep_rew_mean      | 7.19     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 9804     |
# |    fps              | 328      |
# |    time_elapsed     | 30187    |
# |    total_timesteps  | 9925970  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00714  |
# |    n_updates        | 2456492  |
# ----------------------------------
# Eval num_timesteps=9930000, episode_reward=7.80 +/- 3.19
# Episode length: 1018.00 +/- 228.43
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 1.02e+03 |
# |    mean_reward      | 7.8      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 9930000  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00704  |
# |    n_updates        | 2457499  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.2e+03  |
# |    ep_rew_mean      | 7.07     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 9808     |
# |    fps              | 328      |
# |    time_elapsed     | 30206    |
# |    total_timesteps  | 9931008  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.019    |
# |    n_updates        | 2457751  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.19e+03 |
# |    ep_rew_mean      | 7.22     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 9812     |
# |    fps              | 328      |
# |    time_elapsed     | 30217    |
# |    total_timesteps  | 9935540  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00933  |
# |    n_updates        | 2458884  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.18e+03 |
# |    ep_rew_mean      | 7.58     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 9816     |
# |    fps              | 328      |
# |    time_elapsed     | 30226    |
# |    total_timesteps  | 9939211  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00501  |
# |    n_updates        | 2459802  |
# ----------------------------------
# Eval num_timesteps=9940000, episode_reward=12.60 +/- 8.59
# Episode length: 891.60 +/- 261.60
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 892      |
# |    mean_reward      | 12.6     |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 9940000  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00383  |
# |    n_updates        | 2459999  |
# ----------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.18e+03 |
# |    ep_rew_mean      | 7.78     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 9820     |
# |    fps              | 328      |
# |    time_elapsed     | 30242    |
# |    total_timesteps  | 9943564  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00719  |
# |    n_updates        | 2460890  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.17e+03 |
# |    ep_rew_mean      | 7.77     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 9824     |
# |    fps              | 328      |
# |    time_elapsed     | 30252    |
# |    total_timesteps  | 9947777  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0118   |
# |    n_updates        | 2461944  |
# ----------------------------------
# Eval num_timesteps=9950000, episode_reward=11.40 +/- 5.12
# Episode length: 741.80 +/- 313.40
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 742      |
# |    mean_reward      | 11.4     |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 9950000  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0121   |
# |    n_updates        | 2462499  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.16e+03 |
# |    ep_rew_mean      | 8.07     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 9828     |
# |    fps              | 328      |
# |    time_elapsed     | 30267    |
# |    total_timesteps  | 9951930  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0199   |
# |    n_updates        | 2462982  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.14e+03 |
# |    ep_rew_mean      | 8.34     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 9832     |
# |    fps              | 328      |
# |    time_elapsed     | 30275    |
# |    total_timesteps  | 9955357  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00629  |
# |    n_updates        | 2463839  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.13e+03 |
# |    ep_rew_mean      | 8.73     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 9836     |
# |    fps              | 328      |
# |    time_elapsed     | 30283    |
# |    total_timesteps  | 9958460  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00573  |
# |    n_updates        | 2464614  |
# ----------------------------------
# Eval num_timesteps=9960000, episode_reward=17.20 +/- 1.60
# Episode length: 701.20 +/- 111.88
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 701      |
# |    mean_reward      | 17.2     |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 9960000  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0121   |
# |    n_updates        | 2464999  |
# ----------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.11e+03 |
# |    ep_rew_mean      | 9.07     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 9840     |
# |    fps              | 328      |
# |    time_elapsed     | 30295    |
# |    total_timesteps  | 9961642  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0291   |
# |    n_updates        | 2465410  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.09e+03 |
# |    ep_rew_mean      | 9.47     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 9844     |
# |    fps              | 328      |
# |    time_elapsed     | 30302    |
# |    total_timesteps  | 9964299  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0104   |
# |    n_updates        | 2466074  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.07e+03 |
# |    ep_rew_mean      | 10       |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 9848     |
# |    fps              | 328      |
# |    time_elapsed     | 30308    |
# |    total_timesteps  | 9966998  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0183   |
# |    n_updates        | 2466749  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.06e+03 |
# |    ep_rew_mean      | 10.3     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 9852     |
# |    fps              | 328      |
# |    time_elapsed     | 30315    |
# |    total_timesteps  | 9969929  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0114   |
# |    n_updates        | 2467482  |
# ----------------------------------
# Eval num_timesteps=9970000, episode_reward=16.80 +/- 2.40
# Episode length: 681.40 +/- 60.58
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 681      |
# |    mean_reward      | 16.8     |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 9970000  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0107   |
# |    n_updates        | 2467499  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.04e+03 |
# |    ep_rew_mean      | 10.7     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 9856     |
# |    fps              | 328      |
# |    time_elapsed     | 30326    |
# |    total_timesteps  | 9972784  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0109   |
# |    n_updates        | 2468195  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | 11.3     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 9860     |
# |    fps              | 328      |
# |    time_elapsed     | 30333    |
# |    total_timesteps  | 9975861  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0161   |
# |    n_updates        | 2468965  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 990      |
# |    ep_rew_mean      | 11.5     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 9864     |
# |    fps              | 328      |
# |    time_elapsed     | 30340    |
# |    total_timesteps  | 9978895  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0221   |
# |    n_updates        | 2469723  |
# ----------------------------------
# Eval num_timesteps=9980000, episode_reward=17.80 +/- 5.91
# Episode length: 484.20 +/- 149.35
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 484      |
# |    mean_reward      | 17.8     |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 9980000  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0244   |
# |    n_updates        | 2469999  |
# ----------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 976      |
# |    ep_rew_mean      | 12       |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 9868     |
# |    fps              | 328      |
# |    time_elapsed     | 30352    |
# |    total_timesteps  | 9982556  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00866  |
# |    n_updates        | 2470638  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 959      |
# |    ep_rew_mean      | 12.3     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 9872     |
# |    fps              | 328      |
# |    time_elapsed     | 30360    |
# |    total_timesteps  | 9985762  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0136   |
# |    n_updates        | 2471440  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 934      |
# |    ep_rew_mean      | 13       |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 9876     |
# |    fps              | 328      |
# |    time_elapsed     | 30366    |
# |    total_timesteps  | 9988463  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00535  |
# |    n_updates        | 2472115  |
# ----------------------------------
# Eval num_timesteps=9990000, episode_reward=19.40 +/- 1.36
# Episode length: 579.00 +/- 39.07
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 579      |
# |    mean_reward      | 19.4     |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 9990000  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0065   |
# |    n_updates        | 2472499  |
# ----------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 920      |
# |    ep_rew_mean      | 13.2     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 9880     |
# |    fps              | 328      |
# |    time_elapsed     | 30377    |
# |    total_timesteps  | 9991515  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00605  |
# |    n_updates        | 2472878  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 900      |
# |    ep_rew_mean      | 13.7     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 9884     |
# |    fps              | 328      |
# |    time_elapsed     | 30384    |
# |    total_timesteps  | 9994114  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00887  |
# |    n_updates        | 2473528  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 892      |
# |    ep_rew_mean      | 13.8     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 9888     |
# |    fps              | 328      |
# |    time_elapsed     | 30391    |
# |    total_timesteps  | 9997253  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00594  |
# |    n_updates        | 2474313  |
# ----------------------------------
# Eval num_timesteps=10000000, episode_reward=19.40 +/- 2.73
# Episode length: 615.80 +/- 102.11
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 616      |
# |    mean_reward      | 19.4     |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 10000000 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0019   |
# |    n_updates        | 2474999  |
# ----------------------------------

# %%
save_path = os.path.join('Training', 'Saved Models','DQN_Pong_10M')
model_pong.save(save_path)

# %%
evaluate_policy(model_pong, env, n_eval_episodes=10, render=True)
# Out:
# (19.9, 1.8681541692269403)

# %%
env.close()
