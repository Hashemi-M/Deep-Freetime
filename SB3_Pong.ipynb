# %%
# https://stable-baselines3.readthedocs.io/en/master/guide/rl.html
# https://spinningup.openai.com/en/latest/spinningup/rl_intro2.html#a-taxonomy-of-rl-algorithms

# %% [markdown]
# # 1. Import dependencies

# %%
import os
from sys import path as syspath
from os import path as ospath
syspath.append(ospath.join(ospath.expanduser("~"), ospath.abspath(os.getcwd())+'/SB3_f'))
ospath.abspath(os.getcwd())+'SB3_f'
# Out:
# '/data/hashemi/Freetime/Freetime-DQN/Deep-FreetimeSB3_f'

# %%
import os
import gym 
import matplotlib.pyplot as plt
import numpy as np'''
from SB3_f.sb3f import DQN
from SB3_f.sb3f.common.vec_env import DummyVecEnv
from SB3_f.sb3f.common.evaluation import evaluate_policy
from SB3_f.sb3f.common.callbacks import EvalCallback, StopTrainingOnRewardThreshold
from SB3_f.sb3f.common.atari_wrappers import AtariWrapper'''

from stable_baselines3 import DQN
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.callbacks import EvalCallback, StopTrainingOnRewardThreshold
from stable_baselines3.common.atari_wrappers import AtariWrapper

# %% [markdown]
# # 2. Load and Test Environment

# %%
environment_name = "Pong-v4"

# %%
env = gym.make(environment_name)

# %%
episodes = 5
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0 
    
    while not done:
        env.render()
        action = env.action_space.sample()
        n_state, reward, done, info = env.step(action)
        score+=reward
    print('Episode:{} Score:{}'.format(episode, score))
env.close()
# Out:
# /usr/local/lib/python3.9/site-packages/gym/envs/atari/environment.py:267: UserWarning: WARN: We strongly suggest supplying `render_mode` when constructing your environment, e.g., gym.make(ID, render_mode='human'). Using `render_mode` provides access to proper scaling, audio support, and proper framerates.
#   logger.warn(
# Episode:1 Score:-21.0
# Episode:2 Score:-20.0
# Episode:3 Score:-21.0
# Episode:4 Score:-20.0
# Episode:5 Score:-19.0

# %% [markdown]
# # 3. Train an RL Model

# %%
log_path = os.path.join('Training','Logs Opt Atari','Pong')
#training_log_path = os.path.join(log_path, 'DQN_Pong')

# %%
save_path = os.path.join('Training', 'Saved Models')

# %%
env = gym.make(environment_name)
env = AtariWrapper(env)

# %%
stop_callback = StopTrainingOnRewardThreshold(reward_threshold=20, verbose=1)
eval_callback = EvalCallback(env, 
                             callback_on_new_best=stop_callback, 
                             eval_freq=10000, 
                             best_model_save_path=save_path, 
                             verbose=1)

# %%
# Pong Reward of -1 or +1 so Opt is +1
#opt_val = 1

model_pong = DQN('CnnPolicy', env, verbose = 1,
            buffer_size = 100000,
            learning_rate = 0.0001, 
            batch_size = 32,
            learning_starts = 100000,
            target_update_interval = 1000,
            train_freq = 4,
            gradient_steps =  1,
            exploration_fraction = 0.1,
            exploration_final_eps = 0.01,
            optimize_memory_usage = False,
            tensorboard_log=log_path)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.

# %%
model_pong.learn(total_timesteps=12000000, callback=eval_callback,tb_log_name='Pong_Opt_10x0.1')
# Out:
# Logging to Training/Logs Opt Atari/Pong/Pong_Opt_10x0.1_6
# /usr/local/lib/python3.9/site-packages/stable_baselines3/common/callbacks.py:345: UserWarning: Training and eval env are not of the same type<stable_baselines3.common.vec_env.vec_transpose.VecTransposeImage object at 0x7feb5e0f2e20> != <stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7feb5e0f2a60>
#   warnings.warn("Training and eval env are not of the same type" f"{self.training_env} != {self.eval_env}")
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 338      |
# |    ep_rew_mean      | -19.8    |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 992      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1354     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 340      |
# |    ep_rew_mean      | -20      |
# |    exploration_rate | 0.998    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 1001     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2717     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 327      |
# |    ep_rew_mean      | -20.2    |
# |    exploration_rate | 0.997    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 1002     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3924     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 325      |
# |    ep_rew_mean      | -20.2    |
# |    exploration_rate | 0.996    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 1004     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 5204     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 331      |
# |    ep_rew_mean      | -20.1    |
# |    exploration_rate | 0.995    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 1003     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 6626     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 327      |
# |    ep_rew_mean      | -20.1    |
# |    exploration_rate | 0.994    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 1003     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 7840     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 321      |
# |    ep_rew_mean      | -20.2    |
# |    exploration_rate | 0.993    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 1004     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 9001     |
# ----------------------------------
# /usr/local/lib/python3.9/site-packages/stable_baselines3/common/evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Eval num_timesteps=10000, episode_reward=-20.00 +/- 2.00
# Episode length: 236.80 +/- 25.57
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 237      |
# |    mean_reward      | -20      |
# | rollout/            |          |
# |    exploration_rate | 0.992    |
# | time/               |          |
# |    total_timesteps  | 10000    |
# ----------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 322      |
# |    ep_rew_mean      | -20.3    |
# |    exploration_rate | 0.991    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 853      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 10310    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 319      |
# |    ep_rew_mean      | -20.4    |
# |    exploration_rate | 0.991    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 866      |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 11467    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 316      |
# |    ep_rew_mean      | -20.4    |
# |    exploration_rate | 0.99     |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 877      |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 12629    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 313      |
# |    ep_rew_mean      | -20.5    |
# |    exploration_rate | 0.989    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 886      |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 13777    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 310      |
# |    ep_rew_mean      | -20.5    |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 893      |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 14871    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 311      |
# |    ep_rew_mean      | -20.4    |
# |    exploration_rate | 0.987    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 901      |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 16175    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 309      |
# |    ep_rew_mean      | -20.5    |
# |    exploration_rate | 0.986    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 908      |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 17307    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 308      |
# |    ep_rew_mean      | -20.5    |
# |    exploration_rate | 0.985    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 913      |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 18491    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 309      |
# |    ep_rew_mean      | -20.4    |
# |    exploration_rate | 0.984    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 919      |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 19791    |
# ----------------------------------
# Eval num_timesteps=20000, episode_reward=-18.00 +/- 6.00
# Episode length: 212.20 +/- 74.63
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 212      |
# |    mean_reward      | -18      |
# | rollout/            |          |
# |    exploration_rate | 0.984    |
# | time/               |          |
# |    total_timesteps  | 20000    |
# ----------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 312      |
# |    ep_rew_mean      | -20.6    |
# |    exploration_rate | 0.983    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 863      |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 21198    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 310      |
# |    ep_rew_mean      | -20.7    |
# |    exploration_rate | 0.982    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 869      |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 22324    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 311      |
# |    ep_rew_mean      | -20.6    |
# |    exploration_rate | 0.98     |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 876      |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 23661    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 309      |
# |    ep_rew_mean      | -20.6    |
# |    exploration_rate | 0.98     |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 881      |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 24756    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 308      |
# |    ep_rew_mean      | -20.6    |
# |    exploration_rate | 0.979    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 886      |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 25909    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 308      |
# |    ep_rew_mean      | -20.6    |
# |    exploration_rate | 0.978    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 890      |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 27072    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 307      |
# |    ep_rew_mean      | -20.7    |
# |    exploration_rate | 0.977    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 895      |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 28245    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 307      |
# |    ep_rew_mean      | -20.6    |
# |    exploration_rate | 0.976    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 899      |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 29461    |
# ----------------------------------
# Eval num_timesteps=30000, episode_reward=-17.80 +/- 6.40
# Episode length: 210.60 +/- 79.43
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 211      |
# |    mean_reward      | -17.8    |
# | rollout/            |          |
# |    exploration_rate | 0.975    |
# | time/               |          |
# |    total_timesteps  | 30000    |
# ----------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 309      |
# |    ep_rew_mean      | -20.8    |
# |    exploration_rate | 0.975    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 862      |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 30871    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 308      |
# |    ep_rew_mean      | -20.8    |
# |    exploration_rate | 0.974    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 867      |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 32104    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 305      |
# |    ep_rew_mean      | -20.8    |
# |    exploration_rate | 0.973    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 871      |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 33245    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 305      |
# |    ep_rew_mean      | -20.8    |
# |    exploration_rate | 0.972    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 875      |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 34436    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 303      |
# |    ep_rew_mean      | -20.8    |
# |    exploration_rate | 0.971    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 878      |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 35539    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 301      |
# |    ep_rew_mean      | -20.9    |
# |    exploration_rate | 0.97     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 882      |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 36701    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 300      |
# |    ep_rew_mean      | -20.9    |
# |    exploration_rate | 0.969    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 885      |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 37831    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 300      |
# |    ep_rew_mean      | -20.9    |
# |    exploration_rate | 0.968    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 888      |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 38952    |
# ----------------------------------
# Eval num_timesteps=40000, episode_reward=-19.40 +/- 3.20
# Episode length: 227.80 +/- 37.91
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 228      |
# |    mean_reward      | -19.4    |
# | rollout/            |          |
# |    exploration_rate | 0.967    |
# | time/               |          |
# |    total_timesteps  | 40000    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 300      |
# |    ep_rew_mean      | -20.9    |
# |    exploration_rate | 0.967    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 859      |
# |    time_elapsed     | 46       |
# |    total_timesteps  | 40261    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 300      |
# |    ep_rew_mean      | -20.9    |
# |    exploration_rate | 0.966    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 862      |
# |    time_elapsed     | 48       |
# |    total_timesteps  | 41474    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 300      |
# |    ep_rew_mean      | -20.9    |
# |    exploration_rate | 0.965    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 866      |
# |    time_elapsed     | 49       |
# |    total_timesteps  | 42663    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 301      |
# |    ep_rew_mean      | -20.9    |
# |    exploration_rate | 0.964    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 869      |
# |    time_elapsed     | 50       |
# |    total_timesteps  | 43870    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 302      |
# |    ep_rew_mean      | -20.9    |
# |    exploration_rate | 0.963    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 872      |
# |    time_elapsed     | 51       |
# |    total_timesteps  | 45051    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 300      |
# |    ep_rew_mean      | -20.9    |
# |    exploration_rate | 0.962    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 875      |
# |    time_elapsed     | 52       |
# |    total_timesteps  | 46159    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 300      |
# |    ep_rew_mean      | -20.9    |
# |    exploration_rate | 0.961    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 877      |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 47305    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 299      |
# |    ep_rew_mean      | -20.9    |
# |    exploration_rate | 0.96     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 880      |
# |    time_elapsed     | 55       |
# |    total_timesteps  | 48433    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 299      |
# |    ep_rew_mean      | -20.9    |
# |    exploration_rate | 0.959    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 883      |
# |    time_elapsed     | 56       |
# |    total_timesteps  | 49715    |
# ----------------------------------
# Eval num_timesteps=50000, episode_reward=-18.20 +/- 5.60
# Episode length: 212.40 +/- 70.21
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 212      |
# |    mean_reward      | -18.2    |
# | rollout/            |          |
# |    exploration_rate | 0.959    |
# | time/               |          |
# |    total_timesteps  | 50000    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 299      |
# |    ep_rew_mean      | -20.9    |
# |    exploration_rate | 0.958    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 862      |
# |    time_elapsed     | 59       |
# |    total_timesteps  | 51132    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 299      |
# |    ep_rew_mean      | -20.9    |
# |    exploration_rate | 0.957    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 865      |
# |    time_elapsed     | 60       |
# |    total_timesteps  | 52261    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 299      |
# |    ep_rew_mean      | -20.9    |
# |    exploration_rate | 0.956    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 867      |
# |    time_elapsed     | 61       |
# |    total_timesteps  | 53519    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 301      |
# |    ep_rew_mean      | -20.9    |
# |    exploration_rate | 0.955    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 870      |
# |    time_elapsed     | 62       |
# |    total_timesteps  | 54839    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 303      |
# |    ep_rew_mean      | -20.9    |
# |    exploration_rate | 0.954    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 873      |
# |    time_elapsed     | 64       |
# |    total_timesteps  | 56175    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 303      |
# |    ep_rew_mean      | -20.9    |
# |    exploration_rate | 0.953    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 875      |
# |    time_elapsed     | 65       |
# |    total_timesteps  | 57338    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 303      |
# |    ep_rew_mean      | -20.9    |
# |    exploration_rate | 0.952    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 877      |
# |    time_elapsed     | 66       |
# |    total_timesteps  | 58516    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 302      |
# |    ep_rew_mean      | -20.9    |
# |    exploration_rate | 0.951    |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 879      |
# |    time_elapsed     | 67       |
# |    total_timesteps  | 59666    |
# ----------------------------------
# Eval num_timesteps=60000, episode_reward=-20.20 +/- 1.60
# Episode length: 233.00 +/- 23.52
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 233      |
# |    mean_reward      | -20.2    |
# | rollout/            |          |
# |    exploration_rate | 0.951    |
# | time/               |          |
# |    total_timesteps  | 60000    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 299      |
# |    ep_rew_mean      | -20.8    |
# |    exploration_rate | 0.95     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 859      |
# |    time_elapsed     | 70       |
# |    total_timesteps  | 60788    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 298      |
# |    ep_rew_mean      | -20.8    |
# |    exploration_rate | 0.949    |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 861      |
# |    time_elapsed     | 71       |
# |    total_timesteps  | 61937    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 298      |
# |    ep_rew_mean      | -20.8    |
# |    exploration_rate | 0.948    |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 863      |
# |    time_elapsed     | 73       |
# |    total_timesteps  | 63062    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 298      |
# |    ep_rew_mean      | -20.8    |
# |    exploration_rate | 0.947    |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 865      |
# |    time_elapsed     | 74       |
# |    total_timesteps  | 64241    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 300      |
# |    ep_rew_mean      | -20.8    |
# |    exploration_rate | 0.946    |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 868      |
# |    time_elapsed     | 75       |
# |    total_timesteps  | 65532    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 299      |
# |    ep_rew_mean      | -20.8    |
# |    exploration_rate | 0.945    |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 870      |
# |    time_elapsed     | 76       |
# |    total_timesteps  | 66650    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 300      |
# |    ep_rew_mean      | -20.8    |
# |    exploration_rate | 0.944    |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 872      |
# |    time_elapsed     | 77       |
# |    total_timesteps  | 67819    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 301      |
# |    ep_rew_mean      | -20.8    |
# |    exploration_rate | 0.943    |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 874      |
# |    time_elapsed     | 78       |
# |    total_timesteps  | 69040    |
# ----------------------------------
# Eval num_timesteps=70000, episode_reward=-20.80 +/- 0.40
# Episode length: 242.80 +/- 11.65
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 243      |
# |    mean_reward      | -20.8    |
# | rollout/            |          |
# |    exploration_rate | 0.942    |
# | time/               |          |
# |    total_timesteps  | 70000    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 300      |
# |    ep_rew_mean      | -20.7    |
# |    exploration_rate | 0.942    |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 856      |
# |    time_elapsed     | 82       |
# |    total_timesteps  | 70251    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 299      |
# |    ep_rew_mean      | -20.8    |
# |    exploration_rate | 0.941    |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 858      |
# |    time_elapsed     | 83       |
# |    total_timesteps  | 71376    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 299      |
# |    ep_rew_mean      | -20.8    |
# |    exploration_rate | 0.94     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 860      |
# |    time_elapsed     | 84       |
# |    total_timesteps  | 72605    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 299      |
# |    ep_rew_mean      | -20.8    |
# |    exploration_rate | 0.939    |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 862      |
# |    time_elapsed     | 85       |
# |    total_timesteps  | 73784    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 299      |
# |    ep_rew_mean      | -20.8    |
# |    exploration_rate | 0.938    |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 864      |
# |    time_elapsed     | 86       |
# |    total_timesteps  | 74943    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 300      |
# |    ep_rew_mean      | -20.8    |
# |    exploration_rate | 0.937    |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 866      |
# |    time_elapsed     | 87       |
# |    total_timesteps  | 76209    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 300      |
# |    ep_rew_mean      | -20.8    |
# |    exploration_rate | 0.936    |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 868      |
# |    time_elapsed     | 89       |
# |    total_timesteps  | 77328    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 301      |
# |    ep_rew_mean      | -20.8    |
# |    exploration_rate | 0.935    |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 870      |
# |    time_elapsed     | 90       |
# |    total_timesteps  | 78578    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 300      |
# |    ep_rew_mean      | -20.8    |
# |    exploration_rate | 0.934    |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 871      |
# |    time_elapsed     | 91       |
# |    total_timesteps  | 79698    |
# ----------------------------------
# Eval num_timesteps=80000, episode_reward=-20.60 +/- 0.80
# Episode length: 243.60 +/- 12.78
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 244      |
# |    mean_reward      | -20.6    |
# | rollout/            |          |
# |    exploration_rate | 0.934    |
# | time/               |          |
# |    total_timesteps  | 80000    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 298      |
# |    ep_rew_mean      | -20.7    |
# |    exploration_rate | 0.933    |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 856      |
# |    time_elapsed     | 94       |
# |    total_timesteps  | 80903    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 299      |
# |    ep_rew_mean      | -20.7    |
# |    exploration_rate | 0.932    |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 858      |
# |    time_elapsed     | 95       |
# |    total_timesteps  | 82143    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 298      |
# |    ep_rew_mean      | -20.7    |
# |    exploration_rate | 0.931    |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 860      |
# |    time_elapsed     | 96       |
# |    total_timesteps  | 83360    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 297      |
# |    ep_rew_mean      | -20.7    |
# |    exploration_rate | 0.93     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 861      |
# |    time_elapsed     | 98       |
# |    total_timesteps  | 84507    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 295      |
# |    ep_rew_mean      | -20.7    |
# |    exploration_rate | 0.929    |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 863      |
# |    time_elapsed     | 99       |
# |    total_timesteps  | 85722    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 296      |
# |    ep_rew_mean      | -20.7    |
# |    exploration_rate | 0.928    |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 865      |
# |    time_elapsed     | 100      |
# |    total_timesteps  | 86962    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 295      |
# |    ep_rew_mean      | -20.7    |
# |    exploration_rate | 0.927    |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 866      |
# |    time_elapsed     | 101      |
# |    total_timesteps  | 88024    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 296      |
# |    ep_rew_mean      | -20.7    |
# |    exploration_rate | 0.926    |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 868      |
# |    time_elapsed     | 102      |
# |    total_timesteps  | 89226    |
# ----------------------------------
# Eval num_timesteps=90000, episode_reward=-18.80 +/- 4.40
# Episode length: 219.40 +/- 57.21
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 219      |
# |    mean_reward      | -18.8    |
# | rollout/            |          |
# |    exploration_rate | 0.926    |
# | time/               |          |
# |    total_timesteps  | 90000    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 298      |
# |    ep_rew_mean      | -20.8    |
# |    exploration_rate | 0.925    |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 856      |
# |    time_elapsed     | 105      |
# |    total_timesteps  | 90581    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 298      |
# |    ep_rew_mean      | -20.8    |
# |    exploration_rate | 0.924    |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 857      |
# |    time_elapsed     | 106      |
# |    total_timesteps  | 91775    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 299      |
# |    ep_rew_mean      | -20.7    |
# |    exploration_rate | 0.923    |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 859      |
# |    time_elapsed     | 108      |
# |    total_timesteps  | 92972    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 299      |
# |    ep_rew_mean      | -20.7    |
# |    exploration_rate | 0.922    |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 861      |
# |    time_elapsed     | 109      |
# |    total_timesteps  | 94103    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 297      |
# |    ep_rew_mean      | -20.8    |
# |    exploration_rate | 0.921    |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 862      |
# |    time_elapsed     | 110      |
# |    total_timesteps  | 95198    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 299      |
# |    ep_rew_mean      | -20.7    |
# |    exploration_rate | 0.92     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 864      |
# |    time_elapsed     | 111      |
# |    total_timesteps  | 96545    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 299      |
# |    ep_rew_mean      | -20.7    |
# |    exploration_rate | 0.919    |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 865      |
# |    time_elapsed     | 112      |
# |    total_timesteps  | 97702    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 298      |
# |    ep_rew_mean      | -20.8    |
# |    exploration_rate | 0.918    |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 866      |
# |    time_elapsed     | 113      |
# |    total_timesteps  | 98811    |
# ----------------------------------
# Eval num_timesteps=100000, episode_reward=-17.60 +/- 6.80
# Episode length: 209.80 +/- 77.92
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 210      |
# |    mean_reward      | -17.6    |
# | rollout/            |          |
# |    exploration_rate | 0.918    |
# | time/               |          |
# |    total_timesteps  | 100000   |
# ----------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 300      |
# |    ep_rew_mean      | -20.9    |
# |    exploration_rate | 0.917    |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 854      |
# |    time_elapsed     | 117      |
# |    total_timesteps  | 100253   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0169   |
# |    n_updates        | 63       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 301      |
# |    ep_rew_mean      | -20.9    |
# |    exploration_rate | 0.916    |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 848      |
# |    time_elapsed     | 119      |
# |    total_timesteps  | 101517   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0178   |
# |    n_updates        | 379      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 302      |
# |    ep_rew_mean      | -20.8    |
# |    exploration_rate | 0.915    |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 841      |
# |    time_elapsed     | 122      |
# |    total_timesteps  | 102786   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00159  |
# |    n_updates        | 696      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 301      |
# |    ep_rew_mean      | -20.8    |
# |    exploration_rate | 0.914    |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 836      |
# |    time_elapsed     | 124      |
# |    total_timesteps  | 103905   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0273   |
# |    n_updates        | 976      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 301      |
# |    ep_rew_mean      | -20.8    |
# |    exploration_rate | 0.913    |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 831      |
# |    time_elapsed     | 126      |
# |    total_timesteps  | 105072   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0169   |
# |    n_updates        | 1267     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 300      |
# |    ep_rew_mean      | -20.8    |
# |    exploration_rate | 0.912    |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 826      |
# |    time_elapsed     | 128      |
# |    total_timesteps  | 106177   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0287   |
# |    n_updates        | 1544     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 301      |
# |    ep_rew_mean      | -20.8    |
# |    exploration_rate | 0.911    |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 821      |
# |    time_elapsed     | 130      |
# |    total_timesteps  | 107429   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0539   |
# |    n_updates        | 1857     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 301      |
# |    ep_rew_mean      | -20.8    |
# |    exploration_rate | 0.91     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 816      |
# |    time_elapsed     | 133      |
# |    total_timesteps  | 108690   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0576   |
# |    n_updates        | 2172     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 301      |
# |    ep_rew_mean      | -20.8    |
# |    exploration_rate | 0.909    |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 812      |
# |    time_elapsed     | 135      |
# |    total_timesteps  | 109823   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.02     |
# |    n_updates        | 2455     |
# ----------------------------------
# Eval num_timesteps=110000, episode_reward=-18.60 +/- 4.80
# Episode length: 218.20 +/- 61.66
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 218      |
# |    mean_reward      | -18.6    |
# | rollout/            |          |
# |    exploration_rate | 0.909    |
# | time/               |          |
# |    total_timesteps  | 110000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0246   |
# |    n_updates        | 2499     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 303      |
# |    ep_rew_mean      | -20.9    |
# |    exploration_rate | 0.908    |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 797      |
# |    time_elapsed     | 139      |
# |    total_timesteps  | 111241   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.045    |
# |    n_updates        | 2810     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 302      |
# |    ep_rew_mean      | -20.9    |
# |    exploration_rate | 0.907    |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 793      |
# |    time_elapsed     | 141      |
# |    total_timesteps  | 112359   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0278   |
# |    n_updates        | 3089     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 303      |
# |    ep_rew_mean      | -20.9    |
# |    exploration_rate | 0.906    |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 788      |
# |    time_elapsed     | 144      |
# |    total_timesteps  | 113612   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0325   |
# |    n_updates        | 3402     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 303      |
# |    ep_rew_mean      | -20.9    |
# |    exploration_rate | 0.905    |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 784      |
# |    time_elapsed     | 146      |
# |    total_timesteps  | 114789   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0264   |
# |    n_updates        | 3697     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 302      |
# |    ep_rew_mean      | -20.9    |
# |    exploration_rate | 0.904    |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 780      |
# |    time_elapsed     | 148      |
# |    total_timesteps  | 115916   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0435   |
# |    n_updates        | 3978     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 302      |
# |    ep_rew_mean      | -20.9    |
# |    exploration_rate | 0.903    |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 776      |
# |    time_elapsed     | 150      |
# |    total_timesteps  | 117170   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0567   |
# |    n_updates        | 4292     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 303      |
# |    ep_rew_mean      | -20.9    |
# |    exploration_rate | 0.902    |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 773      |
# |    time_elapsed     | 152      |
# |    total_timesteps  | 118300   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0165   |
# |    n_updates        | 4574     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 302      |
# |    ep_rew_mean      | -20.9    |
# |    exploration_rate | 0.901    |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 770      |
# |    time_elapsed     | 155      |
# |    total_timesteps  | 119447   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0327   |
# |    n_updates        | 4861     |
# ----------------------------------
# Eval num_timesteps=120000, episode_reward=-18.00 +/- 6.00
# Episode length: 213.00 +/- 72.01
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 213      |
# |    mean_reward      | -18      |
# | rollout/            |          |
# |    exploration_rate | 0.901    |
# | time/               |          |
# |    total_timesteps  | 120000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.09     |
# |    n_updates        | 4999     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 303      |
# |    ep_rew_mean      | -20.9    |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 758      |
# |    time_elapsed     | 159      |
# |    total_timesteps  | 120862   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0249   |
# |    n_updates        | 5215     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 303      |
# |    ep_rew_mean      | -20.9    |
# |    exploration_rate | 0.899    |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 755      |
# |    time_elapsed     | 161      |
# |    total_timesteps  | 122059   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0293   |
# |    n_updates        | 5514     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 304      |
# |    ep_rew_mean      | -20.9    |
# |    exploration_rate | 0.898    |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 752      |
# |    time_elapsed     | 163      |
# |    total_timesteps  | 123346   |
# | train/              |          |
# ...
# Episode length: 1101.40 +/- 308.84
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 1.1e+03  |
# |    mean_reward      | 5.8      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 11900000 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00578  |
# |    n_updates        | 2949999  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.32e+03 |
# |    ep_rew_mean      | 5.44     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 12272    |
# |    fps              | 325      |
# |    time_elapsed     | 36562    |
# |    total_timesteps  | 11901548 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0141   |
# |    n_updates        | 2950386  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.32e+03 |
# |    ep_rew_mean      | 5.96     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 12276    |
# |    fps              | 325      |
# |    time_elapsed     | 36574    |
# |    total_timesteps  | 11906800 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00768  |
# |    n_updates        | 2951699  |
# ----------------------------------
# Eval num_timesteps=11910000, episode_reward=7.00 +/- 5.59
# Episode length: 1182.00 +/- 240.12
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 1.18e+03 |
# |    mean_reward      | 7        |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 11910000 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00497  |
# |    n_updates        | 2952499  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.3e+03  |
# |    ep_rew_mean      | 6.05     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 12280    |
# |    fps              | 325      |
# |    time_elapsed     | 36595    |
# |    total_timesteps  | 11911428 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00938  |
# |    n_updates        | 2952856  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.3e+03  |
# |    ep_rew_mean      | 6.06     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 12284    |
# |    fps              | 325      |
# |    time_elapsed     | 36605    |
# |    total_timesteps  | 11915846 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00545  |
# |    n_updates        | 2953961  |
# ----------------------------------
# Eval num_timesteps=11920000, episode_reward=8.60 +/- 3.01
# Episode length: 1209.80 +/- 70.29
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 1.21e+03 |
# |    mean_reward      | 8.6      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 11920000 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0128   |
# |    n_updates        | 2954999  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.29e+03 |
# |    ep_rew_mean      | 5.79     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 12288    |
# |    fps              | 325      |
# |    time_elapsed     | 36627    |
# |    total_timesteps  | 11921283 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00957  |
# |    n_updates        | 2955320  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.29e+03 |
# |    ep_rew_mean      | 5.86     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 12292    |
# |    fps              | 325      |
# |    time_elapsed     | 36640    |
# |    total_timesteps  | 11926622 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00866  |
# |    n_updates        | 2956655  |
# ----------------------------------
# Eval num_timesteps=11930000, episode_reward=8.00 +/- 4.00
# Episode length: 1072.60 +/- 413.91
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 1.07e+03 |
# |    mean_reward      | 8        |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 11930000 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0156   |
# |    n_updates        | 2957499  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.31e+03 |
# |    ep_rew_mean      | 5.8      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 12296    |
# |    fps              | 325      |
# |    time_elapsed     | 36664    |
# |    total_timesteps  | 11933151 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0038   |
# |    n_updates        | 2958287  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.32e+03 |
# |    ep_rew_mean      | 5.94     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 12300    |
# |    fps              | 325      |
# |    time_elapsed     | 36676    |
# |    total_timesteps  | 11938365 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0184   |
# |    n_updates        | 2959591  |
# ----------------------------------
# Eval num_timesteps=11940000, episode_reward=3.40 +/- 4.03
# Episode length: 1123.00 +/- 350.39
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 1.12e+03 |
# |    mean_reward      | 3.4      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 11940000 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00585  |
# |    n_updates        | 2959999  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.31e+03 |
# |    ep_rew_mean      | 5.89     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 12304    |
# |    fps              | 325      |
# |    time_elapsed     | 36697    |
# |    total_timesteps  | 11943800 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0142   |
# |    n_updates        | 2960949  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.32e+03 |
# |    ep_rew_mean      | 5.82     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 12308    |
# |    fps              | 325      |
# |    time_elapsed     | 36710    |
# |    total_timesteps  | 11948985 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00554  |
# |    n_updates        | 2962246  |
# ----------------------------------
# Eval num_timesteps=11950000, episode_reward=9.60 +/- 4.36
# Episode length: 865.00 +/- 367.03
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 865      |
# |    mean_reward      | 9.6      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 11950000 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0125   |
# |    n_updates        | 2962499  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.32e+03 |
# |    ep_rew_mean      | 6.12     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 12312    |
# |    fps              | 325      |
# |    time_elapsed     | 36731    |
# |    total_timesteps  | 11955062 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00678  |
# |    n_updates        | 2963765  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.32e+03 |
# |    ep_rew_mean      | 6.22     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 12316    |
# |    fps              | 325      |
# |    time_elapsed     | 36743    |
# |    total_timesteps  | 11959885 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0013   |
# |    n_updates        | 2964971  |
# ----------------------------------
# Eval num_timesteps=11960000, episode_reward=5.80 +/- 4.26
# Episode length: 1236.20 +/- 156.70
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 1.24e+03 |
# |    mean_reward      | 5.8      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 11960000 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0172   |
# |    n_updates        | 2964999  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.33e+03 |
# |    ep_rew_mean      | 6.43     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 12320    |
# |    fps              | 325      |
# |    time_elapsed     | 36764    |
# |    total_timesteps  | 11964888 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00608  |
# |    n_updates        | 2966221  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.33e+03 |
# |    ep_rew_mean      | 6.45     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 12324    |
# |    fps              | 325      |
# |    time_elapsed     | 36775    |
# |    total_timesteps  | 11969498 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00501  |
# |    n_updates        | 2967374  |
# ----------------------------------
# Eval num_timesteps=11970000, episode_reward=7.60 +/- 5.00
# Episode length: 1113.80 +/- 247.15
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 1.11e+03 |
# |    mean_reward      | 7.6      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 11970000 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00576  |
# |    n_updates        | 2967499  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.34e+03 |
# |    ep_rew_mean      | 6.49     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 12328    |
# |    fps              | 325      |
# |    time_elapsed     | 36797    |
# |    total_timesteps  | 11975181 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00543  |
# |    n_updates        | 2968795  |
# ----------------------------------
# Eval num_timesteps=11980000, episode_reward=8.20 +/- 3.66
# Episode length: 1018.40 +/- 374.61
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 1.02e+03 |
# |    mean_reward      | 8.2      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 11980000 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0177   |
# |    n_updates        | 2969999  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.34e+03 |
# |    ep_rew_mean      | 6.61     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 12332    |
# |    fps              | 325      |
# |    time_elapsed     | 36819    |
# |    total_timesteps  | 11981153 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00352  |
# |    n_updates        | 2970288  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.33e+03 |
# |    ep_rew_mean      | 6.62     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 12336    |
# |    fps              | 325      |
# |    time_elapsed     | 36830    |
# |    total_timesteps  | 11985877 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0132   |
# |    n_updates        | 2971469  |
# ----------------------------------
# Eval num_timesteps=11990000, episode_reward=3.80 +/- 6.49
# Episode length: 1238.40 +/- 169.75
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 1.24e+03 |
# |    mean_reward      | 3.8      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 11990000 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00961  |
# |    n_updates        | 2972499  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.33e+03 |
# |    ep_rew_mean      | 6.64     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 12340    |
# |    fps              | 325      |
# |    time_elapsed     | 36852    |
# |    total_timesteps  | 11991386 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0136   |
# |    n_updates        | 2972846  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.32e+03 |
# |    ep_rew_mean      | 6.77     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 12344    |
# |    fps              | 325      |
# |    time_elapsed     | 36863    |
# |    total_timesteps  | 11995826 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.02     |
# |    n_updates        | 2973956  |
# ----------------------------------
# Eval num_timesteps=12000000, episode_reward=8.40 +/- 5.08
# Episode length: 1207.20 +/- 251.04
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 1.21e+03 |
# |    mean_reward      | 8.4      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 12000000 |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0112   |
# |    n_updates        | 2974999  |
# ----------------------------------

# %%
save_path = os.path.join('Training', 'Saved Models','Opt_Pong_10M')
model_pong.save(save_path)

# %%
evaluate_policy(model_pong, env, n_eval_episodes=10, render=True)
# Out:
# (0.4, 6.902173570694959)

# %%
env.close()
