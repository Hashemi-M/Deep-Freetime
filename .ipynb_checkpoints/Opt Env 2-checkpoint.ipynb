# %%
from sys import path as syspath
from os import path as ospath
syspath.append(ospath.join(ospath.expanduser("~"), '/data/hashemi/Freetime/Freetime-DQN/Deep-Freetime/SB3_f'))

# %%
import torch as torch
torch._C._cuda_getDeviceCount() > 0
# Out:
# True

# %%
import os
import gym 
import matplotlib.pyplot as plt
import numpy as np 
from SB3_f.sb3f import DQN
from SB3_f.sb3f.common.vec_env import DummyVecEnv
from SB3_f.sb3f.common.evaluation import evaluate_policy
from SB3_f.sb3f.common.callbacks import EvalCallback, StopTrainingOnRewardThreshold

# %%
rewards = [[1,1,6],[1,3,4]]
from GridEnv import WindyGridworld
env = WindyGridworld(
        height=20,
        width=11,
        rewards=rewards,
        wind=True,
        allowed_actions=['L', 'R', 'C'],
        reward_terminates_episode=False
    )

# %%
episodes = 5
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0 
    
    while not done:
        env.render()
        action = env.action_space.sample()
        n_state, reward, done, info = env.step(action)
        score+=reward
    print('Episode:{} Score:{}'.format(episode, score))
env.close()
# Out:
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# Qt: Session management error: None of the authentication protocols specified are supported
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QStandardPaths: XDG_RUNTIME_DIR points to non-existing path '/run/user/1001', please create it with 0700 permissions.
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
#
# QObject::moveToThread: Current thread (0x5558f0c82b40) is not the object's thread (0x5558f0e52950).
# Cannot move to target thread (0x5558f0c82b40)
# Episode:1 Score:0
# Episode:2 Score:0
# Episode:3 Score:0
# Episode:4 Score:0
# Episode:5 Score:0

# %%
save_path = os.path.join('Training', 'Saved Models')
log_path = os.path.join('Training', 'Logs Bias Only', 'Env 2')

# %%
from SB3_f.sb3f.common.callbacks import EvalCallback, StopTrainingOnRewardThreshold

stop_callback = StopTrainingOnRewardThreshold(reward_threshold=2, verbose=1)
eval_callback = EvalCallback(env, 
                             callback_on_new_best=stop_callback, 
                             eval_freq=10000, 
                             best_model_save_path=save_path, 
                             verbose=1)

# %%
# try 0.2 exploration period
model = DQN('CnnPolicy', env, exploration_fraction=0.2,
  exploration_final_eps=0.1,learning_starts=100000, verbose = 1, buffer_size = 50000,target_update_interval=1000, tensorboard_log=log_path)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.

# %%
from SB3_f.sb3f.common.utils import obs_as_tensor
device = torch.device('cuda:0')

obs = env.canvas
plt.imshow(obs)


# Check the Network Q Value
observation = np.transpose(obs, (2, 0, 1))
observation = observation[np.newaxis, ...]
observation = obs_as_tensor(observation, device)
with torch.no_grad():
        q_values = model.q_net(observation)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
q_values
# Out:
# tensor([[1.9972, 2.0019, 2.0080]], device='cuda:0')

# %%
model.learn(total_timesteps=1000000,callback=eval_callback, tb_log_name='Env2_0.2exp_1M')
# Out:
# 2022-10-21 05:45:24.249896: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# Logging to Training/Logs Bias Only/Env 2/Env2_0.2exp_1M_8
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11       |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 51       |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 44       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.8     |
# |    ep_rew_mean      | 0.125    |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 126      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 110      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.7     |
# |    ep_rew_mean      | 0.0833   |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 159      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 140      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.4     |
# |    ep_rew_mean      | 0.0625   |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 238      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 215      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.8     |
# |    ep_rew_mean      | 0.15     |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 300      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 277      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.5     |
# |    ep_rew_mean      | 0.125    |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 344      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 323      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.9     |
# |    ep_rew_mean      | 0.179    |
# |    exploration_rate | 0.998    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 405      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 389      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.1     |
# |    ep_rew_mean      | 0.188    |
# |    exploration_rate | 0.998    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 461      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 452      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.2     |
# |    ep_rew_mean      | 0.167    |
# |    exploration_rate | 0.998    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 513      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 513      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.7     |
# |    ep_rew_mean      | 0.15     |
# |    exploration_rate | 0.998    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 542      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 548      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.9     |
# |    ep_rew_mean      | 0.159    |
# |    exploration_rate | 0.997    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 592      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 610      |
# ----------------------------------
# /data/hashemi/Freetime/Freetime-DQN/Deep-Freetime/SB3_f/sb3f/common/callbacks.py:388: UserWarning: Training and eval env are not of the same type<sb3f.common.vec_env.vec_transpose.VecTransposeImage object at 0x7f9694f2c2e0> != <sb3f.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f9694f2ca30>
#   warnings.warn("Training and eval env are not of the same type" f"{self.training_env} != {self.eval_env}")
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.8     |
# |    ep_rew_mean      | 0.146    |
# |    exploration_rate | 0.997    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 634      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 664      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.8     |
# |    ep_rew_mean      | 0.135    |
# |    exploration_rate | 0.997    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              |
|
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00355  |
# |    n_updates        | 12067    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.6     |
# |    ep_rew_mean      | 1.06     |
# |    exploration_rate | 0.333    |
# | time/               |          |
# |    episodes         | 9668     |
# |    fps              | 1484     |
# |    time_elapsed     | 99       |
# |    total_timesteps  | 148331   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0162   |
# |    n_updates        | 12082    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.6     |
# |    ep_rew_mean      | 1.09     |
# |    exploration_rate | 0.332    |
# | time/               |          |
# |    episodes         | 9672     |
# |    fps              | 1483     |
# |    time_elapsed     | 100      |
# |    total_timesteps  | 148405   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00252  |
# |    n_updates        | 12101    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.6     |
# |    ep_rew_mean      | 1.03     |
# |    exploration_rate | 0.332    |
# | time/               |          |
# |    episodes         | 9676     |
# |    fps              | 1482     |
# |    time_elapsed     | 100      |
# |    total_timesteps  | 148477   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00969  |
# |    n_updates        | 12119    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.5     |
# |    ep_rew_mean      | 1.03     |
# |    exploration_rate | 0.332    |
# | time/               |          |
# |    episodes         | 9680     |
# |    fps              | 1481     |
# |    time_elapsed     | 100      |
# |    total_timesteps  | 148543   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00356  |
# |    n_updates        | 12135    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.4     |
# |    ep_rew_mean      | 1.02     |
# |    exploration_rate | 0.331    |
# | time/               |          |
# |    episodes         | 9684     |
# |    fps              | 1480     |
# |    time_elapsed     | 100      |
# |    total_timesteps  | 148607   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00435  |
# |    n_updates        | 12151    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.1     |
# |    ep_rew_mean      | 0.98     |
# |    exploration_rate | 0.331    |
# | time/               |          |
# |    episodes         | 9688     |
# |    fps              | 1480     |
# |    time_elapsed     | 100      |
# |    total_timesteps  | 148652   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00257  |
# |    n_updates        | 12162    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.1     |
# |    ep_rew_mean      | 0.95     |
# |    exploration_rate | 0.331    |
# | time/               |          |
# |    episodes         | 9692     |
# |    fps              | 1479     |
# |    time_elapsed     | 100      |
# |    total_timesteps  | 148732   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00936  |
# |    n_updates        | 12182    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.2     |
# |    ep_rew_mean      | 0.96     |
# |    exploration_rate | 0.33     |
# | time/               |          |
# |    episodes         | 9696     |
# |    fps              | 1478     |
# |    time_elapsed     | 100      |
# |    total_timesteps  | 148806   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00174  |
# |    n_updates        | 12201    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.3     |
# |    ep_rew_mean      | 0.97     |
# |    exploration_rate | 0.33     |
# | time/               |          |
# |    episodes         | 9700     |
# |    fps              | 1477     |
# |    time_elapsed     | 100      |
# |    total_timesteps  | 148866   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00976  |
# |    n_updates        | 12216    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.2     |
# |    ep_rew_mean      | 0.98     |
# |    exploration_rate | 0.33     |
# | time/               |          |
# |    episodes         | 9704     |
# |    fps              | 1477     |
# |    time_elapsed     | 100      |
# |    total_timesteps  | 148925   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0185   |
# |    n_updates        | 12231    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.1     |
# |    ep_rew_mean      | 1        |
# |    exploration_rate | 0.33     |
# | time/               |          |
# |    episodes         | 9708     |
# |    fps              | 1476     |
# |    time_elapsed     | 100      |
# |    total_timesteps  | 148988   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00364  |
# |    n_updates        | 12246    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.9     |
# |    ep_rew_mean      | 1.01     |
# |    exploration_rate | 0.329    |
# | time/               |          |
# |    episodes         | 9712     |
# |    fps              | 1475     |
# |    time_elapsed     | 100      |
# |    total_timesteps  | 149049   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00796  |
# |    n_updates        | 12262    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.9     |
# |    ep_rew_mean      | 1.01     |
# |    exploration_rate | 0.329    |
# | time/               |          |
# |    episodes         | 9716     |
# |    fps              | 1474     |
# |    time_elapsed     | 101      |
# |    total_timesteps  | 149127   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00235  |
# |    n_updates        | 12281    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.9     |
# |    ep_rew_mean      | 1.02     |
# |    exploration_rate | 0.329    |
# | time/               |          |
# |    episodes         | 9720     |
# |    fps              | 1473     |
# |    time_elapsed     | 101      |
# |    total_timesteps  | 149200   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00746  |
# |    n_updates        | 12299    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17       |
# |    ep_rew_mean      | 1.06     |
# |    exploration_rate | 0.328    |
# | time/               |          |
# |    episodes         | 9724     |
# |    fps              | 1473     |
# |    time_elapsed     | 101      |
# |    total_timesteps  | 149276   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00233  |
# |    n_updates        | 12318    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.7     |
# |    ep_rew_mean      | 1.01     |
# |    exploration_rate | 0.328    |
# | time/               |          |
# |    episodes         | 9728     |
# |    fps              | 1472     |
# |    time_elapsed     | 101      |
# |    total_timesteps  | 149318   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.014    |
# |    n_updates        | 12329    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.7     |
# |    ep_rew_mean      | 1.05     |
# |    exploration_rate | 0.328    |
# | time/               |          |
# |    episodes         | 9732     |
# |    fps              | 1471     |
# |    time_elapsed     | 101      |
# |    total_timesteps  | 149392   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00387  |
# |    n_updates        | 12347    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.7     |
# |    ep_rew_mean      | 1.05     |
# |    exploration_rate | 0.327    |
# | time/               |          |
# |    episodes         | 9736     |
# |    fps              | 1471     |
# |    time_elapsed     | 101      |
# |    total_timesteps  | 149468   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0103   |
# |    n_updates        | 12366    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.6     |
# |    ep_rew_mean      | 1.01     |
# |    exploration_rate | 0.327    |
# | time/               |          |
# |    episodes         | 9740     |
# |    fps              | 1470     |
# |    time_elapsed     | 101      |
# |    total_timesteps  | 149532   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00261  |
# |    n_updates        | 12382    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.5     |
# |    ep_rew_mean      | 1.03     |
# |    exploration_rate | 0.327    |
# | time/               |          |
# |    episodes         | 9744     |
# |    fps              | 1469     |
# |    time_elapsed     | 101      |
# |    total_timesteps  | 149588   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00224  |
# |    n_updates        | 12396    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.3     |
# |    ep_rew_mean      | 0.98     |
# |    exploration_rate | 0.327    |
# | time/               |          |
# |    episodes         | 9748     |
# |    fps              | 1469     |
# |    time_elapsed     | 101      |
# |    total_timesteps  | 149635   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00377  |
# |    n_updates        | 12408    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.2     |
# |    ep_rew_mean      | 0.99     |
# |    exploration_rate | 0.326    |
# | time/               |          |
# |    episodes         | 9752     |
# |    fps              | 1468     |
# |    time_elapsed     | 101      |
# |    total_timesteps  | 149711   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00483  |
# |    n_updates        | 12427    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16       |
# |    ep_rew_mean      | 1.01     |
# |    exploration_rate | 0.326    |
# | time/               |          |
# |    episodes         | 9756     |
# |    fps              | 1467     |
# |    time_elapsed     | 102      |
# |    total_timesteps  | 149769   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00408  |
# |    n_updates        | 12442    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.3     |
# |    ep_rew_mean      | 0.99     |
# |    exploration_rate | 0.326    |
# | time/               |          |
# |    episodes         | 9760     |
# |    fps              | 1467     |
# |    time_elapsed     | 102      |
# |    total_timesteps  | 149823   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.017    |
# |    n_updates        | 12455    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.1     |
# |    ep_rew_mean      | 0.98     |
# |    exploration_rate | 0.326    |
# | time/               |          |
# |    episodes         | 9764     |
# |    fps              | 1466     |
# |    time_elapsed     | 102      |
# |    total_timesteps  | 149882   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00542  |
# |    n_updates        | 12470    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.1     |
# |    ep_rew_mean      | 0.97     |
# |    exploration_rate | 0.325    |
# | time/               |          |
# |    episodes         | 9768     |
# |    fps              | 1465     |
# |    time_elapsed     | 102      |
# |    total_timesteps  | 149943   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0137   |
# |    n_updates        | 12485    |
# ----------------------------------
# Eval num_timesteps=150000, episode_reward=1.80 +/- 0.40
# Episode length: 18.40 +/- 0.80
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 18.4     |
# |    mean_reward      | 1.8      |
# | rollout/            |          |
# |    exploration_rate | 0.325    |
# | time/               |          |
# |    total_timesteps  | 150000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00301  |
# |    n_updates        | 12499    |
# ----------------------------------
# New best mean reward!
# Stopping training because the mean reward 1.80  is above the threshold 1

# %%
save_path = os.path.join('Training', 'Saved Models', 'Env2_Opt_BaisOnly_1M')
model.save(save_path)
