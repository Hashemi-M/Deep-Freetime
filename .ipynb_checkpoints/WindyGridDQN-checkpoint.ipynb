# %%
# https://stable-baselines3.readthedocs.io/en/master/guide/rl.html
# https://spinningup.openai.com/en/latest/spinningup/rl_intro2.html#a-taxonomy-of-rl-algorithms

# %% [markdown]
# # 1. Import dependencies

# %%
import os
import gym 
from stable_baselines3 import DQN
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy

# %% [markdown]
# # 2. Load and Test Environment

# %%
#environment_name = "Pong-v0"
rewards = [[1,0,5], [1,10,4], [1,4,6]]
#rewards = [[1,0,8], [1,10,3]]

# %%
#env = gym.make(environment_name)
from GridEnv import WindyGridworld
env = WindyGridworld(
        height=20,
        width=11,
        rewards=rewards,
        wind=True,
        allowed_actions=['L', 'R', 'C'],
        reward_terminates_episode=False
    )

# %%
episodes = 10
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0 
    
    while not done:
        env.render()
        action = env.action_space.sample()
        n_state, reward, done, info = env.step(action)
        score+=reward
    print('Episode:{} Score:{}'.format(episode, score))
env.close()
# Out:
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# Qt: Session management error: None of the authentication protocols specified are supported
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QStandardPaths: XDG_RUNTIME_DIR points to non-existing path '/run/user/1001', please create it with 0700 permissions.
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
#
# QObject::moveToThread: Current thread (0x55af871f8160) is not the object's thread (0x55af86dbf7c0).
# Cannot move to target thread (0x55af871f8160)
# Episode:1 Score:0
# Episode:2 Score:0
# Episode:3 Score:0
# Episode:4 Score:0
# Episode:5 Score:0
# Episode:6 Score:0
# Episode:7 Score:0
# Episode:8 Score:0
# Episode:9 Score:0
# Episode:10 Score:0

# %%
env.action_space.sample()
# Out:
# 1

# %%
env.observation_space.sample().shape
# Out:
# (84, 84, 3)

# %% [markdown]
# # 3. Train an RL Model

# %%
DQN_path = os.path.join('Training', 'Saved Models', 'DQN_model_GridWorld_Plenty')

# %%
from stable_baselines3.common.evaluation import evaluate_policy

# %%
log_path = os.path.join('Training','Logs')
training_log_path = os.path.join(log_path, 'DQN_Pong')

# %%
from stable_baselines3.common.callbacks import EvalCallback, StopTrainingOnRewardThreshold

# %%
save_path = os.path.join('Training', 'Saved Models')
log_path = os.path.join('Training', 'Logs')

# %%
from GridEnv import WindyGridworld
env = env = WindyGridworld(
        height=20,
        width=11,
        rewards=rewards,
        wind=True,
        allowed_actions=['L', 'R', 'C'],
        reward_terminates_episode=False
    )

print(env.rewards)
# Out:
# [[1, 0, 5], [1, 10, 4], [1, 4, 6]]

# %%
stop_callback = StopTrainingOnRewardThreshold(reward_threshold=3, verbose=1)
eval_callback = EvalCallback(env, 
                             callback_on_new_best=stop_callback, 
                             eval_freq=10000, 
                             best_model_save_path=save_path, 
                             verbose=1)

# %%
len(env.observation_space.shape)
# Out:
# 3

# %%
model = DQN('CnnPolicy', env, verbose = 1, buffer_size = 10000, tensorboard_log=log_path)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.
# /usr/local/lib/python3.9/site-packages/torch/cuda/__init__.py:83: UserWarning: CUDA initialization: CUDA unknown error - this may be due to an incorrectly set up environment, e.g. changing env variable CUDA_VISIBLE_DEVICES after program start. Setting the available devices to be zero. (Triggered internally at  ../c10/cuda/CUDAFunctions.cpp:109.)
#   return torch._C._cuda_getDeviceCount() > 0

# %%
model.learn(total_timesteps=3000000, callback=eval_callback)
# Out:
# 2022-08-17 00:40:06.264655: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# Logging to Training/Logs/DQN_14
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.5     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 64       |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 54       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.5     |
# |    ep_rew_mean      | 0.125    |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 135      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 116      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.5     |
# |    ep_rew_mean      | 0.167    |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 212      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 186      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.5     |
# |    ep_rew_mean      | 0.188    |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 277      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 248      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.5     |
# |    ep_rew_mean      | 0.15     |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 339      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 310      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.6     |
# |    ep_rew_mean      | 0.208    |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 401      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 374      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15       |
# |    ep_rew_mean      | 0.214    |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 444      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 420      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.1     |
# |    ep_rew_mean      | 0.188    |
# |    exploration_rate | 0.998    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 500      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 483      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.1     |
# |    ep_rew_mean      | 0.167    |
# |    exploration_rate | 0.998    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 554      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 545      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.9     |
# |    ep_rew_mean      | 0.15     |
# |    exploration_rate | 0.998    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 596      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 595      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.3     |
# |    ep_rew_mean      | 0.136    |
# |    exploration_rate | 0.998    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 625      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 631      |
# ----------------------------------
# /usr/local/lib/python3.9/site-packages/stable_baselines3/common/callbacks.py:345: UserWarning: Training and eval env are not of the same type<stable_baselines3.common.vec_env.vec_transpose.VecTransposeImage object at 0x7f183ebf4250> != <stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f1781f26b80>
#   warnings.warn("Training and eval env are not of the same type" f"{self.training_env} != {self.eval_env}")
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.5     |
# |    ep_rew_mean      | 0.167    |
# |    exploration_rate | 0.998    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 677      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 698      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14       |
# |    ep_rew_mean      | 0.154    |
# |    exploration_rate | 0.998    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 699      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 728      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.1     |
# |    ep_rew_mean      | 0.161    |
# |    exploration_rate | 0.998    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 744      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 789      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.9     |
# |    ep_rew_mean      | 0.15     |
# |    exploration_rate | 0.997    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 775      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 832      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.2     |
# |    ep_rew_mean      | 0.156    |
# |    exploration_rate | 0.997    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 832      |
# |    time_elapsed     | 1        |
# |    total_timesteps  |
|
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00138  |
# |    n_updates        | 19608    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.3     |
# |    ep_rew_mean      | 0.96     |
# |    exploration_rate | 0.593    |
# | time/               |          |
# |    episodes         | 8684     |
# |    fps              | 1070     |
# |    time_elapsed     | 120      |
# |    total_timesteps  | 128514   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000355 |
# |    n_updates        | 19628    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.1     |
# |    ep_rew_mean      | 0.95     |
# |    exploration_rate | 0.593    |
# | time/               |          |
# |    episodes         | 8688     |
# |    fps              | 1070     |
# |    time_elapsed     | 120      |
# |    total_timesteps  | 128559   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000635 |
# |    n_updates        | 19639    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17       |
# |    ep_rew_mean      | 0.96     |
# |    exploration_rate | 0.593    |
# | time/               |          |
# |    episodes         | 8692     |
# |    fps              | 1069     |
# |    time_elapsed     | 120      |
# |    total_timesteps  | 128628   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000605 |
# |    n_updates        | 19656    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17       |
# |    ep_rew_mean      | 0.98     |
# |    exploration_rate | 0.592    |
# | time/               |          |
# |    episodes         | 8696     |
# |    fps              | 1069     |
# |    time_elapsed     | 120      |
# |    total_timesteps  | 128707   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00062  |
# |    n_updates        | 19676    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.2     |
# |    ep_rew_mean      | 0.97     |
# |    exploration_rate | 0.592    |
# | time/               |          |
# |    episodes         | 8700     |
# |    fps              | 1069     |
# |    time_elapsed     | 120      |
# |    total_timesteps  | 128769   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000278 |
# |    n_updates        | 19692    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.1     |
# |    ep_rew_mean      | 0.96     |
# |    exploration_rate | 0.592    |
# | time/               |          |
# |    episodes         | 8704     |
# |    fps              | 1069     |
# |    time_elapsed     | 120      |
# |    total_timesteps  | 128833   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000697 |
# |    n_updates        | 19708    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.1     |
# |    ep_rew_mean      | 0.94     |
# |    exploration_rate | 0.592    |
# | time/               |          |
# |    episodes         | 8708     |
# |    fps              | 1068     |
# |    time_elapsed     | 120      |
# |    total_timesteps  | 128900   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000369 |
# |    n_updates        | 19724    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17       |
# |    ep_rew_mean      | 0.94     |
# |    exploration_rate | 0.592    |
# | time/               |          |
# |    episodes         | 8712     |
# |    fps              | 1068     |
# |    time_elapsed     | 120      |
# |    total_timesteps  | 128970   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000763 |
# |    n_updates        | 19742    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.4     |
# |    ep_rew_mean      | 0.96     |
# |    exploration_rate | 0.591    |
# | time/               |          |
# |    episodes         | 8716     |
# |    fps              | 1068     |
# |    time_elapsed     | 120      |
# |    total_timesteps  | 129049   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00063  |
# |    n_updates        | 19762    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17       |
# |    ep_rew_mean      | 0.91     |
# |    exploration_rate | 0.591    |
# | time/               |          |
# |    episodes         | 8720     |
# |    fps              | 1068     |
# |    time_elapsed     | 120      |
# |    total_timesteps  | 129094   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.001    |
# |    n_updates        | 19773    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.9     |
# |    ep_rew_mean      | 0.94     |
# |    exploration_rate | 0.591    |
# | time/               |          |
# |    episodes         | 8724     |
# |    fps              | 1067     |
# |    time_elapsed     | 120      |
# |    total_timesteps  | 129160   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000953 |
# |    n_updates        | 19789    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17       |
# |    ep_rew_mean      | 0.98     |
# |    exploration_rate | 0.591    |
# | time/               |          |
# |    episodes         | 8728     |
# |    fps              | 1067     |
# |    time_elapsed     | 121      |
# |    total_timesteps  | 129240   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000464 |
# |    n_updates        | 19809    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17       |
# |    ep_rew_mean      | 1        |
# |    exploration_rate | 0.59     |
# | time/               |          |
# |    episodes         | 8732     |
# |    fps              | 1067     |
# |    time_elapsed     | 121      |
# |    total_timesteps  | 129320   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0006   |
# |    n_updates        | 19829    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.1     |
# |    ep_rew_mean      | 1        |
# |    exploration_rate | 0.59     |
# | time/               |          |
# |    episodes         | 8736     |
# |    fps              | 1066     |
# |    time_elapsed     | 121      |
# |    total_timesteps  | 129400   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00052  |
# |    n_updates        | 19849    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.5     |
# |    ep_rew_mean      | 1.03     |
# |    exploration_rate | 0.59     |
# | time/               |          |
# |    episodes         | 8740     |
# |    fps              | 1066     |
# |    time_elapsed     | 121      |
# |    total_timesteps  | 129480   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000981 |
# |    n_updates        | 19869    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.4     |
# |    ep_rew_mean      | 1.04     |
# |    exploration_rate | 0.59     |
# | time/               |          |
# |    episodes         | 8744     |
# |    fps              | 1066     |
# |    time_elapsed     | 121      |
# |    total_timesteps  | 129551   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00108  |
# |    n_updates        | 19887    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.4     |
# |    ep_rew_mean      | 1.06     |
# |    exploration_rate | 0.59     |
# | time/               |          |
# |    episodes         | 8748     |
# |    fps              | 1066     |
# |    time_elapsed     | 121      |
# |    total_timesteps  | 129630   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000432 |
# |    n_updates        | 19907    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.4     |
# |    ep_rew_mean      | 1.04     |
# |    exploration_rate | 0.589    |
# | time/               |          |
# |    episodes         | 8752     |
# |    fps              | 1065     |
# |    time_elapsed     | 121      |
# |    total_timesteps  | 129710   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000238 |
# |    n_updates        | 19927    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.1     |
# |    ep_rew_mean      | 1.01     |
# |    exploration_rate | 0.589    |
# | time/               |          |
# |    episodes         | 8756     |
# |    fps              | 1065     |
# |    time_elapsed     | 121      |
# |    total_timesteps  | 129757   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000518 |
# |    n_updates        | 19939    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.2     |
# |    ep_rew_mean      | 1.07     |
# |    exploration_rate | 0.589    |
# | time/               |          |
# |    episodes         | 8760     |
# |    fps              | 1065     |
# |    time_elapsed     | 121      |
# |    total_timesteps  | 129836   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000272 |
# |    n_updates        | 19958    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.3     |
# |    ep_rew_mean      | 1.07     |
# |    exploration_rate | 0.589    |
# | time/               |          |
# |    episodes         | 8764     |
# |    fps              | 1065     |
# |    time_elapsed     | 121      |
# |    total_timesteps  | 129893   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00042  |
# |    n_updates        | 19973    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.4     |
# |    ep_rew_mean      | 1.08     |
# |    exploration_rate | 0.588    |
# | time/               |          |
# |    episodes         | 8768     |
# |    fps              | 1065     |
# |    time_elapsed     | 122      |
# |    total_timesteps  | 129973   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000464 |
# |    n_updates        | 19993    |
# ----------------------------------
# Eval num_timesteps=130000, episode_reward=3.00 +/- 0.00
# Episode length: 19.00 +/- 0.00
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 19       |
# |    mean_reward      | 3        |
# | rollout/            |          |
# |    exploration_rate | 0.588    |
# | time/               |          |
# |    total_timesteps  | 130000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000825 |
# |    n_updates        | 19999    |
# ----------------------------------
# New best mean reward!
# Stopping training because the mean reward 3.00  is above the threshold 3

# %%
model.load(DQN_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [17], in <cell line: 1>()
# ----> 1 model.load(DQN_path)
#
# File /usr/local/lib/python3.9/site-packages/stable_baselines3/common/base_class.py:704, in BaseAlgorithm.load(cls, path, env, device, custom_objects, print_system_info, force_reset, **kwargs)
#     701     print("== CURRENT SYSTEM INFO ==")
#     702     get_system_info()
# --> 704 data, params, pytorch_variables = load_from_zip_file(
#     705     path, device=device, custom_objects=custom_objects, print_system_info=print_system_info
#     706 )
#     708 # Remove stored device information and replace with ours
#     709 if "policy_kwargs" in data:
#
# File /usr/local/lib/python3.9/site-packages/stable_baselines3/common/save_util.py:388, in load_from_zip_file(load_path, load_data, custom_objects, device, verbose, print_system_info)
#     361 def load_from_zip_file(
#     362     load_path: Union[str, pathlib.Path, io.BufferedIOBase],
#     363     load_data: bool = True,
#    (...)
#     367     print_system_info: bool = False,
#     368 ) -> (Tuple[Optional[Dict[str, Any]], Optional[TensorDict], Optional[TensorDict]]):
#     369     """
#     370     Load model data from a .zip archive
#     371
#    (...)
#     386         and dict of pytorch variables
#     387     """
# --> 388     load_path = open_path(load_path, "r", verbose=verbose, suffix="zip")
#     390     # set device to cpu if cuda is not available
#     391     device = get_device(device=device)
#
# File /usr/local/lib/python3.9/functools.py:888, in singledispatch.<locals>.wrapper(*args, **kw)
#     884 if not args:
#     885     raise TypeError(f'{funcname} requires at least '
#     886                     '1 positional argument')
# --> 888 return dispatch(args[0].__class__)(*args, **kw)
#
# File /usr/local/lib/python3.9/site-packages/stable_baselines3/common/save_util.py:232, in open_path_str(path, mode, verbose, suffix)
#     217 @open_path.register(str)
#     218 def open_path_str(path: str, mode: str, verbose: int = 0, suffix: Optional[str] = None) -> io.BufferedIOBase:
#     219     """
#     220     Open a path given by a string. If writing to the path, the function ensures
#     221     that the path exists.
#    (...)
#     230     :return:
#     231     """
# --> 232     return open_path(pathlib.Path(path), mode, verbose, suffix)
#
# File /usr/local/lib/python3.9/functools.py:888, in singledispatch.<locals>.wrapper(*args, **kw)
#     884 if not args:
#     885     raise TypeError(f'{funcname} requires at least '
#     886                     '1 positional argument')
# --> 888 return dispatch(args[0].__class__)(*args, **kw)
#
# File /usr/local/lib/python3.9/site-packages/stable_baselines3/common/save_util.py:284, in open_path_pathlib(path, mode, verbose, suffix)
#     277         path.parent.mkdir(exist_ok=True, parents=True)
#     279 # if opening was successful uses the identity function
#     280 # if opening failed with IsADirectory|FileNotFound, calls open_path_pathlib
#     281 #   with corrections
#     282 # if reading failed with FileNotFoundError, calls open_path_pathlib with suffix
# --> 284 return open_path(path, mode, verbose, suffix)
#
# File /usr/local/lib/python3.9/functools.py:888, in singledispatch.<locals>.wrapper(*args, **kw)
#     884 if not args:
#     885     raise TypeError(f'{funcname} requires at least '
#     886                     '1 positional argument')
# --> 888 return dispatch(args[0].__class__)(*args, **kw)
#
# File /usr/local/lib/python3.9/site-packages/stable_baselines3/common/save_util.py:264, in open_path_pathlib(path, mode, verbose, suffix)
#     262             path, suffix = newpath, None
#     263         else:
# --> 264             raise error
#     265 else:
#     266     try:
#
# File /usr/local/lib/python3.9/site-packages/stable_baselines3/common/save_util.py:256, in open_path_pathlib(path, mode, verbose, suffix)
#     254 if mode == "r":
#     255     try:
# --> 256         path = path.open("rb")
#     257     except FileNotFoundError as error:
#     258         if suffix is not None and suffix != "":
#
# File /usr/local/lib/python3.9/pathlib.py:1252, in Path.open(self, mode, buffering, encoding, errors, newline)
#    1246 def open(self, mode='r', buffering=-1, encoding=None,
#    1247          errors=None, newline=None):
#    1248     """
#    1249     Open the file pointed by this path and return a file object, as
#    1250     the built-in open() function does.
#    1251     """
# -> 1252     return io.open(self, mode, buffering, encoding, errors, newline,
#    1253                    opener=self._opener)
#
# File /usr/local/lib/python3.9/pathlib.py:1120, in Path._opener(self, name, flags, mode)
#    1118 def _opener(self, name, flags, mode=0o666):
#    1119     # A stub for the opener argument to built-in open()
# -> 1120     return self._accessor.open(self, flags, mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Training/Saved Models/DQN_model_Gridworld_Plenty.zip'

# %%
evaluate_policy(model, env, n_eval_episodes=30, render=True)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Input In [40], in <cell line: 1>()
# ----> 1 evaluate_policy(model, env, n_eval_episodes=30, render=True)
#
# File /usr/local/lib/python3.9/site-packages/stable_baselines3/common/evaluation.py:86, in evaluate_policy(model, env, n_eval_episodes, deterministic, render, callback, reward_threshold, return_episode_rewards, warn)
#      84 episode_starts = np.ones((env.num_envs,), dtype=bool)
#      85 while (episode_counts < episode_count_targets).any():
# ---> 86     actions, states = model.predict(observations, state=states, episode_start=episode_starts, deterministic=deterministic)
#      87     observations, rewards, dones, infos = env.step(actions)
#      88     current_rewards += rewards
#
# File /usr/local/lib/python3.9/site-packages/stable_baselines3/dqn/dqn.py:248, in DQN.predict(self, observation, state, episode_start, deterministic)
#     246         action = np.array(self.action_space.sample())
#     247 else:
# --> 248     action, state = self.policy.predict(observation, state, episode_start, deterministic)
#     249 return action, state
#
# File /usr/local/lib/python3.9/site-packages/stable_baselines3/common/policies.py:335, in BasePolicy.predict(self, observation, state, episode_start, deterministic)
#     327 # TODO (GH/1): add support for RNN policies
#     328 # if state is None:
#     329 #     state = self.initial_state
#     330 # if episode_start is None:
#     331 #     episode_start = [False for _ in range(self.n_envs)]
#     332 # Switch to eval mode (this affects batch norm / dropout)
#     333 self.set_training_mode(False)
# --> 335 observation, vectorized_env = self.obs_to_tensor(observation)
#     337 with th.no_grad():
#     338     actions = self._predict(observation, deterministic=deterministic)
#
# File /usr/local/lib/python3.9/site-packages/stable_baselines3/common/policies.py:254, in BaseModel.obs_to_tensor(self, observation)
#     251     # Add batch dimension if needed
#     252     observation = observation.reshape((-1,) + self.observation_space.shape)
# --> 254 observation = obs_as_tensor(observation, self.device)
#     255 return observation, vectorized_env
#
# File /usr/local/lib/python3.9/site-packages/stable_baselines3/common/utils.py:451, in obs_as_tensor(obs, device)
#     443 """
#     444 Moves the observation to the given device.
#     445
#    (...)
#     448 :return: PyTorch tensor of the observation on a desired device.
#     449 """
#     450 if isinstance(obs, np.ndarray):
# --> 451     return th.as_tensor(obs).to(device)
#     452 elif isinstance(obs, dict):
#     453     return {key: th.as_tensor(_obs).to(device) for (key, _obs) in obs.items()}
#
# RuntimeError: CUDA error: unspecified launch failure
# CUDA kernel errors might be asynchronously reported at some other API call,so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.

# %%
env.close()
