# %%
from sys import path as syspath
from os import path as ospath
syspath.append(ospath.join(ospath.expanduser("~"), '/data/hashemi/Freetime/Freetime-DQN/Deep-Freetime/SB3_f'))

# %%
import torch as torch
torch._C._cuda_getDeviceCount() > 0
# Out:
# True

# %%
import os
import gym 
import matplotlib.pyplot as plt
import numpy as np 
from SB3_f.sb3f import DQN
from SB3_f.sb3f.common.vec_env import DummyVecEnv
from SB3_f.sb3f.common.evaluation import evaluate_policy
from SB3_f.sb3f.common.callbacks import EvalCallback, StopTrainingOnRewardThreshold

# %%
rewards = [[2,0,10],[1,0,0]]
from GridEnv import WindyGridworld
env = WindyGridworld(
        height=20,
        width=11,
        rewards=rewards,
        wind=True,
        allowed_actions=['L', 'R', 'C'],
        reward_terminates_episode=False
    )

# %%
episodes = 5
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0 
    
    while not done:
        env.render()
        action = env.action_space.sample()
        n_state, reward, done, info = env.step(action)
        score+=reward
    print('Episode:{} Score:{}'.format(episode, score))
env.close()
# Out:
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
#
# QObject::moveToThread: Current thread (0x5558f07ea8b0) is not the object's thread (0x5558f0b36000).
# Cannot move to target thread (0x5558f07ea8b0)
# Episode:1 Score:0
# Episode:2 Score:0
# Episode:3 Score:0
# Episode:4 Score:0
# Episode:5 Score:1

# %%
save_path = os.path.join('Training', 'Saved Models')
log_path = os.path.join('Training', 'Logs Bias Only', 'Env 3')

# %%
stop_callback = StopTrainingOnRewardThreshold(reward_threshold=2, verbose=1)
eval_callback = EvalCallback(env, 
                             callback_on_new_best=stop_callback, 
                             eval_freq=10000, 
                             best_model_save_path=save_path, 
                             verbose=1)

# %%
# Using same prams that performed optimally in Baseline
model = DQN('CnnPolicy', env, exploration_fraction=0.4,
    exploration_final_eps=0.1,learning_starts=100000,
    verbose = 1, 
    buffer_size = 50000,
    target_update_interval=1000,
    tensorboard_log=log_path)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.

# %%
from SB3_f.sb3f.common.utils import obs_as_tensor
device = torch.device('cuda:0')

obs = env.canvas
plt.imshow(obs)


# Check the Network Q Value
observation = np.transpose(obs, (2, 0, 1))
observation = observation[np.newaxis, ...]
observation = obs_as_tensor(observation, device)
with torch.no_grad():
        q_values = model.q_net(observation)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
q_values
# Out:
# tensor([[1.0759, 1.0759, 1.0748]], device='cuda:0')

# %%
model.learn(total_timesteps=2000000,callback=eval_callback, tb_log_name='Env3_0.2exp_50kbuffer')
# Out:
# Logging to Training/Logs Abs Weight/Env1/Env1_0.2exp_50kbuffer_5
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.8     |
# |    ep_rew_mean      | 0.25     |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 2903     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 59       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.9     |
# |    ep_rew_mean      | 0.25     |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 3083     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 103      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.8     |
# |    ep_rew_mean      | 0.167    |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 3203     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 165      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.1     |
# |    ep_rew_mean      | 0.125    |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 3225     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 209      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.9     |
# |    ep_rew_mean      | 0.15     |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 3289     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 278      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.2     |
# |    ep_rew_mean      | 0.125    |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 3290     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 342      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.5     |
# |    ep_rew_mean      | 0.143    |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 3311     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 407      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.6     |
# |    ep_rew_mean      | 0.125    |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 3332     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 468      |
# ----------------------------------
# /data/hashemi/Freetime/Freetime-DQN/Deep-Freetime/SB3_f/sb3f/common/callbacks.py:388: UserWarning: Training and eval env are not of the same type<sb3f.common.vec_env.vec_transpose.VecTransposeImage object at 0x7fcfa169f430> != <sb3f.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7fcfa169f370>
#   warnings.warn("Training and eval env are not of the same type" f"{self.training_env} != {self.eval_env}")
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.1     |
# |    ep_rew_mean      | 0.111    |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 3317     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 507      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.7     |
# |    ep_rew_mean      | 0.1      |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 3315     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 549      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.1     |
# |    ep_rew_mean      | 0.0909   |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 3339     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 621      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.5     |
# |    ep_rew_mean      | 0.0833   |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 3350     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 697      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.8     |
# |    ep_rew_mean      | 0.0769   |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 3336     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 717      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.9     |
# |    ep_rew_mean      | 0.107    |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 3349     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 779      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.7     |
# |    ep_rew_mean      | 0.1      |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 3343     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 823      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.9     |
# |    ep_rew_mean      | 0.109    |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 3347     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 888      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14       |
# |    ep_rew_mean      | 0.103    |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 3354     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 954      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14       |
# |    ep_rew_mean      | 0.0972   |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 3348     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1006     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.2     |
# |    ep_rew_mean      | 0.0921   |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 3359     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1079     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.1     |
# |    ep_rew_mean      | 0.1      |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 3360     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1127     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.6     |
# |    ep_rew_mean      | 0.0952   |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 3351     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1144     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.9     |
# |    ep_rew_mean      | 0.102    |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 3362     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1223     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14       |
# |    ep_rew_mean      | 0.0978   |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 3368     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1288     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14       |
# |    ep_rew_mean      | 0.0938   |
# |    exploration_rate | 0.998    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 3372     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1344     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14       |
# |    ep_rew_mean      | 0.09     |
# |    exploration_rate | 0.998    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 3368     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1398     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.2     |
# |    ep_rew_mean      | 0.08     |
# |    exploration_rate | 0.998    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 3375     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1478     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.5     |
# |    ep_rew_mean      | 0.09     |
# |    exploration_rate | 0.998    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 3381     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1550     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.5     |
# |    ep_rew_mean      | 0.1      |
# |    exploration_rate | 0.998    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 3382     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1612     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.7     |
# |    ep_rew_mean      | 0.1      |
# |    exploration_rate | 0.998    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 3386     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1678     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.3     |
# |    ep_rew_mean      | 0.09     |
# |    exploration_rate | 0.998    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 3381     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1705     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.2     |
# |    ep_rew_mean      | 0.09     |
# |    exploration_rate | 0.998    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 3381     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1757     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14       |
# |    ep_rew_mean      | 0.08     |
# |    exploration_rate | 0.998    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 3382     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1806     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.6     |
# |    ep_rew_mean      | 0.08     |
# |    exploration_rate | 0.998    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 3378     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1832     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.7     |
# |    ep_rew_mean      | 0.08     |
# |    exploration_rate | 0.998    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 3377     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1878     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.7     |
# |    ep_rew_mean      | 0.08     |
# |    exploration_rate | 0.998    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 3374     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1914     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.6     |
# |    ep_rew_mean      | 0.08     |
# |    exploration_rate | 0.998    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 3379     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1977     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.3     |
# |    ep_rew_mean      | 0.08     |
# |    exploration_rate | 0.998    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 3374     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2025     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.7     |
# |    ep_rew_mean      | 0.08     |
# |    exploration_rate | 0.998    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 3375     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2087     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.7     |
# |    ep_rew_mean      | 0.08     |
# |    exploration_rate | 0.998    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 3378     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2149     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.9     |
# |    ep_rew_mean      | 0.09     |
# |    exploration_rate | 0.998    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 3383     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2218     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.9     |
# |    ep_rew_mean      | 0.08     |
# |    exploration_rate | 0.997    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 3387     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2281     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.8     |
# |    ep_rew_mean      | 0.08     |
# |    exploration_rate | 0.997    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 3389     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2335     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.1     |
# |    ep_rew_mean      | 0.08     |
# |    exploration_rate | 0.997    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 3395     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2415     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.1     |
# |    ep_rew_mean      | 0.08     |
# |    exploration_rate | 0.997    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 3400     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2492     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.3     |
# |    ep_rew_mean      | 0.07     |
# |    exploration_rate | 0.997    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 3404     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2562     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.9     |
# |    ep_rew_mean      | 0.07     |
# |    exploration_rate | 0.997    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 3408     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2634     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.9     |
# |    ep_rew_mean      | 0.06     |
# |    exploration_rate | 0.997    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 3412     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2709     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.6     |
# |    ep_rew_mean      | 0.06     |
# |    exploration_rate | 0.997    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 3411     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2748     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.7     |
# |    ep_rew_mean      | 0.06     |
# |    exploration_rate | 0.997    |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 3413     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2809     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.7     |
# |    ep_rew_mean      | 0.07     |
# |    exploration_rate | 0.997    |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 3416     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2870     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.7     |
# |    ep_rew_mean      | 0.07     |
# |    exploration_rate | 0.997    |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 3420     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2950     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.4     |
# |    ep_rew_mean      | 0.05     |
# |    exploration_rate | 0.997    |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 3419     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2989     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.3     |
# |    ep_rew_mean      | 0.04     |
# |    exploration_rate | 0.997    |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 3415     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3040     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.1     |
# |    ep_rew_mean      | 0.05     |
# |    exploration_rate | 0.997    |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 3414     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3086     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.2     |
# |    ep_rew_mean      | 0.05     |
# |    exploration_rate | 0.996    |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 3412     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3126     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.2     |
# |    ep_rew_mean      | 0.05     |
# |    exploration_rate | 0.996    |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 3407     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3181     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.2     |
# |    ep_rew_mean      | 0.06     |
# |    exploration_rate | 0.996    |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 3406     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3224     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.7     |
# |    ep_rew_mean      | 0.07     |
# |    exploration_rate | 0.996    |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 3410     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3303     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.8     |
# |    ep_rew_mean      | 0.07     |
# |    exploration_rate | 0.996    |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 3405     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3356     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.8     |
# |    ep_rew_mean      | 0.07     |
# |    exploration_rate | 0.996    |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 3404     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3399     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.9     |
# |    ep_rew_mean      | 0.07     |
# |    exploration_rate | 0.996    |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 3402     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3463     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15       |
# |    ep_rew_mean      | 0.07     |
# |    exploration_rate | 0.996    |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 3398     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3528     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15       |
# |    ep_rew_mean      | 0.07     |
# |    exploration_rate | 0.996    |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 3390     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3590     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.1     |
# |    ep_rew_mean      | 0.05     |
# |    exploration_rate | 0.996    |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 3391     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3655     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15       |
# |    ep_rew_mean      | 0.05     |
# |    exploration_rate | 0.996    |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 3392     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3718     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.7     |
# |    ep_rew_mean      | 0.05     |
# |    exploration_rate | 0.996    |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 3391     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3753     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15       |
# |    ep_rew_mean      | 0.06     |
# |    exploration_rate | 0.996    |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 3395     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3832     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.9     |
# |    ep_rew_mean      | 0.07     |
# |    exploration_rate | 0.996    |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 3397     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3902     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.7     |
# |    ep_rew_mean      | 0.07     |
# |    exploration_rate | 0.996    |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 3398     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3961     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.7     |
# |    ep_rew_mean      | 0.07     |
# |    exploration_rate | 0.995    |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 3398     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4034     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.6     |
# |    ep_rew_mean      | 0.07     |
# |    exploration_rate | 0.995    |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 3399     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4094     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.7     |
# |    ep_rew_mean      | 0.07     |
# |    exploration_rate | 0.995    |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 3402     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4174     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.8     |
# |    ep_rew_mean      | 0.07     |
# |    exploration_rate | 0.995    |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 3402     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4228     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.8     |
# |    ep_rew_mean      | 0.07     |
# |    exploration_rate | 0.995    |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 3402     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4290     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15       |
# |    ep_rew_mean      | 0.06     |
# |    exploration_rate | 0.995    |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 3404     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4367     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.9     |
# |    ep_rew_mean      | 0.06     |
# |    exploration_rate | 0.995    |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 3405     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4445     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.1     |
# |    ep_rew_mean      | 0.06     |
# |    exploration_rate | 0.995    |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 3405     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4497     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.8     |
# |    ep_rew_mean      | 0.06     |
# |    exploration_rate | 0.995    |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 3403     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4521     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15       |
# |    ep_rew_mean      | 0.05     |
# |    exploration_rate | 0.995    |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 3403     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4585     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.1     |
# |    ep_rew_mean      | 0.05     |
# |    exploration_rate | 0.995    |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 3403     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4636     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.2     |
# |    ep_rew_mean      | 0.05     |
# |    exploration_rate | 0.995    |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 3403     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4698     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.3     |
# |    ep_rew_mean      | 0.04     |
# |    exploration_rate | 0.995    |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 3402     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4751     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15       |
# |    ep_rew_mean      | 0.03     |
# |    exploration_rate | 0.995    |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 3401     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4802     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.1     |
# |    ep_rew_mean      | 0.03     |
# |    exploration_rate | 0.995    |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 3402     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4866     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.4     |
# |    ep_rew_mean      | 0.03     |
# |    exploration_rate | 0.994    |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 3404     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4939     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.2     |
# |    ep_rew_mean      | 0.03     |
# |    exploration_rate | 0.994    |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 3403     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4986     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.1     |
# |    ep_rew_mean      | 0.04     |
# |    exploration_rate | 0.994    |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 3402     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5037     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.8     |
# |    ep_rew_mean      | 0.04     |
# |    exploration_rate | 0.994    |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 3399     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5065     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.5     |
# |    ep_rew_mean      | 0.04     |
# |    exploration_rate | 0.994    |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 3399     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5109     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.5     |
# |    ep_rew_mean      | 0.03     |
# |    exploration_rate | 0.994    |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 3400     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5172     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.7     |
# |    ep_rew_mean      | 0.04     |
# |    exploration_rate | 0.994    |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 3400     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5218     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.3     |
# |    ep_rew_mean      | 0.04     |
# |    exploration_rate | 0.994    |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 3399     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5267     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.1     |
# |    ep_rew_mean      | 0.03     |
# |    exploration_rate | 0.994    |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 3399     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5313     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.3     |
# |    ep_rew_mean      | 0.03     |
# |    exploration_rate | 0.994    |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 3401     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5393     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.4     |
# |    ep_rew_mean      | 0.05     |
# |    exploration_rate | 0.994    |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 3403     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5471     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.2     |
# |    ep_rew_mean      | 0.05     |
# |    exploration_rate | 0.994    |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 3402     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5510     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.1     |
# |    ep_rew_mean      | 0.08     |
# |    exploration_rate | 0.994    |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 3404     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5587     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.2     |
# |    ep_rew_mean      | 0.09     |
# |    exploration_rate | 0.994    |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 3403     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5645     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.1     |
# |    ep_rew_mean      | 0.09     |
# |    exploration_rate | 0.994    |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 3403     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5699     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.9     |
# |    ep_rew_mean      | 0.09     |
# |    exploration_rate | 0.994    |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 3404     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5760     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.6     |
# |    ep_rew_mean      | 0.1      |
# |    exploration_rate | 0.993    |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 3398     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5804     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.5     |
# |    ep_rew_mean      | 0.1      |
# |    exploration_rate | 0.993    |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 3396     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5849     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.8     |
# |    ep_rew_mean      | 0.1      |
# |    exploration_rate | 0.993    |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 3395     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5906     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.9     |
# |    ep_rew_mean      | 0.11     |
# |    exploration_rate | 0.993    |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 3394     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5971     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.9     |
# |    ep_rew_mean      | 0.12     |
# |    exploration_rate | 0.993    |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 3391     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6026     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.1     |
# |    ep_rew_mean      | 0.13     |
# |    exploration_rate | 0.993    |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 3390     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6105     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14       |
# |    ep_rew_mean      | 0.13     |
# |    exploration_rate | 0.993    |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 3388     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6152     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.9     |
# |    ep_rew_mean      | 0.13     |
# |    exploration_rate | 0.993    |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 3386     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6193     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.9     |
# |    ep_rew_mean      | 0.15     |
# |    exploration_rate | 0.993    |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 3386     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6259     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.9     |
# |    ep_rew_mean      | 0.16     |
# |    exploration_rate | 0.993    |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 3385     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6332     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.3     |
# |    ep_rew_mean      | 0.16     |
# |    exploration_rate | 0.993    |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 3383     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6412     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.3     |
# |    ep_rew_mean      | 0.15     |
# |    exploration_rate | 0.993    |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 3382     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6469     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.8     |
# |    ep_rew_mean      | 0.15     |
# |    exploration_rate | 0.993    |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 3383     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6549     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.1     |
# |    ep_rew_mean      | 0.15     |
# |    exploration_rate | 0.993    |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 3383     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6623     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.1     |
# |    ep_rew_mean      | 0.15     |
# |    exploration_rate | 0.992    |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 3383     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6684     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.3     |
# |    ep_rew_mean      | 0.14     |
# |    exploration_rate | 0.992    |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 3382     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6745     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.4     |
# |    ep_rew_mean      | 0.14     |
# |    exploration_rate | 0.992    |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 3377     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 6806     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.6     |
# |    ep_rew_mean      | 0.15     |
# |    exploration_rate | 0.992    |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 3376     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 6873     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.3     |
# |    ep_rew_mean      | 0.15     |
# |    exploration_rate | 0.992    |
# | time/               |          |
# |    episodes         | 476      |
# |    fps              | 3374     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 6922     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.3     |
# |    ep_rew_mean      | 0.14     |
# |    exploration_rate | 0.992    |
# | time/               |          |
# |    episodes         | 480      |
# |    fps              | 3372     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 7001     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.5     |
# |    ep_rew_mean      | 0.14     |
# |    exploration_rate | 0.992    |
# | time/               |          |
# |    episodes         | 484      |
# |    fps              | 3372     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 7062     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.3     |
# |    ep_rew_mean      | 0.11     |
# |    exploration_rate | 0.992    |
# | time/               |          |
# |    episodes         | 488      |
# |    fps              | 3371     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 7118     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.5     |
# |    ep_rew_mean      | 0.1      |
# |    exploration_rate | 0.992    |
# | time/               |          |
# |    episodes         | 492      |
# |    fps              | 3373     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 7198     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.4     |
# |    ep_rew_mean      | 0.1      |
# ...
# |    loss             | 0.00153  |
# |    n_updates        | 56971    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.1     |
# |    ep_rew_mean      | 0.39     |
# |    exploration_rate | 0.631    |
# | time/               |          |
# |    episodes         | 22372    |
# |    fps              | 1030     |
# |    time_elapsed     | 318      |
# |    total_timesteps  | 327964   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00079  |
# |    n_updates        | 56990    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18       |
# |    ep_rew_mean      | 0.39     |
# |    exploration_rate | 0.631    |
# | time/               |          |
# |    episodes         | 22376    |
# |    fps              | 1030     |
# |    time_elapsed     | 318      |
# |    total_timesteps  | 328028   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00187  |
# |    n_updates        | 57006    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18       |
# |    ep_rew_mean      | 0.4      |
# |    exploration_rate | 0.631    |
# | time/               |          |
# |    episodes         | 22380    |
# |    fps              | 1030     |
# |    time_elapsed     | 318      |
# |    total_timesteps  | 328106   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00351  |
# |    n_updates        | 57026    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.8     |
# |    ep_rew_mean      | 0.41     |
# |    exploration_rate | 0.631    |
# | time/               |          |
# |    episodes         | 22384    |
# |    fps              | 1030     |
# |    time_elapsed     | 318      |
# |    total_timesteps  | 328165   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00225  |
# |    n_updates        | 57041    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.7     |
# |    ep_rew_mean      | 0.41     |
# |    exploration_rate | 0.631    |
# | time/               |          |
# |    episodes         | 22388    |
# |    fps              | 1030     |
# |    time_elapsed     | 318      |
# |    total_timesteps  | 328224   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00542  |
# |    n_updates        | 57055    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.7     |
# |    ep_rew_mean      | 0.4      |
# |    exploration_rate | 0.631    |
# | time/               |          |
# |    episodes         | 22392    |
# |    fps              | 1030     |
# |    time_elapsed     | 318      |
# |    total_timesteps  | 328304   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00158  |
# |    n_updates        | 57075    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.8     |
# |    ep_rew_mean      | 0.41     |
# |    exploration_rate | 0.631    |
# | time/               |          |
# |    episodes         | 22396    |
# |    fps              | 1030     |
# |    time_elapsed     | 318      |
# |    total_timesteps  | 328362   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00204  |
# |    n_updates        | 57090    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18       |
# |    ep_rew_mean      | 0.4      |
# |    exploration_rate | 0.631    |
# | time/               |          |
# |    episodes         | 22400    |
# |    fps              | 1029     |
# |    time_elapsed     | 318      |
# |    total_timesteps  | 328440   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00224  |
# |    n_updates        | 57109    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18       |
# |    ep_rew_mean      | 0.4      |
# |    exploration_rate | 0.63     |
# | time/               |          |
# |    episodes         | 22404    |
# |    fps              | 1029     |
# |    time_elapsed     | 319      |
# |    total_timesteps  | 328519   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00207  |
# |    n_updates        | 57129    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18       |
# |    ep_rew_mean      | 0.42     |
# |    exploration_rate | 0.63     |
# | time/               |          |
# |    episodes         | 22408    |
# |    fps              | 1029     |
# |    time_elapsed     | 319      |
# |    total_timesteps  | 328597   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00502  |
# |    n_updates        | 57149    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.3     |
# |    ep_rew_mean      | 0.44     |
# |    exploration_rate | 0.63     |
# | time/               |          |
# |    episodes         | 22412    |
# |    fps              | 1029     |
# |    time_elapsed     | 319      |
# |    total_timesteps  | 328674   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00276  |
# |    n_updates        | 57168    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.3     |
# |    ep_rew_mean      | 0.44     |
# |    exploration_rate | 0.63     |
# | time/               |          |
# |    episodes         | 22416    |
# |    fps              | 1029     |
# |    time_elapsed     | 319      |
# |    total_timesteps  | 328741   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00256  |
# |    n_updates        | 57185    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.2     |
# |    ep_rew_mean      | 0.45     |
# |    exploration_rate | 0.63     |
# | time/               |          |
# |    episodes         | 22420    |
# |    fps              | 1029     |
# |    time_elapsed     | 319      |
# |    total_timesteps  | 328806   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00156  |
# |    n_updates        | 57201    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.3     |
# |    ep_rew_mean      | 0.46     |
# |    exploration_rate | 0.63     |
# | time/               |          |
# |    episodes         | 22424    |
# |    fps              | 1029     |
# |    time_elapsed     | 319      |
# |    total_timesteps  | 328884   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00324  |
# |    n_updates        | 57220    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.4     |
# |    ep_rew_mean      | 0.47     |
# |    exploration_rate | 0.63     |
# | time/               |          |
# |    episodes         | 22428    |
# |    fps              | 1029     |
# |    time_elapsed     | 319      |
# |    total_timesteps  | 328962   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00127  |
# |    n_updates        | 57240    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.3     |
# |    ep_rew_mean      | 0.47     |
# |    exploration_rate | 0.63     |
# | time/               |          |
# |    episodes         | 22432    |
# |    fps              | 1029     |
# |    time_elapsed     | 319      |
# |    total_timesteps  | 329027   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00289  |
# |    n_updates        | 57256    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.1     |
# |    ep_rew_mean      | 0.46     |
# |    exploration_rate | 0.63     |
# | time/               |          |
# |    episodes         | 22436    |
# |    fps              | 1029     |
# |    time_elapsed     | 319      |
# |    total_timesteps  | 329087   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00489  |
# |    n_updates        | 57271    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.9     |
# |    ep_rew_mean      | 0.45     |
# |    exploration_rate | 0.63     |
# | time/               |          |
# |    episodes         | 22440    |
# |    fps              | 1029     |
# |    time_elapsed     | 319      |
# |    total_timesteps  | 329146   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0038   |
# |    n_updates        | 57286    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.7     |
# |    ep_rew_mean      | 0.46     |
# |    exploration_rate | 0.63     |
# | time/               |          |
# |    episodes         | 22444    |
# |    fps              | 1029     |
# |    time_elapsed     | 319      |
# |    total_timesteps  | 329204   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.003    |
# |    n_updates        | 57300    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.8     |
# |    ep_rew_mean      | 0.42     |
# |    exploration_rate | 0.63     |
# | time/               |          |
# |    episodes         | 22448    |
# |    fps              | 1028     |
# |    time_elapsed     | 320      |
# |    total_timesteps  | 329284   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00357  |
# |    n_updates        | 57320    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.8     |
# |    ep_rew_mean      | 0.43     |
# |    exploration_rate | 0.629    |
# | time/               |          |
# |    episodes         | 22452    |
# |    fps              | 1028     |
# |    time_elapsed     | 320      |
# |    total_timesteps  | 329362   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00348  |
# |    n_updates        | 57340    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.7     |
# |    ep_rew_mean      | 0.44     |
# |    exploration_rate | 0.629    |
# | time/               |          |
# |    episodes         | 22456    |
# |    fps              | 1028     |
# |    time_elapsed     | 320      |
# |    total_timesteps  | 329441   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00619  |
# |    n_updates        | 57360    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.7     |
# |    ep_rew_mean      | 0.45     |
# |    exploration_rate | 0.629    |
# | time/               |          |
# |    episodes         | 22460    |
# |    fps              | 1028     |
# |    time_elapsed     | 320      |
# |    total_timesteps  | 329518   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00251  |
# |    n_updates        | 57379    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.9     |
# |    ep_rew_mean      | 0.47     |
# |    exploration_rate | 0.629    |
# | time/               |          |
# |    episodes         | 22464    |
# |    fps              | 1028     |
# |    time_elapsed     | 320      |
# |    total_timesteps  | 329596   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0048   |
# |    n_updates        | 57398    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.7     |
# |    ep_rew_mean      | 0.46     |
# |    exploration_rate | 0.629    |
# | time/               |          |
# |    episodes         | 22468    |
# |    fps              | 1028     |
# |    time_elapsed     | 320      |
# |    total_timesteps  | 329659   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00404  |
# |    n_updates        | 57414    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.7     |
# |    ep_rew_mean      | 0.45     |
# |    exploration_rate | 0.629    |
# | time/               |          |
# |    episodes         | 22472    |
# |    fps              | 1028     |
# |    time_elapsed     | 320      |
# |    total_timesteps  | 329734   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.002    |
# |    n_updates        | 57433    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.9     |
# |    ep_rew_mean      | 0.43     |
# |    exploration_rate | 0.629    |
# | time/               |          |
# |    episodes         | 22476    |
# |    fps              | 1028     |
# |    time_elapsed     | 320      |
# |    total_timesteps  | 329814   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00135  |
# |    n_updates        | 57453    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.6     |
# |    ep_rew_mean      | 0.43     |
# |    exploration_rate | 0.629    |
# | time/               |          |
# |    episodes         | 22480    |
# |    fps              | 1028     |
# |    time_elapsed     | 320      |
# |    total_timesteps  | 329865   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0012   |
# |    n_updates        | 57466    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.8     |
# |    ep_rew_mean      | 0.44     |
# |    exploration_rate | 0.629    |
# | time/               |          |
# |    episodes         | 22484    |
# |    fps              | 1028     |
# |    time_elapsed     | 320      |
# |    total_timesteps  | 329942   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00347  |
# |    n_updates        | 57485    |
# ----------------------------------
# Eval num_timesteps=330000, episode_reward=1.00 +/- 0.00
# Episode length: 19.00 +/- 0.00
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 19       |
# |    mean_reward      | 1        |
# | rollout/            |          |
# |    exploration_rate | 0.629    |
# | time/               |          |
# |    total_timesteps  | 330000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00196  |
# |    n_updates        | 57499    |
# ----------------------------------
# New best mean reward!
# Stopping training because the mean reward 1.00  is above the threshold 1
