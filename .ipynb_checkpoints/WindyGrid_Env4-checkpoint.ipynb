# %%
# https://stable-baselines3.readthedocs.io/en/master/guide/rl.html
# https://spinningup.openai.com/en/latest/spinningup/rl_intro2.html#a-taxonomy-of-rl-algorithms

# %% [markdown]
# # 1. Import dependencies

# %%
import torch as torch
torch._C._cuda_getDeviceCount() > 0
# Out:
# True

# %%
import os
import gym 
from stable_baselines3 import DQN
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy

# %% [markdown]
# # 2. Load and Test Environment

# %%
#environment_name = "Pong-v0"
#rewards = [[1,0,5], [1,10,4], [1,4,6]]
#rewards = [[1,0,8], [1,10,3]]
#rewards = [[1,7,5],[1,0,4]]
rewards = [[1,10,5]]

# %%
#env = gym.make(environment_name)
from GridEnv import WindyGridworld
env = WindyGridworld(
        height=20,
        width=11,
        rewards=rewards,
        wind=False,
        allowed_actions=['L', 'R', 'U', 'D', 'UL', 'UR', 'DL', 'DR'],
        reward_terminates_episode=True
    )

# %%
episodes = 5
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0 
    
    while not done:
        env.render()
        action = env.action_space.sample()
        n_state, reward, done, info = env.step(action)
        score+=reward
    print('Episode:{} Score:{}'.format(episode, score))
env.close()
# Out:
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
#
# QObject::moveToThread: Current thread (0x5576eb5c05e0) is not the object's thread (0x5576ebccce90).
# Cannot move to target thread (0x5576eb5c05e0)
# Episode:1 Score:0
# Episode:2 Score:0
# Episode:3 Score:0
# Episode:4 Score:0
# Episode:5 Score:0

# %% [markdown]
# # 3. Train an RL Model

# %%
from stable_baselines3.common.evaluation import evaluate_policy

# %%
log_path = os.path.join('Training','Logs')

# %%
from stable_baselines3.common.callbacks import EvalCallback, StopTrainingOnRewardThreshold

# %%
save_path = os.path.join('Training', 'Saved Models')
log_path = os.path.join('Training', 'Logs')

# %%
from GridEnv import WindyGridworld
env = WindyGridworld(
        height=20,
        width=11,
        rewards=rewards,
        wind=False,
        allowed_actions=['L', 'R', 'U', 'D', 'UL', 'UR', 'DL', 'DR'],
        reward_terminates_episode=True
    )

# %%
stop_callback = StopTrainingOnRewardThreshold(reward_threshold=2, verbose=1)
eval_callback = EvalCallback(env, 
                             callback_on_new_best=stop_callback, 
                             eval_freq=10000, 
                             best_model_save_path=save_path, 
                             verbose=1)

# %%
# try 0.2 exploration period
model = DQN('CnnPolicy', env, exploration_fraction=0.2,
  exploration_final_eps=0.1,learning_starts=100000, verbose = 1, buffer_size = 50000,target_update_interval=1000, tensorboard_log=log_path)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.

# %%
model.learn(total_timesteps=1000000,callback=eval_callback, tb_log_name='Env4_Full_1M')
# Out:
# Logging to Training/Logs/Env4_Full_1M_4
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14       |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 2796     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 56       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.88     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 2639     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 63       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.83     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 2582     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 82       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.44     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 2903     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 151      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.1     |
# |    ep_rew_mean      | 0.05     |
# |    exploration_rate | 0.998    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 2829     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 242      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11       |
# |    ep_rew_mean      | 0.0417   |
# |    exploration_rate | 0.998    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 2825     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 263      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 0.0357   |
# |    exploration_rate | 0.998    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 2847     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 290      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.5      |
# |    ep_rew_mean      | 0.0312   |
# |    exploration_rate | 0.998    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 2839     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 304      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.69     |
# |    ep_rew_mean      | 0.0278   |
# |    exploration_rate | 0.997    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 2819     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 313      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.95     |
# |    ep_rew_mean      | 0.025    |
# |    exploration_rate | 0.997    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 2792     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 318      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.66     |
# |    ep_rew_mean      | 0.0227   |
# |    exploration_rate | 0.997    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 2787     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 337      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.88     |
# |    ep_rew_mean      | 0.0208   |
# |    exploration_rate | 0.997    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 2836     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 378      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.38     |
# |    ep_rew_mean      | 0.0192   |
# |    exploration_rate | 0.997    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 2816     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 384      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.96     |
# |    ep_rew_mean      | 0.0179   |
# |    exploration_rate | 0.997    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 2795     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 390      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.03     |
# |    ep_rew_mean      | 0.0167   |
# |    exploration_rate | 0.997    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 2826     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 422      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.89     |
# |    ep_rew_mean      | 0.0156   |
# |    exploration_rate | 0.996    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 2830     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 441      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.88     |
# |    ep_rew_mean      | 0.0147   |
# |    exploration_rate | 0.996    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 2842     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 468      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.67     |
# |    ep_rew_mean      | 0.0139   |
# |    exploration_rate | 0.996    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 2932     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 552      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.32     |
# |    ep_rew_mean      | 0.0132   |
# |    exploration_rate | 0.996    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 2915     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 556      |
# ----------------------------------
# /usr/local/lib/python3.9/site-packages/stable_baselines3/common/callbacks.py:345: UserWarning: Training and eval env are not of the same type<stable_baselines3.common.vec_env.vec_transpose.VecTransposeImage object at 0x7f1907392850> != <stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f1930758250>
#   warnings.warn("Training and eval env are not of the same type" f"{self.training_env} != {self.eval_env}")
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.91     |
# |    ep_rew_mean      | 0.0125   |
# |    exploration_rate | 0.995    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 2972     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 633      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.77     |
# |    ep_rew_mean      | 0.0119   |
# |    exploration_rate | 0.995    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 2967     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 653      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.7      |
# |    ep_rew_mean      | 0.0114   |
# |    exploration_rate | 0.995    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 2968     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 678      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.43     |
# |    ep_rew_mean      | 0.0109   |
# |    exploration_rate | 0.995    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 2954     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 684      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7
|
# |    exploration_rate | 0.2      |
# | time/               |          |
# |    episodes         | 23336    |
# |    fps              | 1006     |
# |    time_elapsed     | 217      |
# |    total_timesteps  | 218672   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00358  |
# |    n_updates        | 29667    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.53     |
# |    ep_rew_mean      | 0.57     |
# |    exploration_rate | 0.2      |
# | time/               |          |
# |    episodes         | 23340    |
# |    fps              | 1006     |
# |    time_elapsed     | 217      |
# |    total_timesteps  | 218753   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00961  |
# |    n_updates        | 29688    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.11     |
# |    ep_rew_mean      | 0.59     |
# |    exploration_rate | 0.2      |
# | time/               |          |
# |    episodes         | 23344    |
# |    fps              | 1006     |
# |    time_elapsed     | 217      |
# |    total_timesteps  | 218837   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00924  |
# |    n_updates        | 29709    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.14     |
# |    ep_rew_mean      | 0.61     |
# |    exploration_rate | 0.2      |
# | time/               |          |
# |    episodes         | 23348    |
# |    fps              | 1006     |
# |    time_elapsed     | 217      |
# |    total_timesteps  | 218874   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0138   |
# |    n_updates        | 29718    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.39     |
# |    ep_rew_mean      | 0.63     |
# |    exploration_rate | 0.2      |
# | time/               |          |
# |    episodes         | 23352    |
# |    fps              | 1006     |
# |    time_elapsed     | 217      |
# |    total_timesteps  | 218911   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0143   |
# |    n_updates        | 29727    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.33     |
# |    ep_rew_mean      | 0.62     |
# |    exploration_rate | 0.2      |
# | time/               |          |
# |    episodes         | 23356    |
# |    fps              | 1006     |
# |    time_elapsed     | 217      |
# |    total_timesteps  | 218927   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00677  |
# |    n_updates        | 29731    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.76     |
# |    ep_rew_mean      | 0.65     |
# |    exploration_rate | 0.2      |
# | time/               |          |
# |    episodes         | 23360    |
# |    fps              | 1006     |
# |    time_elapsed     | 217      |
# |    total_timesteps  | 218981   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00536  |
# |    n_updates        | 29745    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.99     |
# |    ep_rew_mean      | 0.66     |
# |    exploration_rate | 0.2      |
# | time/               |          |
# |    episodes         | 23364    |
# |    fps              | 1005     |
# |    time_elapsed     | 217      |
# |    total_timesteps  | 219049   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0105   |
# |    n_updates        | 29762    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.2     |
# |    ep_rew_mean      | 0.66     |
# |    exploration_rate | 0.2      |
# | time/               |          |
# |    episodes         | 23368    |
# |    fps              | 1005     |
# |    time_elapsed     | 217      |
# |    total_timesteps  | 219108   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00497  |
# |    n_updates        | 29776    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.7     |
# |    ep_rew_mean      | 0.67     |
# |    exploration_rate | 0.2      |
# | time/               |          |
# |    episodes         | 23372    |
# |    fps              | 1005     |
# |    time_elapsed     | 217      |
# |    total_timesteps  | 219191   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00996  |
# |    n_updates        | 29797    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.9     |
# |    ep_rew_mean      | 0.68     |
# |    exploration_rate | 0.2      |
# | time/               |          |
# |    episodes         | 23376    |
# |    fps              | 1005     |
# |    time_elapsed     | 218      |
# |    total_timesteps  | 219236   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00778  |
# |    n_updates        | 29808    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.8     |
# |    ep_rew_mean      | 0.65     |
# |    exploration_rate | 0.2      |
# | time/               |          |
# |    episodes         | 23380    |
# |    fps              | 1005     |
# |    time_elapsed     | 218      |
# |    total_timesteps  | 219282   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0068   |
# |    n_updates        | 29820    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.7     |
# |    ep_rew_mean      | 0.63     |
# |    exploration_rate | 0.2      |
# | time/               |          |
# |    episodes         | 23384    |
# |    fps              | 1005     |
# |    time_elapsed     | 218      |
# |    total_timesteps  | 219300   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00601  |
# |    n_updates        | 29824    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.7     |
# |    ep_rew_mean      | 0.6      |
# |    exploration_rate | 0.2      |
# | time/               |          |
# |    episodes         | 23388    |
# |    fps              | 1005     |
# |    time_elapsed     | 218      |
# |    total_timesteps  | 219356   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0138   |
# |    n_updates        | 29838    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.1     |
# |    ep_rew_mean      | 0.62     |
# |    exploration_rate | 0.2      |
# | time/               |          |
# |    episodes         | 23392    |
# |    fps              | 1004     |
# |    time_elapsed     | 218      |
# |    total_timesteps  | 219419   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00977  |
# |    n_updates        | 29854    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.9     |
# |    ep_rew_mean      | 0.6      |
# |    exploration_rate | 0.2      |
# | time/               |          |
# |    episodes         | 23396    |
# |    fps              | 1004     |
# |    time_elapsed     | 218      |
# |    total_timesteps  | 219437   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0117   |
# |    n_updates        | 29859    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.9     |
# |    ep_rew_mean      | 0.58     |
# |    exploration_rate | 0.2      |
# | time/               |          |
# |    episodes         | 23400    |
# |    fps              | 1004     |
# |    time_elapsed     | 218      |
# |    total_timesteps  | 219481   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0109   |
# |    n_updates        | 29870    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.8     |
# |    ep_rew_mean      | 0.56     |
# |    exploration_rate | 0.2      |
# | time/               |          |
# |    episodes         | 23404    |
# |    fps              | 1004     |
# |    time_elapsed     | 218      |
# |    total_timesteps  | 219506   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0128   |
# |    n_updates        | 29876    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11       |
# |    ep_rew_mean      | 0.56     |
# |    exploration_rate | 0.2      |
# | time/               |          |
# |    episodes         | 23408    |
# |    fps              | 1004     |
# |    time_elapsed     | 218      |
# |    total_timesteps  | 219558   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00476  |
# |    n_updates        | 29889    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.7     |
# |    ep_rew_mean      | 0.54     |
# |    exploration_rate | 0.2      |
# | time/               |          |
# |    episodes         | 23412    |
# |    fps              | 1004     |
# |    time_elapsed     | 218      |
# |    total_timesteps  | 219663   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00443  |
# |    n_updates        | 29915    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.3     |
# |    ep_rew_mean      | 0.56     |
# |    exploration_rate | 0.2      |
# | time/               |          |
# |    episodes         | 23416    |
# |    fps              | 1004     |
# |    time_elapsed     | 218      |
# |    total_timesteps  | 219742   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0066   |
# |    n_updates        | 29935    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.7     |
# |    ep_rew_mean      | 0.57     |
# |    exploration_rate | 0.2      |
# | time/               |          |
# |    episodes         | 23420    |
# |    fps              | 1003     |
# |    time_elapsed     | 218      |
# |    total_timesteps  | 219795   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0058   |
# |    n_updates        | 29948    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.1     |
# |    ep_rew_mean      | 0.57     |
# |    exploration_rate | 0.2      |
# | time/               |          |
# |    episodes         | 23424    |
# |    fps              | 1003     |
# |    time_elapsed     | 219      |
# |    total_timesteps  | 219868   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0047   |
# |    n_updates        | 29966    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.1     |
# |    ep_rew_mean      | 0.58     |
# |    exploration_rate | 0.2      |
# | time/               |          |
# |    episodes         | 23428    |
# |    fps              | 1003     |
# |    time_elapsed     | 219      |
# |    total_timesteps  | 219902   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0092   |
# |    n_updates        | 29975    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.8     |
# |    ep_rew_mean      | 0.58     |
# |    exploration_rate | 0.2      |
# | time/               |          |
# |    episodes         | 23432    |
# |    fps              | 1003     |
# |    time_elapsed     | 219      |
# |    total_timesteps  | 219990   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0196   |
# |    n_updates        | 29997    |
# ----------------------------------

# %%
save_path = os.path.join('Training', 'Saved Models', 'Env4_Full_1M')
#load_path = os.path.join('Training', 'Saved Models', 'DQN_model_GridWorld')
model.save(save_path)

# %%
evaluate_policy(model, env, n_eval_episodes=30, render=True)

# %%
env.close()

# %%
del model
