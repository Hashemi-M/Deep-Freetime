# %%
# https://stable-baselines3.readthedocs.io/en/master/guide/rl.html
# https://spinningup.openai.com/en/latest/spinningup/rl_intro2.html#a-taxonomy-of-rl-algorithms

# %% [markdown]
# # 1. Import dependencies

# %%
import torch as torch
torch._C._cuda_getDeviceCount() > 0
# Out:
# True

# %%
import os
import gym 
from stable_baselines3 import DQN
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy

# %% [markdown]
# # 2. Load and Test Environment

# %%
#environment_name = "Pong-v0"
#rewards = [[1,0,5], [1,10,4], [1,4,6]]
#rewards = [[1,0,8], [1,10,3]]
#rewards = [[1,7,5],[1,0,4]]
rewards = [[1,1,6],[1,3,4]]

# %%
#env = gym.make(environment_name)
from GridEnv import WindyGridworld
env = WindyGridworld(
        height=20,
        width=11,
        rewards=rewards,
        wind=True,
        allowed_actions=['L', 'R', 'C'],
        reward_terminates_episode=False
    )

# %%
episodes = 5
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0 
    
    while not done:
        env.render()
        action = env.action_space.sample()
        n_state, reward, done, info = env.step(action)
        score+=reward
    print('Episode:{} Score:{}'.format(episode, score))
env.close()
# Out:
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# Qt: Session management error: None of the authentication protocols specified are supported
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QStandardPaths: XDG_RUNTIME_DIR points to non-existing path '/run/user/1001', please create it with 0700 permissions.
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
#
# QObject::moveToThread: Current thread (0x558a099cb000) is not the object's thread (0x558a09e08be0).
# Cannot move to target thread (0x558a099cb000)
# Episode:1 Score:0
# Episode:2 Score:0
# Episode:3 Score:0
# Episode:4 Score:0
# Episode:5 Score:2

# %% [markdown]
# # 3. Train an RL Model

# %%
from stable_baselines3.common.evaluation import evaluate_policy

# %%
log_path = os.path.join('Training','Logs')

# %%
from stable_baselines3.common.callbacks import EvalCallback, StopTrainingOnRewardThreshold

# %%
save_path = os.path.join('Training', 'Saved Models')
log_path = os.path.join('Training', 'Logs')

# %%
from GridEnv import WindyGridworld
env = env = WindyGridworld(
        height=20,
        width=11,
        rewards=rewards,
        wind=True,
        allowed_actions=['L', 'R', 'C'],
        reward_terminates_episode=False
    )

print(env.rewards)

from stable_baselines3.common.atari_wrappers import WarpFrame

#env = WarpFrame(env)
# Out:
# [[1, 1, 6], [1, 3, 4]]

# %%
stop_callback = StopTrainingOnRewardThreshold(reward_threshold=3, verbose=1)
eval_callback = EvalCallback(env, 
                             callback_on_new_best=stop_callback, 
                             eval_freq=10000, 
                             best_model_save_path=save_path, 
                             verbose=1)

# %%
# try 0.2 exploration period
model = DQN('CnnPolicy', env, exploration_fraction=0.1,
  exploration_final_eps=0.1,learning_starts=100000, verbose = 1, buffer_size = 50000,target_update_interval=1000, tensorboard_log=log_path)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.

# %%
model.learn(total_timesteps=2000000,callback=eval_callback, tb_log_name='Env2_Exp0.1_2M')
# Out:
# 2022-09-25 22:29:29.522769: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# Logging to Training/Logs/Env2_Exp0.1_2M_4
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.5     |
# |    ep_rew_mean      | 0.5      |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 30       |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 70       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.1     |
# |    ep_rew_mean      | 0.25     |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 52       |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 121      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.7     |
# |    ep_rew_mean      | 0.167    |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 80       |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 188      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.6     |
# |    ep_rew_mean      | 0.125    |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 105      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 250      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.8     |
# |    ep_rew_mean      | 0.15     |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 132      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 316      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.8     |
# |    ep_rew_mean      | 0.25     |
# |    exploration_rate | 0.998    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 158      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 379      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16       |
# |    ep_rew_mean      | 0.214    |
# |    exploration_rate | 0.998    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 185      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 448      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.5     |
# |    ep_rew_mean      | 0.188    |
# |    exploration_rate | 0.998    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 215      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 527      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.2     |
# |    ep_rew_mean      | 0.194    |
# |    exploration_rate | 0.997    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 237      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 584      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.6     |
# |    ep_rew_mean      | 0.175    |
# |    exploration_rate | 0.997    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 267      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 664      |
# ----------------------------------
# /usr/local/lib/python3.9/site-packages/stable_baselines3/common/callbacks.py:345: UserWarning: Training and eval env are not of the same type<stable_baselines3.common.vec_env.vec_transpose.VecTransposeImage object at 0x7fb46e15b2b0> != <stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7fb46e15b580>
#   warnings.warn("Training and eval env are not of the same type" f"{self.training_env} != {self.eval_env}")
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.6     |
# |    ep_rew_mean      | 0.159    |
# |    exploration_rate | 0.997    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 292      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 731      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.2     |
# |    ep_rew_mean      | 0.146    |
# |    exploration_rate | 0.996    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 310      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 780      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.2     |
# |    ep_rew_mean      | 0.135    |
# |    exploration_rate | 0.996    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 332      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 843      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.2     |
# |    ep_rew_mean      | 0.143    |
# |    exploration_rate | 0.996    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 354      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 905      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.8     |
# |    ep_rew_mean      | 0.133    |
# |    exploration_rate | 0.996    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 370      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 950      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.8     |
# |    ep_rew_mean      | 0.125    |
# |    exploration_rate | 0.995    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 258      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 1012     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.5     |
# |    ep_rew_mean      | 0.118    |
# |    exploration_rate | 0.995    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 267      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 1051     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.5     |
# |    ep_rew_mean      | 0.125    |
# |    exploration_rate | 0.995    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 282      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 1113     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.7     |
# |    ep_rew_mean      | 0.132    |
# |    exploration_rate | 0.995    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 300      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 1193     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.6     |
# |    ep_rew_mean      | 0.125    |
# |    exploration_rate | 0.994    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 313      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 1251     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.4     |
# |    ep_rew_mean      | 0.131    |
# |    exploration_rate | 0.994    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 323      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 1296     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.6     |
# |    ep_rew_mean      | 0.125    |
# |    exploration_rate | 0.994    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 341      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 1376     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.5     |
# |    ep_rew_mean      | 0.12     |
# |    exploration_rate | 0.994    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 353      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 1427     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.2     |
# |    ep_rew_mean      | 0.115    |
# |    exploration_rate | 0.993    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 361      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 1464     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.2     |
# |    ep_rew_mean      | 0.11     |
# |    exploration_rate | 0.993    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 372      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 1517     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.1     |
# |    ep_rew_mean      | 0.11     |
# |    exploration_rate | 0.993    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 385      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 1577     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.2     |
# |    ep_rew_mean      | 0.11     |
# |    exploration_rate | 0.993    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 399      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 1640     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.7     |
# |    ep_rew_mean      | 0.11     |
# |    exploration_rate | 0.993    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 402      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 1657     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.7     |
# |    ep_rew_mean      | 0.11     |
# |    exploration_rate | 0.992    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 416      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 1720     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.7     |
# |    ep_rew_mean      | 0.1      |
# |    exploration_rate | 0.992    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 429      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 1782     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.8     |
# |    ep_rew_mean      | 0.08     |
# |    exploration_rate | 0.992    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 446      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 1862     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.9     |
# |    ep_rew_mean      | 0.08     |
# |    exploration_rate | 0.991    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 461      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 1935     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.8     |
# |    ep_rew_mean      | 0.08     |
# |    exploration_rate | 0.991    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 475      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 2005     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.7     |
# |    ep_rew_mean      | 0.07     |
# |    exploration_rate | 0.991    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 485      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 2054     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.4     |
# |    ep_rew_mean      | 0.07     |
# |    exploration_rate | 0.991    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 494      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 2100     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.3     |
# |    ep_rew_mean      | 0.07     |
# |    exploration_rate | 0.99     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 506      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 2161     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.1     |
# |    ep_rew_mean      | 0.08     |
# |    exploration_rate | 0.99     |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 512      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 2188     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.1     |
# |    ep_rew_mean      | 0.08     |
# |    exploration_rate | 0.99     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 524      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 2248     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.2     |
# |    ep_rew_mean      | 0.07     |
# |    exploration_rate | 0.99     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 539      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 2328     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.2     |
# |    ep_rew_mean      | 0.07     |
# |    exploration_rate | 0.989    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 547      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 2369     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.4     |
# |    ep_rew_mean      | 0.08     |
# |    exploration_rate | 0.989    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 563      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 2449     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.6     |
# |    ep_rew_mean      | 0.09     |
# |    exploration_rate | 0.989    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 574      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 2509     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.8     |
# |    ep_rew_mean      | 0.09     |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 589      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 2589     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.4     |
# |    ep_rew_mean      | 0.09     |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 599      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 2638     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.5     |
# |    ep_rew_mean      | 0.1      |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 610      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 2700     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.4     |
# |    ep_rew_mean      | 0.1      |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 616      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 2734     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.4     |
# |    ep_rew_mean      | 0.1      |
# |    exploration_rate | 0.987    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 631      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 2814     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.4     |
# |    ep_rew_mean      | 0.1      |
# |    exploration_rate | 0.987    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 640      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 2866     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.7     |
# |    ep_rew_mean      | 0.1      |
# |    exploration_rate | 0.987    |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 653      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 2935     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.9     |
# |    ep_rew_mean      | 0.13     |
# |    exploration_rate | 0.986    |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 666      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 3011     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.9     |
# |    ep_rew_mean      | 0.12     |
# |    exploration_rate | 0.986    |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 677      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 3072     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15       |
# |    ep_rew_mean      | 0.12     |
# |    exploration_rate | 0.986    |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 688      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 3136     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.5     |
# |    ep_rew_mean      | 0.13     |
# |    exploration_rate | 0.986    |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 701      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 3207     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.6     |
# |    ep_rew_mean      | 0.13     |
# |    exploration_rate | 0.985    |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 713      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 3278     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.7     |
# |    ep_rew_mean      | 0.13     |
# |    exploration_rate | 0.985    |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 725      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 3348     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.5     |
# |    ep_rew_mean      | 0.13     |
# |    exploration_rate | 0.985    |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 736      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 3415     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.5     |
# |    ep_rew_mean      | 0.13     |
# |    exploration_rate | 0.984    |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 747      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 3483     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.3     |
# |    ep_rew_mean      | 0.13     |
# |    exploration_rate | 0.984    |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 755      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 3532     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.5     |
# |    ep_rew_mean      | 0.15     |
# |    exploration_rate | 0.984    |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 767      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 3603     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.6     |
# |    ep_rew_mean      | 0.16     |
# |    exploration_rate | 0.984    |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 776      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 3662     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.6     |
# |    ep_rew_mean      | 0.16     |
# |    exploration_rate | 0.983    |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 786      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 3724     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.2     |
# |    ep_rew_mean      | 0.16     |
# |    exploration_rate | 0.983    |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 799      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 3804     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16       |
# |    ep_rew_mean      | 0.16     |
# |    exploration_rate | 0.983    |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 807      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 3852     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.8     |
# |    ep_rew_mean      | 0.16     |
# |    exploration_rate | 0.982    |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 815      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 3907     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16       |
# |    ep_rew_mean      | 0.16     |
# |    exploration_rate | 0.982    |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 824      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 3969     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.7     |
# |    ep_rew_mean      | 0.17     |
# |    exploration_rate | 0.982    |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 831      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 4017     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.3     |
# |    ep_rew_mean      | 0.16     |
# |    exploration_rate | 0.982    |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 835      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 4041     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.8     |
# |    ep_rew_mean      | 0.15     |
# |    exploration_rate | 0.982    |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 838      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 4068     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.9     |
# |    ep_rew_mean      | 0.15     |
# |    exploration_rate | 0.981    |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 847      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 4127     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.9     |
# |    ep_rew_mean      | 0.14     |
# |    exploration_rate | 0.981    |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 856      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 4188     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.2     |
# |    ep_rew_mean      | 0.14     |
# |    exploration_rate | 0.981    |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 865      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 4251     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.1     |
# |    ep_rew_mean      | 0.14     |
# |    exploration_rate | 0.981    |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 875      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 4319     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.3     |
# |    ep_rew_mean      | 0.14     |
# |    exploration_rate | 0.98     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 887      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 4399     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.3     |
# |    ep_rew_mean      | 0.14     |
# |    exploration_rate | 0.98     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 896      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 4462     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.3     |
# |    ep_rew_mean      | 0.12     |
# |    exploration_rate | 0.98     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 908      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 4540     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.5     |
# |    ep_rew_mean      | 0.12     |
# |    exploration_rate | 0.979    |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 919      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 4620     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.3     |
# |    ep_rew_mean      | 0.12     |
# |    exploration_rate | 0.979    |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 925      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 4665     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.2     |
# |    ep_rew_mean      | 0.11     |
# |    exploration_rate | 0.979    |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 934      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 4728     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.2     |
# |    ep_rew_mean      | 0.11     |
# |    exploration_rate | 0.978    |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 944      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 4796     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.2     |
# |    ep_rew_mean      | 0.11     |
# |    exploration_rate | 0.978    |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 953      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 4863     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15       |
# |    ep_rew_mean      | 0.1      |
# |    exploration_rate | 0.978    |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 960      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 4911     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.6     |
# |    ep_rew_mean      | 0.1      |
# |    exploration_rate | 0.978    |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 964      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 4942     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.9     |
# |    ep_rew_mean      | 0.1      |
# |    exploration_rate | 0.977    |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 974      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 5019     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.8     |
# |    ep_rew_mean      | 0.08     |
# |    exploration_rate | 0.977    |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 983      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 5082     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.5     |
# |    ep_rew_mean      | 0.08     |
# |    exploration_rate | 0.977    |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 987      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 5113     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.3     |
# |    ep_rew_mean      | 0.09     |
# |    exploration_rate | 0.977    |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 992      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 5150     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.2     |
# |    ep_rew_mean      | 0.09     |
# |    exploration_rate | 0.977    |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 1001     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 5221     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.3     |
# |    ep_rew_mean      | 0.09     |
# |    exploration_rate | 0.976    |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 1010     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 5287     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.4     |
# |    ep_rew_mean      | 0.11     |
# |    exploration_rate | 0.976    |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 1018     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 5349     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.6     |
# |    ep_rew_mean      | 0.11     |
# |    exploration_rate | 0.976    |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 1028     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 5425     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.6     |
# |    ep_rew_mean      | 0.1      |
# |    exploration_rate | 0.975    |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 1034     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 5472     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15       |
# |    ep_rew_mean      | 0.11     |
# |    exploration_rate | 0.975    |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 1043     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 5541     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.2     |
# |    ep_rew_mean      | 0.11     |
# |    exploration_rate | 0.975    |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 1048     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 5583     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.1     |
# |    ep_rew_mean      | 0.11     |
# |    exploration_rate | 0.975    |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 1054     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 5634     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.1     |
# |    ep_rew_mean      | 0.11     |
# |    exploration_rate | 0.974    |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 1062     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 5696     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.1     |
# |    ep_rew_mean      | 0.12     |
# |    exploration_rate | 0.974    |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 1070     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 5757     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.2     |
# |    ep_rew_mean      | 0.13     |
# |    exploration_rate | 0.974    |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 1080     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 5835     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.7     |
# |    ep_rew_mean      | 0.13     |
# |    exploration_rate | 0.974    |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 1084     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 5871     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.8     |
# |    ep_rew_mean      | 0.13     |
# |    exploration_rate | 0.973    |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 1092     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 5939     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.6     |
# |    ep_rew_mean      | 0.12     |
# |    exploration_rate | 0.973    |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 1099     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 6003     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.4     |
# |    ep_rew_mean      | 0.12     |
# |    exploration_rate | 0.973    |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 1106     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 6057     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.4     |
# |    ep_rew_mean      | 0.12     |
# |    exploration_rate | 0.973    |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 1111     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 6103     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.4     |
# |    ep_rew_mean      | 0.13     |
# |    exploration_rate | 0.972    |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 1119     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 6164     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.1     |
# |    ep_rew_mean      | 0.14     |
# |    exploration_rate | 0.972    |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 1124     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 6208     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.9     |
# |    ep_rew_mean      | 0.15     |
# |    exploration_rate | 0.972    |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 1130     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 6258     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14       |
# |    ep_rew_mean      | 0.15     |
# |    exploration_rate | 0.972    |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 1136     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 6311     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.4     |
# |    ep_rew_mean      | 0.16     |
# |    exploration_rate | 0.971    |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 1144     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 6381     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.3     |
# |    ep_rew_mean      | 0.18     |
# |    exploration_rate | 0.971    |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 1152     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 6450     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.5     |
# |    ep_rew_mean      | 0.18     |
# |    exploration_rate | 0.971    |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 1161     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 6529     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.9     |
# |    ep_rew_mean      | 0.17     |
# |    exploration_rate | 0.97     |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 1170     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 6604     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15       |
# |    ep_rew_mean      | 0.16     |
# |    exploration_rate | 0.97     |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 1175     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 6646     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.9     |
# |    ep_rew_mean      | 0.16     |
# |    exploration_rate | 0.97     |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 1182     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 6708     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.8     |
# |    ep_rew_mean      | 0.17     |
# |    exploration_rate | 0.97     |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 1188     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 6766     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.5     |
# |    ep_rew_mean      | 0.15     |
# |    exploration_rate | 0.969    |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 1191     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 6796     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.2     |
# |    ep_rew_mean      | 0.15     |
# |    exploration_rate | 0.969    |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 1197     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 6846     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.4     |
# |    ep_rew_mean      | 0.14     |
# |    exploration_rate | 0.969    |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 1204     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 6909     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.4     |
# |    ep_rew_mean      | 0.13     |
# |    exploration_rate | 0.969    |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 1212     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 6983     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.7     |
# |    ep_rew_mean      | 0.14     |
# |    exploration_rate | 0.968    |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 1219     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 7051     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.5     |
# |    ep_rew_mean      | 0.13     |
# |    exploration_rate | 0.968    |
# | time/               |          |
# |    episodes         | 476      |
# |    fps              | 1222     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 7087     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.5     |
# |    ep_rew_mean      | 0.13     |
# |    exploration_rate | 0.968    |
# | time/               |          |
# |    episodes         | 480      |
# |    fps              | 1228     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 7144     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.3     |
# |    ep_rew_mean      | 0.12     |
# |    exploration_rate | 0.968    |
# | time/               |          |
# |    episodes         | 484      |
# |    fps              | 1233     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 7188     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.2     |
# |    ep_rew_mean      | 0.13     |
# |    exploration_rate | 0.967    |
# | time/               |          |
# |    episodes         | 488      |
# |    fps              | 1240     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 7258     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.3     |
# |    ep_rew_mean      | 0.13     |
# |    exploration_rate | 0.967    |
# | time/               |          |
# |    episodes         | 492      |
# ...
# |    episodes         | 6772     |
# |    fps              | 2823     |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 100211   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.65e-05 |
# |    n_updates        | 52       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.9     |
# |    ep_rew_mean      | 0.18     |
# |    exploration_rate | 0.549    |
# | time/               |          |
# |    episodes         | 6776     |
# |    fps              | 2819     |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 100263   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0158   |
# |    n_updates        | 65       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.7     |
# |    ep_rew_mean      | 0.18     |
# |    exploration_rate | 0.549    |
# | time/               |          |
# |    episodes         | 6780     |
# |    fps              | 2815     |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 100316   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.95e-05 |
# |    n_updates        | 78       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.7     |
# |    ep_rew_mean      | 0.17     |
# |    exploration_rate | 0.548    |
# | time/               |          |
# |    episodes         | 6784     |
# |    fps              | 2810     |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 100381   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.58e-05 |
# |    n_updates        | 95       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.7     |
# |    ep_rew_mean      | 0.17     |
# |    exploration_rate | 0.548    |
# | time/               |          |
# |    episodes         | 6788     |
# |    fps              | 2806     |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 100425   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0152   |
# |    n_updates        | 106      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.6     |
# |    ep_rew_mean      | 0.17     |
# |    exploration_rate | 0.548    |
# | time/               |          |
# |    episodes         | 6792     |
# |    fps              | 2802     |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 100473   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000156 |
# |    n_updates        | 118      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.8     |
# |    ep_rew_mean      | 0.17     |
# |    exploration_rate | 0.548    |
# | time/               |          |
# |    episodes         | 6796     |
# |    fps              | 2796     |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 100546   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00019  |
# |    n_updates        | 136      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.6     |
# |    ep_rew_mean      | 0.16     |
# |    exploration_rate | 0.547    |
# | time/               |          |
# |    episodes         | 6800     |
# |    fps              | 2793     |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 100582   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.08e-05 |
# |    n_updates        | 145      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13       |
# |    ep_rew_mean      | 0.14     |
# |    exploration_rate | 0.547    |
# | time/               |          |
# |    episodes         | 6804     |
# |    fps              | 2792     |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 100594   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0296   |
# |    n_updates        | 148      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13       |
# |    ep_rew_mean      | 0.14     |
# |    exploration_rate | 0.547    |
# | time/               |          |
# |    episodes         | 6808     |
# |    fps              | 2789     |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 100632   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0152   |
# |    n_updates        | 157      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.2     |
# |    ep_rew_mean      | 0.18     |
# |    exploration_rate | 0.547    |
# | time/               |          |
# |    episodes         | 6812     |
# |    fps              | 2784     |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 100697   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000567 |
# |    n_updates        | 174      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.3     |
# |    ep_rew_mean      | 0.18     |
# |    exploration_rate | 0.547    |
# | time/               |          |
# |    episodes         | 6816     |
# |    fps              | 2778     |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 100771   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0157   |
# |    n_updates        | 192      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13       |
# |    ep_rew_mean      | 0.17     |
# |    exploration_rate | 0.546    |
# | time/               |          |
# |    episodes         | 6820     |
# |    fps              | 2776     |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 100796   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000141 |
# |    n_updates        | 198      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.7     |
# |    ep_rew_mean      | 0.16     |
# |    exploration_rate | 0.546    |
# | time/               |          |
# |    episodes         | 6824     |
# |    fps              | 2773     |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 100831   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0155   |
# |    n_updates        | 207      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.8     |
# |    ep_rew_mean      | 0.16     |
# |    exploration_rate | 0.546    |
# | time/               |          |
# |    episodes         | 6828     |
# |    fps              | 2769     |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 100893   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.031    |
# |    n_updates        | 223      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.7     |
# |    ep_rew_mean      | 0.17     |
# |    exploration_rate | 0.546    |
# | time/               |          |
# |    episodes         | 6832     |
# |    fps              | 2765     |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 100947   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000101 |
# |    n_updates        | 236      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.8     |
# |    ep_rew_mean      | 0.17     |
# |    exploration_rate | 0.546    |
# | time/               |          |
# |    episodes         | 6836     |
# |    fps              | 2760     |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 100999   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000704 |
# |    n_updates        | 249      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.1     |
# |    ep_rew_mean      | 0.18     |
# |    exploration_rate | 0.545    |
# | time/               |          |
# |    episodes         | 6840     |
# |    fps              | 2755     |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 101066   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000297 |
# |    n_updates        | 266      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.3     |
# |    ep_rew_mean      | 0.17     |
# |    exploration_rate | 0.545    |
# | time/               |          |
# |    episodes         | 6844     |
# |    fps              | 2750     |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 101131   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000217 |
# |    n_updates        | 282      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.1     |
# |    ep_rew_mean      | 0.16     |
# |    exploration_rate | 0.545    |
# | time/               |          |
# |    episodes         | 6848     |
# |    fps              | 2747     |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 101174   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.95e-05 |
# |    n_updates        | 293      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.1     |
# |    ep_rew_mean      | 0.14     |
# |    exploration_rate | 0.544    |
# | time/               |          |
# |    episodes         | 6852     |
# |    fps              | 2741     |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 101245   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0155   |
# |    n_updates        | 311      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.3     |
# |    ep_rew_mean      | 0.14     |
# |    exploration_rate | 0.544    |
# | time/               |          |
# |    episodes         | 6856     |
# |    fps              | 2737     |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 101308   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00012  |
# |    n_updates        | 326      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.7     |
# |    ep_rew_mean      | 0.12     |
# |    exploration_rate | 0.544    |
# | time/               |          |
# |    episodes         | 6860     |
# |    fps              | 2732     |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 101372   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000261 |
# |    n_updates        | 342      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.5     |
# |    ep_rew_mean      | 0.11     |
# |    exploration_rate | 0.544    |
# | time/               |          |
# |    episodes         | 6864     |
# |    fps              | 2729     |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 101416   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.31e-06 |
# |    n_updates        | 353      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.6     |
# |    ep_rew_mean      | 0.13     |
# |    exploration_rate | 0.543    |
# | time/               |          |
# |    episodes         | 6868     |
# |    fps              | 2723     |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 101496   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000207 |
# |    n_updates        | 373      |
# ----------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [14], in <cell line: 1>()
# ----> 1 model.learn(total_timesteps=2000000,callback=eval_callback, tb_log_name='Env2_Exp0.1_2M')
#
# File /usr/local/lib/python3.9/site-packages/stable_baselines3/dqn/dqn.py:264, in DQN.learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     251 def learn(
#     252     self,
#     253     total_timesteps: int,
#    (...)
#     261     reset_num_timesteps: bool = True,
#     262 ) -> OffPolicyAlgorithm:
# --> 264     return super().learn(
#     265         total_timesteps=total_timesteps,
#     266         callback=callback,
#     267         log_interval=log_interval,
#     268         eval_env=eval_env,
#     269         eval_freq=eval_freq,
#     270         n_eval_episodes=n_eval_episodes,
#     271         tb_log_name=tb_log_name,
#     272         eval_log_path=eval_log_path,
#     273         reset_num_timesteps=reset_num_timesteps,
#     274     )
#
# File /usr/local/lib/python3.9/site-packages/stable_baselines3/common/off_policy_algorithm.py:365, in OffPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     363         # Special case when the user passes `gradient_steps=0`
#     364         if gradient_steps > 0:
# --> 365             self.train(batch_size=self.batch_size, gradient_steps=gradient_steps)
#     367 callback.on_training_end()
#     369 return self
#
# File /usr/local/lib/python3.9/site-packages/stable_baselines3/dqn/dqn.py:210, in DQN.train(self, gradient_steps, batch_size)
#     208 # Optimize the policy
#     209 self.policy.optimizer.zero_grad()
# --> 210 loss.backward()
#     211 # Clip gradient norm
#     212 th.nn.utils.clip_grad_norm_(self.policy.parameters(), self.max_grad_norm)
#
# File /usr/local/lib/python3.9/site-packages/torch/_tensor.py:396, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     387 if has_torch_function_unary(self):
#     388     return handle_torch_function(
#     389         Tensor.backward,
#     390         (self,),
#    (...)
#     394         create_graph=create_graph,
#     395         inputs=inputs)
# --> 396 torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#
# File /usr/local/lib/python3.9/site-packages/torch/autograd/__init__.py:173, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     168     retain_graph = create_graph
#     170 # The reason we repeat same the comment below is that
#     171 # some Python versions print out the first line of a multi-line function
#     172 # calls in the traceback and some print out the last line
# --> 173 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     174     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     175     allow_unreachable=True, accumulate_grad=True)
#
# KeyboardInterrupt:

# %%
save_path = os.path.join('Training', 'Saved Models', 'Env2_Exp0.1_2M')
#load_path = os.path.join('Training', 'Saved Models', 'DQN_model_GridWorld')
model.save(save_path)

# %%
evaluate_policy(model, env, n_eval_episodes=30, render=True)

# %%
env.close()
