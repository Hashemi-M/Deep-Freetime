# %%
# https://stable-baselines3.readthedocs.io/en/master/guide/rl.html
# https://spinningup.openai.com/en/latest/spinningup/rl_intro2.html#a-taxonomy-of-rl-algorithms

# %% [markdown]
# # 1. Import dependencies

# %%
import torch as torch
torch._C._cuda_getDeviceCount() > 0
# Out:
# True

# %%
import os
import gym 
from stable_baselines3 import DQN
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy

# %% [markdown]
# # 2. Load and Test Environment

# %%
#environment_name = "Pong-v0"
#rewards = [[1,0,5], [1,10,4], [1,4,6]]
#rewards = [[1,0,8], [1,10,3]]
rewards = [[1,0,5]]

# %%
#env = gym.make(environment_name)
from GridEnv import WindyGridworld
env = WindyGridworld(
        height=20,
        width=11,
        rewards=rewards,
        wind=True,
        allowed_actions=['L', 'R', 'C'],
        reward_terminates_episode=False
    )

# %%
episodes = 5
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0 
    
    while not done:
        env.render()
        action = env.action_space.sample()
        n_state, reward, done, info = env.step(action)
        score+=reward
    print('Episode:{} Score:{}'.format(episode, score))
env.close()
# Out:
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# Qt: Session management error: None of the authentication protocols specified are supported
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QStandardPaths: XDG_RUNTIME_DIR points to non-existing path '/run/user/1001', please create it with 0700 permissions.
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
#
# QObject::moveToThread: Current thread (0x562523802c70) is not the object's thread (0x562523c34250).
# Cannot move to target thread (0x562523802c70)
# Episode:1 Score:0
# Episode:2 Score:0
# Episode:3 Score:0
# Episode:4 Score:0
# Episode:5 Score:0

# %% [markdown]
# # 3. Train an RL Model

# %%
from stable_baselines3.common.evaluation import evaluate_policy

# %%
log_path = os.path.join('Training','Logs')

# %%
from stable_baselines3.common.callbacks import EvalCallback, StopTrainingOnRewardThreshold

# %%
save_path = os.path.join('Training', 'Saved Models')
log_path = os.path.join('Training', 'Logs')

# %%
from GridEnv import WindyGridworld
env = env = WindyGridworld(
        height=20,
        width=11,
        rewards=rewards,
        wind=True,
        allowed_actions=['L', 'R', 'C'],
        reward_terminates_episode=False
    )

print(env.rewards)
# Out:
# [[1, 0, 5]]

# %%
stop_callback = StopTrainingOnRewardThreshold(reward_threshold=3, verbose=1)
eval_callback = EvalCallback(env, 
                             callback_on_new_best=stop_callback, 
                             eval_freq=10000, 
                             best_model_save_path=save_path, 
                             verbose=1)

# %%
model = DQN('CnnPolicy', env, verbose = 1, buffer_size = 10000, tensorboard_log=log_path)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.

# %%
model.learn(total_timesteps=3000000, callback=eval_callback)
# Out:
# 2022-08-17 13:03:44.162340: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# Logging to Training/Logs/DQN_16
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.5     |
# |    ep_rew_mean      | 0.25     |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 29       |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 66       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16       |
# |    ep_rew_mean      | 0.25     |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 56       |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 128      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.8     |
# |    ep_rew_mean      | 0.167    |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 82       |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 190      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.9     |
# |    ep_rew_mean      | 0.25     |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 116      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 270      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.6     |
# |    ep_rew_mean      | 0.3      |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 141      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 331      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.9     |
# |    ep_rew_mean      | 0.25     |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 161      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 381      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16       |
# |    ep_rew_mean      | 0.25     |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 188      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 447      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.5     |
# |    ep_rew_mean      | 0.312    |
# |    exploration_rate | 0.998    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 219      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 527      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.1     |
# |    ep_rew_mean      | 0.278    |
# |    exploration_rate | 0.998    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 240      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 580      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.5     |
# |    ep_rew_mean      | 0.275    |
# |    exploration_rate | 0.998    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 270      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 660      |
# ----------------------------------
# /usr/local/lib/python3.9/site-packages/stable_baselines3/common/callbacks.py:345: UserWarning: Training and eval env are not of the same type<stable_baselines3.common.vec_env.vec_transpose.VecTransposeImage object at 0x7f0c41a95e80> != <stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f0c41a3b7c0>
#   warnings.warn("Training and eval env are not of the same type" f"{self.training_env} != {self.eval_env}")
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.5     |
# |    ep_rew_mean      | 0.273    |
# |    exploration_rate | 0.998    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 294      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 724      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.7     |
# |    ep_rew_mean      | 0.271    |
# |    exploration_rate | 0.997    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 323      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 802      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.7     |
# |    ep_rew_mean      | 0.269    |
# |    exploration_rate | 0.997    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 348      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 869      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.6     |
# |    ep_rew_mean      | 0.268    |
# |    exploration_rate | 0.997    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 370      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 931      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.3     |
# |    ep_rew_mean      | 0.267    |
# |    exploration_rate | 0.997    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 385      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 976      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.1     |
# |    ep_rew_mean      | 0.25     |
# |    exploration_rate | 0.997    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 404      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 1030     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.6     |
# |    ep_rew_mean      | 0.25     |
# |    exploration_rate | 0.997    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 414      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 1059     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.4     |
# |    ep_rew_mean      | 0.25     |
# |    exploration_rate | 0.996    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 431      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 1109     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.4     |
# |    ep_rew_mean      | 0.25     |
# |    exploration_rate | 0.996    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 451      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 1167     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.3     |
# |    ep_rew_mean      | 0.25     |
# |    exploration_rate | 0.996    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 471      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 1228     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.2     |
# |    ep_rew_mean      | 0.238    |
# |    exploration_rate | 0.996    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 488      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 1279     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.1     |
# |    ep_rew_mean      | 0.239    |
# |    exploration_rate | 0.996    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 503      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 1325     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.1     |
# |    ep_rew_mean      | 0.228    |
# |    exploration_rate | 0.996    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 525      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 1393     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15       |
# |    ep_rew_mean      | 0.219    |
# |    exploration_rate | 0.995    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 541      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 1444     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.9     |
# |    ep_rew_mean      | 0.22     |
# |    exploration_rate | 0.995    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 556      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 1492     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.9     |
# |    ep_rew_mean      | 0.22     |
# |    exploration_rate | 0.995    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 577      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 1560     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.8     |
# |    ep_rew_mean      | 0.22     |
# |    exploration_rate | 0.995    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 592      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 1609     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.7     |
# |    ep_rew_mean      | 0.22     |
# |    exploration_rate | 0.995    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 606      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 1655     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.7     |
# |    ep_rew_mean      | 0.21     |
# |    exploration_rate | 0.995    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 630      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 1735     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.5     |
# |    ep_rew_mean      | 0.2      |
# |    exploration_rate | 0.994    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 644      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 1783     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.6     |
# |    ep_rew_mean      | 0.23     |
# |    exploration_rate | 0.994    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 660      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 1838     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.4     |
# |    ep_rew_mean      | 0.22     |
# |    exploration_rate | 0.994    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 675      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 1889     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.1     |
# |    ep_rew_mean      | 0.21     |
# |    exploration_rate | 0.994    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 688      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 1935     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14       |
# |    ep_rew_mean      | 0.21     |
# |    exploration_rate | 0.994    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 702      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 1984     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.6     |
# |    ep_rew_mean      | 0.2      |
# |    exploration_rate | 0.994    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 713      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2023     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.7     |
# |    ep_rew_mean      | 0.2      |
# |    exploration_rate | 0.993    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 732      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2092     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.3     |
# |    ep_rew_mean      | 0.22     |
# |    exploration_rate | 0.993    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 743      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2135     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.4     |
# |    ep_rew_mean      | 0.21     |
# |    exploration_rate | 0.993    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 763      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2207     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.4     |
# |    ep_rew_mean      | 0.21     |
# |    exploration_rate | 0.993    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 779      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2268     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.3     |
# |    ep_rew_mean      | 0.21     |
# |    exploration_rate | 0.993    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 791      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2311     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.2     |
# |    ep_rew_mean      | 0.22     |
# |    exploration_rate | 0.993    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 802      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2353     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.7     |
# |    ep_rew_mean      | 0.23     |
# |    exploration_rate | 0.992    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 822      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2430     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.7     |
# |    ep_rew_mean      | 0.22     |
# |    exploration_rate | 0.992    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 834      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2479     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.6     |
# |    ep_rew_mean      | 0.23     |
# |    exploration_rate | 0.992    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 845      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2525     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.5     |
# |    ep_rew_mean      | 0.22     |
# |    exploration_rate | 0.992    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 857      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 2576     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.4     |
# |    ep_rew_mean      | 0.22     |
# |    exploration_rate | 0.992    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 868      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 2620     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.7     |
# |    ep_rew_mean      | 0.21     |
# |    exploration_rate | 0.991    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 885      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 2691     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.6     |
# |    ep_rew_mean      | 0.22     |
# |    exploration_rate | 0.991    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 899      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 2749     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.8     |
# |    ep_rew_mean      | 0.24     |
# |    exploration_rate | 0.991    |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 919      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 2829     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.8     |
# |    ep_rew_mean      | 0.23     |
# |    exploration_rate | 0.991    |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 928      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 2870     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.6     |
# |    ep_rew_mean      | 0.23     |
# |    exploration_rate | 0.991    |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 940      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 2920     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.7     |
# |    ep_rew_mean      | 0.22     |
# |    exploration_rate | 0.991    |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 954      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 2979     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.9     |
# |    ep_rew_mean      | 0.22     |
# |    exploration_rate | 0.99     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 969      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3044     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.6     |
# |    ep_rew_mean      | 0.22     |
# |    exploration_rate | 0.99     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 980      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3093     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.8     |
# |    ep_rew_mean      | 0.22     |
# |    exploration_rate | 0.99     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 995      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3161     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.9     |
# |    ep_rew_mean      | 0.2      |
# |    exploration_rate | 0.99     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 1009     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3226     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.9     |
# |    ep_rew_mean      | 0.21     |
# |    exploration_rate | 0.99     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 1022     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3284     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14       |
# |    ep_rew_mean      | 0.2      |
# |    exploration_rate | 0.989    |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 1032     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3331     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.9     |
# |    ep_rew_mean      | 0.2      |
# |    exploration_rate | 0.989    |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 1041     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3371     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.9     |
# |    ep_rew_mean      | 0.21     |
# |    exploration_rate | 0.989    |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 1049     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3413     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14       |
# |    ep_rew_mean      | 0.21     |
# |    exploration_rate | 0.989    |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 1067     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3493     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.2     |
# |    ep_rew_mean      | 0.18     |
# |    exploration_rate | 0.989    |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 1081     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3560     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.2     |
# |    ep_rew_mean      | 0.19     |
# |    exploration_rate | 0.989    |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 1094     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3623     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14       |
# |    ep_rew_mean      | 0.18     |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 1104     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3671     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.3     |
# |    ep_rew_mean      | 0.18     |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 1119     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3746     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.5     |
# |    ep_rew_mean      | 0.18     |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 1130     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3802     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.5     |
# |    ep_rew_mean      | 0.19     |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 1146     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3882     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.8     |
# |    ep_rew_mean      | 0.24     |
# |    exploration_rate | 0.987    |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 1162     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3962     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.1     |
# |    ep_rew_mean      | 0.23     |
# |    exploration_rate | 0.987    |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 1176     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 4032     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.9     |
# |    ep_rew_mean      | 0.23     |
# |    exploration_rate | 0.987    |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 1183     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 4069     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.2     |
# |    ep_rew_mean      | 0.28     |
# |    exploration_rate | 0.987    |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 1195     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 4137     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.1     |
# |    ep_rew_mean      | 0.29     |
# |    exploration_rate | 0.987    |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 1207     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 4199     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.3     |
# |    ep_rew_mean      | 0.28     |
# |    exploration_rate | 0.986    |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 1222     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 4279     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15       |
# |    ep_rew_mean      | 0.27     |
# |    exploration_rate | 0.986    |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 1232     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 4330     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.3     |
# |    ep_rew_mean      | 0.27     |
# |    exploration_rate | 0.986    |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 1245     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 4405     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.6     |
# |    ep_rew_mean      | 0.26     |
# |    exploration_rate | 0.986    |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 1258     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 4475     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.6     |
# |    ep_rew_mean      | 0.26     |
# |    exploration_rate | 0.986    |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 1270     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 4543     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.5     |
# |    ep_rew_mean      | 0.27     |
# |    exploration_rate | 0.985    |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 1279     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 4595     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.7     |
# |    ep_rew_mean      | 0.27     |
# |    exploration_rate | 0.985    |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 1291     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 4662     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.4     |
# |    ep_rew_mean      | 0.28     |
# |    exploration_rate | 0.985    |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 1298     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 4705     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.2     |
# |    ep_rew_mean      | 0.27     |
# |    exploration_rate | 0.985    |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 1305     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 4745     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.2     |
# |    ep_rew_mean      | 0.27     |
# |    exploration_rate | 0.985    |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 1314     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 4801     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.3     |
# |    ep_rew_mean      | 0.29     |
# |    exploration_rate | 0.985    |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 1325     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 4864     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.4     |
# |    ep_rew_mean      | 0.32     |
# |    exploration_rate | 0.984    |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 1332     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 4907     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.4     |
# |    ep_rew_mean      | 0.32     |
# |    exploration_rate | 0.984    |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 1340     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 4958     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.4     |
# |    ep_rew_mean      | 0.31     |
# |    exploration_rate | 0.984    |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 1353     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 5032     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.3     |
# |    ep_rew_mean      | 0.31     |
# |    exploration_rate | 0.984    |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 1361     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 5086     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.1     |
# |    ep_rew_mean      | 0.32     |
# |    exploration_rate | 0.984    |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 1368     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 5130     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.3     |
# |    ep_rew_mean      | 0.33     |
# |    exploration_rate | 0.984    |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 1379     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 5197     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.3     |
# |    ep_rew_mean      | 0.33     |
# |    exploration_rate | 0.983    |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 1391     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 5276     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.3     |
# |    ep_rew_mean      | 0.35     |
# |    exploration_rate | 0.983    |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 1400     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 5331     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15       |
# |    ep_rew_mean      | 0.32     |
# |    exploration_rate | 0.983    |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 1408     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 5385     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.8     |
# |    ep_rew_mean      | 0.29     |
# |    exploration_rate | 0.983    |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 1418     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 5447     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.8     |
# |    ep_rew_mean      | 0.3      |
# |    exploration_rate | 0.983    |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 1427     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 5508     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.9     |
# |    ep_rew_mean      | 0.31     |
# |    exploration_rate | 0.982    |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 1434     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 5557     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.5     |
# |    ep_rew_mean      | 0.26     |
# |    exploration_rate | 0.982    |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 1439     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 5591     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.7     |
# |    ep_rew_mean      | 0.27     |
# |    exploration_rate | 0.982    |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 1451     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 5671     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.6     |
# |    ep_rew_mean      | 0.28     |
# |    exploration_rate | 0.982    |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 1461     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 5738     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.9     |
# |    ep_rew_mean      | 0.31     |
# |    exploration_rate | 0.982    |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 1473     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 5818     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.5     |
# |    ep_rew_mean      | 0.31     |
# |    exploration_rate | 0.981    |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 1479     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 5857     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.4     |
# |    ep_rew_mean      | 0.32     |
# |    exploration_rate | 0.981    |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 1487     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 5919     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.2     |
# |    ep_rew_mean      | 0.32     |
# |    exploration_rate | 0.981    |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 1494     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 5965     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.2     |
# |    ep_rew_mean      | 0.31     |
# |    exploration_rate | 0.981    |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 1502     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 6020     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.3     |
# |    ep_rew_mean      | 0.3      |
# |    exploration_rate | 0.981    |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 1512     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 6096     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.4     |
# |    ep_rew_mean      | 0.3      |
# |    exploration_rate | 0.981    |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 1519     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 6144     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.8     |
# |    ep_rew_mean      | 0.31     |
# |    exploration_rate | 0.98     |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 1530     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 6222     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.6     |
# |    ep_rew_mean      | 0.3      |
# |    exploration_rate | 0.98     |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 1534     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 6257     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.6     |
# |    ep_rew_mean      | 0.27     |
# |    exploration_rate | 0.98     |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 1544     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 6328     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.9     |
# |    ep_rew_mean      | 0.24     |
# |    exploration_rate | 0.98     |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 1554     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 6398     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.2     |
# |    ep_rew_mean      | 0.24     |
# |    exploration_rate | 0.979    |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 1564     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 6478     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.9     |
# |    ep_rew_mean      | 0.24     |
# |    exploration_rate | 0.979    |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 1570     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 6524     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.1     |
# |    ep_rew_mean      | 0.24     |
# |    exploration_rate | 0.979    |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 1579     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 6593     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.1     |
# |    ep_rew_mean      | 0.22     |
# |    exploration_rate | 0.979    |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 1585     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 6637     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.9     |
# |    ep_rew_mean      | 0.22     |
# |    exploration_rate | 0.979    |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 1591     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 6683     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.6     |
# |    ep_rew_mean      | 0.21     |
# |    exploration_rate | 0.979    |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 1597     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 6736     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.4     |
# |    ep_rew_mean      | 0.18     |
# |    exploration_rate | 0.979    |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 1601     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 6767     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.2     |
# |    ep_rew_mean      | 0.18     |
# |    exploration_rate | 0.978    |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 1606     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 6810     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.3     |
# |    ep_rew_mean      | 0.16     |
# |    exploration_rate | 0.978    |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 1615     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 6877     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.3     |
# |    ep_rew_mean      | 0.14     |
# |    exploration_rate | 0.978    |
# | time/               |          |
# |    episodes         | 476      |
# |    fps              | 1622     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 6938     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.5     |
# |    ep_rew_mean      | 0.14     |
# |    exploration_rate | 0.978    |
# | time/               |          |
# |    episodes         | 480      |
# |    fps              | 1631     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 7007     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15       |
# |    ep_rew_mean      | 0.16     |
# |    exploration_rate | 0.978    |
# | time/               |          |
# |    episodes         | 484      |
# |    fps              | 1641     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 7087     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.8     |
# |    ep_rew_mean      | 0.17     |
# |    exploration_rate | 0.977    |
# | time/               |          |
# |    episodes         | 488      |
# |    fps              | 1648     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 7149     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.7     |
# |    ep_rew_mean      | 0.19     |
# |    exploration_rate | 0.977    |
# | time/               |          |
# |    episodes         | 492      |
# ...
# |    loss             | 0.00167  |
# |    n_updates        | 19490    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.4     |
# |    ep_rew_mean      | 0.93     |
# |    exploration_rate | 0.595    |
# | time/               |          |
# |    episodes         | 8456     |
# |    fps              | 1021     |
# |    time_elapsed     | 125      |
# |    total_timesteps  | 128033   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000458 |
# |    n_updates        | 19508    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.8     |
# |    ep_rew_mean      | 0.95     |
# |    exploration_rate | 0.594    |
# | time/               |          |
# |    episodes         | 8460     |
# |    fps              | 1021     |
# |    time_elapsed     | 125      |
# |    total_timesteps  | 128113   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000898 |
# |    n_updates        | 19528    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.9     |
# |    ep_rew_mean      | 0.97     |
# |    exploration_rate | 0.594    |
# | time/               |          |
# |    episodes         | 8464     |
# |    fps              | 1020     |
# |    time_elapsed     | 125      |
# |    total_timesteps  | 128193   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000326 |
# |    n_updates        | 19548    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.9     |
# |    ep_rew_mean      | 0.97     |
# |    exploration_rate | 0.594    |
# | time/               |          |
# |    episodes         | 8468     |
# |    fps              | 1020     |
# |    time_elapsed     | 125      |
# |    total_timesteps  | 128257   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000765 |
# |    n_updates        | 19564    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.9     |
# |    ep_rew_mean      | 0.99     |
# |    exploration_rate | 0.594    |
# | time/               |          |
# |    episodes         | 8472     |
# |    fps              | 1020     |
# |    time_elapsed     | 125      |
# |    total_timesteps  | 128337   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000938 |
# |    n_updates        | 19584    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18       |
# |    ep_rew_mean      | 0.98     |
# |    exploration_rate | 0.593    |
# | time/               |          |
# |    episodes         | 8476     |
# |    fps              | 1020     |
# |    time_elapsed     | 125      |
# |    total_timesteps  | 128417   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000921 |
# |    n_updates        | 19604    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.9     |
# |    ep_rew_mean      | 0.97     |
# |    exploration_rate | 0.593    |
# | time/               |          |
# |    episodes         | 8480     |
# |    fps              | 1020     |
# |    time_elapsed     | 125      |
# |    total_timesteps  | 128480   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000963 |
# |    n_updates        | 19619    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.1     |
# |    ep_rew_mean      | 0.98     |
# |    exploration_rate | 0.593    |
# | time/               |          |
# |    episodes         | 8484     |
# |    fps              | 1019     |
# |    time_elapsed     | 126      |
# |    total_timesteps  | 128560   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000411 |
# |    n_updates        | 19639    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.1     |
# |    ep_rew_mean      | 0.99     |
# |    exploration_rate | 0.593    |
# | time/               |          |
# |    episodes         | 8488     |
# |    fps              | 1019     |
# |    time_elapsed     | 126      |
# |    total_timesteps  | 128621   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00185  |
# |    n_updates        | 19655    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.9     |
# |    ep_rew_mean      | 0.99     |
# |    exploration_rate | 0.592    |
# | time/               |          |
# |    episodes         | 8492     |
# |    fps              | 1019     |
# |    time_elapsed     | 126      |
# |    total_timesteps  | 128689   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000608 |
# |    n_updates        | 19672    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.9     |
# |    ep_rew_mean      | 0.96     |
# |    exploration_rate | 0.592    |
# | time/               |          |
# |    episodes         | 8496     |
# |    fps              | 1019     |
# |    time_elapsed     | 126      |
# |    total_timesteps  | 128741   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000692 |
# |    n_updates        | 19685    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.7     |
# |    ep_rew_mean      | 0.93     |
# |    exploration_rate | 0.592    |
# | time/               |          |
# |    episodes         | 8500     |
# |    fps              | 1018     |
# |    time_elapsed     | 126      |
# |    total_timesteps  | 128785   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000517 |
# |    n_updates        | 19696    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.7     |
# |    ep_rew_mean      | 0.93     |
# |    exploration_rate | 0.592    |
# | time/               |          |
# |    episodes         | 8504     |
# |    fps              | 1018     |
# |    time_elapsed     | 126      |
# |    total_timesteps  | 128865   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000324 |
# |    n_updates        | 19716    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.4     |
# |    ep_rew_mean      | 0.89     |
# |    exploration_rate | 0.592    |
# | time/               |          |
# |    episodes         | 8508     |
# |    fps              | 1018     |
# |    time_elapsed     | 126      |
# |    total_timesteps  | 128921   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000132 |
# |    n_updates        | 19730    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.4     |
# |    ep_rew_mean      | 0.89     |
# |    exploration_rate | 0.591    |
# | time/               |          |
# |    episodes         | 8512     |
# |    fps              | 1018     |
# |    time_elapsed     | 126      |
# |    total_timesteps  | 129001   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000543 |
# |    n_updates        | 19750    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.4     |
# |    ep_rew_mean      | 0.9      |
# |    exploration_rate | 0.591    |
# | time/               |          |
# |    episodes         | 8516     |
# |    fps              | 1018     |
# |    time_elapsed     | 126      |
# |    total_timesteps  | 129080   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000542 |
# |    n_updates        | 19769    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.3     |
# |    ep_rew_mean      | 0.85     |
# |    exploration_rate | 0.591    |
# | time/               |          |
# |    episodes         | 8520     |
# |    fps              | 1018     |
# |    time_elapsed     | 126      |
# |    total_timesteps  | 129143   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000828 |
# |    n_updates        | 19785    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.4     |
# |    ep_rew_mean      | 0.87     |
# |    exploration_rate | 0.591    |
# | time/               |          |
# |    episodes         | 8524     |
# |    fps              | 1017     |
# |    time_elapsed     | 126      |
# |    total_timesteps  | 129223   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000306 |
# |    n_updates        | 19805    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.3     |
# |    ep_rew_mean      | 0.84     |
# |    exploration_rate | 0.591    |
# | time/               |          |
# |    episodes         | 8528     |
# |    fps              | 1017     |
# |    time_elapsed     | 127      |
# |    total_timesteps  | 129289   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000946 |
# |    n_updates        | 19822    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.3     |
# |    ep_rew_mean      | 0.86     |
# |    exploration_rate | 0.59     |
# | time/               |          |
# |    episodes         | 8532     |
# |    fps              | 1017     |
# |    time_elapsed     | 127      |
# |    total_timesteps  | 129368   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00112  |
# |    n_updates        | 19841    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.3     |
# |    ep_rew_mean      | 0.84     |
# |    exploration_rate | 0.59     |
# | time/               |          |
# |    episodes         | 8536     |
# |    fps              | 1017     |
# |    time_elapsed     | 127      |
# |    total_timesteps  | 129448   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000535 |
# |    n_updates        | 19861    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.4     |
# |    ep_rew_mean      | 0.86     |
# |    exploration_rate | 0.59     |
# | time/               |          |
# |    episodes         | 8540     |
# |    fps              | 1016     |
# |    time_elapsed     | 127      |
# |    total_timesteps  | 129528   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000358 |
# |    n_updates        | 19881    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.2     |
# |    ep_rew_mean      | 0.84     |
# |    exploration_rate | 0.59     |
# | time/               |          |
# |    episodes         | 8544     |
# |    fps              | 1016     |
# |    time_elapsed     | 127      |
# |    total_timesteps  | 129589   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00121  |
# |    n_updates        | 19897    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.3     |
# |    ep_rew_mean      | 0.86     |
# |    exploration_rate | 0.589    |
# | time/               |          |
# |    episodes         | 8548     |
# |    fps              | 1016     |
# |    time_elapsed     | 127      |
# |    total_timesteps  | 129649   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000862 |
# |    n_updates        | 19912    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.7     |
# |    ep_rew_mean      | 0.9      |
# |    exploration_rate | 0.589    |
# | time/               |          |
# |    episodes         | 8552     |
# |    fps              | 1016     |
# |    time_elapsed     | 127      |
# |    total_timesteps  | 129728   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000252 |
# |    n_updates        | 19931    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.8     |
# |    ep_rew_mean      | 0.93     |
# |    exploration_rate | 0.589    |
# | time/               |          |
# |    episodes         | 8556     |
# |    fps              | 1016     |
# |    time_elapsed     | 127      |
# |    total_timesteps  | 129808   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00047  |
# |    n_updates        | 19951    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.4     |
# |    ep_rew_mean      | 0.88     |
# |    exploration_rate | 0.589    |
# | time/               |          |
# |    episodes         | 8560     |
# |    fps              | 1016     |
# |    time_elapsed     | 127      |
# |    total_timesteps  | 129849   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000616 |
# |    n_updates        | 19962    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.2     |
# |    ep_rew_mean      | 0.89     |
# |    exploration_rate | 0.589    |
# | time/               |          |
# |    episodes         | 8564     |
# |    fps              | 1015     |
# |    time_elapsed     | 127      |
# |    total_timesteps  | 129916   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00028  |
# |    n_updates        | 19978    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.4     |
# |    ep_rew_mean      | 0.88     |
# |    exploration_rate | 0.588    |
# | time/               |          |
# |    episodes         | 8568     |
# |    fps              | 1015     |
# |    time_elapsed     | 127      |
# |    total_timesteps  | 129996   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000254 |
# |    n_updates        | 19998    |
# ----------------------------------
# Eval num_timesteps=130000, episode_reward=3.00 +/- 0.00
# Episode length: 19.00 +/- 0.00
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 19       |
# |    mean_reward      | 3        |
# | rollout/            |          |
# |    exploration_rate | 0.588    |
# | time/               |          |
# |    total_timesteps  | 130000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00107  |
# |    n_updates        | 19999    |
# ----------------------------------
# New best mean reward!
# Stopping training because the mean reward 3.00  is above the threshold 3

# %%
save_path = os.path.join('Training', 'Saved Models', 'DQN_model_GridWorld_Env1')
#load_path = os.path.join('Training', 'Saved Models', 'DQN_model_GridWorld')
model.save(save_path)

# %%
evaluate_policy(model, env, n_eval_episodes=30, render=True)
# Out:
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
#
# QObject::moveToThread: Current thread (0x561658ceb5b0) is not the object's thread (0x561658fb3e10).
# Cannot move to target thread (0x561658ceb5b0)
# (3.0, 0.0)

# %%
env.close()
