# %%
# https://stable-baselines3.readthedocs.io/en/master/guide/rl.html
# https://spinningup.openai.com/en/latest/spinningup/rl_intro2.html#a-taxonomy-of-rl-algorithms

# %% [markdown]
# # 1. Import dependencies

# %%
import torch as torch
torch._C._cuda_getDeviceCount() > 0
# Out:
# True

# %%
import os
import gym 
from stable_baselines3 import DQN
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy

# %% [markdown]
# # 2. Load and Test Environment

# %%
#environment_name = "Pong-v0"
#rewards = [[1,0,5], [1,10,4], [1,4,6]]
#rewards = [[1,0,8], [1,10,3]]
#rewards = [[1,7,5],[1,0,4]]
rewards = [[1,10,5]]

# %%
#env = gym.make(environment_name)
from GridEnv import WindyGridworld
env = WindyGridworld(
        height=20,
        width=11,
        rewards=rewards,
        wind=False,
        allowed_actions=['L', 'R', 'U', 'D', 'UL', 'UR', 'DL', 'DR'],
        reward_terminates_episode=True
    )

# %%
episodes = 5
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0 
    
    while not done:
        env.render()
        action = env.action_space.sample()
        n_state, reward, done, info = env.step(action)
        score+=reward
    print('Episode:{} Score:{}'.format(episode, score))
env.close()
# Out:
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
#
# QObject::moveToThread: Current thread (0x556bd1181980) is not the object's thread (0x556bd15cc5c0).
# Cannot move to target thread (0x556bd1181980)
# Episode:1 Score:0
# Episode:2 Score:0
# Episode:3 Score:0
# Episode:4 Score:0
# Episode:5 Score:0

# %% [markdown]
# # 3. Train an RL Model

# %%
from stable_baselines3.common.evaluation import evaluate_policy

# %%
log_path = os.path.join('Training','Logs')

# %%
from stable_baselines3.common.callbacks import EvalCallback, StopTrainingOnRewardThreshold

# %%
save_path = os.path.join('Training', 'Saved Models')
log_path = os.path.join('Training', 'Logs')

# %%
from GridEnv import WindyGridworld
env = WindyGridworld(
        height=20,
        width=11,
        rewards=rewards,
        wind=False,
        allowed_actions=['L', 'R', 'U', 'D', 'UL', 'UR', 'DL', 'DR'],
        reward_terminates_episode=True
    )

# %%
stop_callback = StopTrainingOnRewardThreshold(reward_threshold=2, verbose=1)
eval_callback = EvalCallback(env, 
                             callback_on_new_best=stop_callback, 
                             eval_freq=10000, 
                             best_model_save_path=save_path, 
                             verbose=1)

# %%
# try 0.2 exploration period
model = DQN('CnnPolicy', env, exploration_fraction=0.2,
  exploration_final_eps=0.1, verbose = 1, buffer_size = 40000,target_update_interval=1000, tensorboard_log=log_path)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.

# %%
model.learn(total_timesteps=1000000,callback=eval_callback, tb_log_name='Env4_Full_1M')
# Out:
# Logging to Training/Logs/Env4_Full_1M_9
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.5      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 1457     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 10       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.62     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 1957     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 29       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.75     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 1804     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 33       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.56     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 1830     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 41       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.5      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 2330     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 90       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.96     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 2261     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 95       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.89     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 2451     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 137      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.28     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 2513     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 169      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.83     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 2458     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 174      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.6      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 2442     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 184      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.48     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 2443     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 197      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.58     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 2475     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 220      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.94     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 2528     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 257      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.8      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 2509     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 269      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.58     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 2479     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 275      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.59     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 2493     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 294      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.38     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 2470     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 298      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.42     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 2494     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 318      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.29     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 2488     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 326      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.5      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.998    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 2546     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 360      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.44     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.998    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 2550     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 373      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.47     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.998    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 2563     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 393      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.5      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.998    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 2572     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 414      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.46     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.998    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 2569     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 428      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.88     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.998    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 2642     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 488      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.05     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.998    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 2660     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 515      |
# ----------------------------------
# /usr/local/lib/python3.9/site-packages/stable_baselines3/common/callbacks.py:345: UserWarning: Training and eval env are not of the same type<stable_baselines3.common.vec_env.vec_transpose.VecTransposeImage object at 0x7f4a4a3abd30> != <stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f4a4a3c7c40>
#   warnings.warn("Training and eval env are not of the same type" f"{self.training_env} != {self.eval_env}")
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.2      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.998    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 2678     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 549      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.37     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.997    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 2680     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 570      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.68     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.997    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 2700     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 609      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.27     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.997    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 2687     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 617      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.4      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.997    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 2689     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 635      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.64     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.997    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 2744     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 701      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.45     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.997    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 2737     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 714      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.65     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.997    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 2741     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 739      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.11     |
# |    ep_rew_mean      | 0.01     |
# |    exploration_rate | 0.996    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 2764     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 795      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.68     |
# |    ep_rew_mean      | 0.01     |
# |    exploration_rate | 0.996    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 2805     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 865      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.74     |
# |    ep_rew_mean      | 0.01     |
# |    exploration_rate | 0.996    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 2809     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 894      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.41     |
# |    ep_rew_mean      | 0.01     |
# |    exploration_rate | 0.996    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 2795     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 898      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.47     |
# |    ep_rew_mean      | 0.01     |
# |    exploration_rate | 0.996    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 2796     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 916      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.2      |
# |    ep_rew_mean      | 0.01     |
# |    exploration_rate | 0.996    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 2840     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 995      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.56     |
# |    ep_rew_mean      | 0.01     |
# |    exploration_rate | 0.995    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 2851     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1050     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.68     |
# |    ep_rew_mean      | 0.01     |
# |    exploration_rate | 0.995    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 2846     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1066     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.54     |
# |    ep_rew_mean      | 0.01     |
# |    exploration_rate | 0.995    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 2839     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1072     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.63     |
# |    ep_rew_mean      | 0.01     |
# |    exploration_rate | 0.995    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 2840     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1089     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.35     |
# |    ep_rew_mean      | 0.01     |
# |    exploration_rate | 0.995    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 2833     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1095     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.33     |
# |    ep_rew_mean      | 0.01     |
# |    exploration_rate | 0.995    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 2831     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1106     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.27     |
# |    ep_rew_mean      | 0.01     |
# |    exploration_rate | 0.995    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 2829     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1120     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.55     |
# |    ep_rew_mean      | 0.01     |
# |    exploration_rate | 0.995    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 2845     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1169     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.92     |
# |    ep_rew_mean      | 0.01     |
# |    exploration_rate | 0.995    |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 2858     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1220     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.5      |
# |    ep_rew_mean      | 0.01     |
# |    exploration_rate | 0.994    |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 2852     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1238     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.31     |
# |    ep_rew_mean      | 0.01     |
# |    exploration_rate | 0.994    |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 2843     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1246     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.04     |
# |    ep_rew_mean      | 0.01     |
# |    exploration_rate | 0.994    |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 2836     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1253     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.92     |
# |    ep_rew_mean      | 0.01     |
# |    exploration_rate | 0.994    |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 2829     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1262     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.63     |
# |    ep_rew_mean      | 0.01     |
# |    exploration_rate | 0.994    |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 2823     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1272     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.03     |
# |    ep_rew_mean      | 0.01     |
# |    exploration_rate | 0.994    |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 2835     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1320     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.27     |
# |    ep_rew_mean      | 0.01     |
# |    exploration_rate | 0.994    |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 2846     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1362     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.67     |
# |    ep_rew_mean      | 0.01     |
# |    exploration_rate | 0.994    |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 2841     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1368     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.75     |
# |    ep_rew_mean      | 0.01     |
# |    exploration_rate | 0.994    |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 2843     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1389     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.91     |
# |    ep_rew_mean      | 0.01     |
# |    exploration_rate | 0.994    |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 2853     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1430     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.7      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.993    |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 2859     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1465     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.13     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.993    |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 2857     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1478     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.91     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.993    |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 2886     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1585     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.07     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.993    |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 2885     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1605     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.96     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.993    |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 2879     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1612     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.57     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.993    |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 2879     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1652     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.84     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.992    |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 2902     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1734     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.9      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.992    |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 2902     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1756     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.06     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.992    |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 2899     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1778     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.21     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.992    |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 2899     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1810     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.25     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.992    |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 2896     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1820     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.34     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.992    |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 2896     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1840     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.38     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.992    |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 2892     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1858     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.02     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.992    |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 2889     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1871     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.01     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.991    |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 2890     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1921     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.99     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.991    |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 2880     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1937     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.86     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.991    |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 2880     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2032     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.86     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.991    |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 2872     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2039     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8        |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.991    |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 2867     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2062     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.61     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.99     |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 2868     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2133     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.26     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.99     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 2862     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2146     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.25     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.99     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 2863     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2187     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.4      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.99     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 2861     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2208     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.65     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.99     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 2865     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2254     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.26     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.989    |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 2883     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2356     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.17     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.989    |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 2881     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2382     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.22     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.989    |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 2878     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2400     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.12     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.989    |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 2892     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2497     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.76     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 2903     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2581     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 2911     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2654     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.1     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 2907     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2664     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.38     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 2902     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2672     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.23     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 2897     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2679     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.08     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 2893     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2686     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.96     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 2890     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2706     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9        |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 2887     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2720     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.16     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 2888     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2756     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.06     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 2883     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2764     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.07     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.987    |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 2880     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2778     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.97     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.987    |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 2880     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2818     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.05     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.987    |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 2877     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2842     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.25     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.987    |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 2874     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2857     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.28     |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.987    |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 2870     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2867     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.04     |
# |    ep_rew_mean      | 0.01     |
# |    exploration_rate | 0.987    |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 2881     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2966     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.49     |
# |    ep_rew_mean      | 0.01     |
# |    exploration_rate | 0.987    |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 2877     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2982     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.1      |
# |    ep_rew_mean      | 0.01     |
# |    exploration_rate | 0.986    |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 2879     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3056     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.15     |
# |    ep_rew_mean      | 0.01     |
# |    exploration_rate | 0.986    |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 2880     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3102     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.14     |
# |    ep_rew_mean      | 0.01     |
# |    exploration_rate | 0.986    |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 2878     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3122     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.74     |
# |    ep_rew_mean      | 0.01     |
# |    exploration_rate | 0.986    |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 2874     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3128     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.32     |
# |    ep_rew_mean      | 0.01     |
# |    exploration_rate | 0.986    |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 2879     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3188     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.33     |
# |    ep_rew_mean      | 0.01     |
# |    exploration_rate | 0.986    |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 2877     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3215     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.84     |
# |    ep_rew_mean      | 0.01     |
# |    exploration_rate | 0.985    |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 2882     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3284     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.29     |
# |    ep_rew_mean      | 0.01     |
# |    exploration_rate | 0.985    |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 2884     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3326     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.49     |
# |    ep_rew_mean      | 0.01     |
# |    exploration_rate | 0.985    |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 2880     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3330     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.98     |
# |    ep_rew_mean      | 0.01     |
# |    exploration_rate | 0.985    |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 2879     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3352     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.68     |
# |    ep_rew_mean      | 0.01     |
# |    exploration_rate | 0.985    |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 2886     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3432     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.67     |
# |    ep_rew_mean      | 0.01     |
# |    exploration_rate | 0.985    |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 2882     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3439     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.09     |
# |    ep_rew_mean      | 0.01     |
# |    exploration_rate | 0.984    |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 2885     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3488     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.19     |
# |    ep_rew_mean      | 0.02     |
# |    exploration_rate | 0.984    |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 2897     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3605     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.31     |
# |    ep_rew_mean      | 0.02     |
# |    exploration_rate | 0.984    |
# | time/               |          |
# |    episodes         | 476      |
# |    fps              | 2897     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3637     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.38     |
# |    ep_rew_mean      | 0.02     |
# |    exploration_rate | 0.984    |
# | time/               |          |
# |    episodes         | 480      |
# |    fps              | 2895     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3658     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.15     |
# |    ep_rew_mean      | 0.02     |
# |    exploration_rate | 0.983    |
# | time/               |          |
# |    episodes         | 484      |
# |    fps              | 2892     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3671     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.97     |
# |    ep_rew_mean      | 0.02     |
# |    exploration_rate | 0.983    |
# | time/               |          |
# |    episodes         | 488      |
# |    fps              | 2900     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3761     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10       |
# |    ep_rew_mean      | 0.02     |
# |    exploration_rate | 0.983    |
# | time/               |          |
# |    episodes         | 492      |
# |    fps              | 2897     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3782     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.7     |
# |    ep_rew_mean      | 0.03     |
# |    exploration_rate | 0.983    |
# ...
# |    ep_rew_mean      | 0.8      |
# |    exploration_rate | 0.339    |
# | time/               |          |
# |    episodes         | 13724    |
# |    fps              | 935      |
# |    time_elapsed     | 157      |
# |    total_timesteps  | 146845   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0108   |
# |    n_updates        | 24211    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 35.2     |
# |    ep_rew_mean      | 0.8      |
# |    exploration_rate | 0.339    |
# | time/               |          |
# |    episodes         | 13728    |
# |    fps              | 934      |
# |    time_elapsed     | 157      |
# |    total_timesteps  | 146968   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00388  |
# |    n_updates        | 24241    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 35.4     |
# |    ep_rew_mean      | 0.81     |
# |    exploration_rate | 0.339    |
# | time/               |          |
# |    episodes         | 13732    |
# |    fps              | 934      |
# |    time_elapsed     | 157      |
# |    total_timesteps  | 146998   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00499  |
# |    n_updates        | 24249    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 35.1     |
# |    ep_rew_mean      | 0.8      |
# |    exploration_rate | 0.338    |
# | time/               |          |
# |    episodes         | 13736    |
# |    fps              | 934      |
# |    time_elapsed     | 157      |
# |    total_timesteps  | 147056   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00553  |
# |    n_updates        | 24263    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 36.1     |
# |    ep_rew_mean      | 0.79     |
# |    exploration_rate | 0.338    |
# | time/               |          |
# |    episodes         | 13740    |
# |    fps              | 934      |
# |    time_elapsed     | 157      |
# |    total_timesteps  | 147205   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00872  |
# |    n_updates        | 24301    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 37.9     |
# |    ep_rew_mean      | 0.79     |
# |    exploration_rate | 0.337    |
# | time/               |          |
# |    episodes         | 13744    |
# |    fps              | 933      |
# |    time_elapsed     | 157      |
# |    total_timesteps  | 147421   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00708  |
# |    n_updates        | 24355    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 38.1     |
# |    ep_rew_mean      | 0.8      |
# |    exploration_rate | 0.336    |
# | time/               |          |
# |    episodes         | 13748    |
# |    fps              | 933      |
# |    time_elapsed     | 158      |
# |    total_timesteps  | 147550   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0103   |
# |    n_updates        | 24387    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 37.6     |
# |    ep_rew_mean      | 0.8      |
# |    exploration_rate | 0.335    |
# | time/               |          |
# |    episodes         | 13752    |
# |    fps              | 933      |
# |    time_elapsed     | 158      |
# |    total_timesteps  | 147741   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0105   |
# |    n_updates        | 24435    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 36.9     |
# |    ep_rew_mean      | 0.78     |
# |    exploration_rate | 0.335    |
# | time/               |          |
# |    episodes         | 13756    |
# |    fps              | 932      |
# |    time_elapsed     | 158      |
# |    total_timesteps  | 147855   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00558  |
# |    n_updates        | 24463    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 39.8     |
# |    ep_rew_mean      | 0.8      |
# |    exploration_rate | 0.333    |
# | time/               |          |
# |    episodes         | 13760    |
# |    fps              | 932      |
# |    time_elapsed     | 159      |
# |    total_timesteps  | 148218   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00289  |
# |    n_updates        | 24554    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 39.7     |
# |    ep_rew_mean      | 0.8      |
# |    exploration_rate | 0.333    |
# | time/               |          |
# |    episodes         | 13764    |
# |    fps              | 931      |
# |    time_elapsed     | 159      |
# |    total_timesteps  | 148320   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00452  |
# |    n_updates        | 24579    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 51.3     |
# |    ep_rew_mean      | 0.8      |
# |    exploration_rate | 0.327    |
# | time/               |          |
# |    episodes         | 13768    |
# |    fps              | 929      |
# |    time_elapsed     | 160      |
# |    total_timesteps  | 149530   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00647  |
# |    n_updates        | 24882    |
# ----------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [43], in <cell line: 1>()
# ----> 1 model.learn(total_timesteps=1000000,callback=eval_callback, tb_log_name='Env4_Full_1M')
#
# File /usr/local/lib/python3.9/site-packages/stable_baselines3/dqn/dqn.py:264, in DQN.learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     251 def learn(
#     252     self,
#     253     total_timesteps: int,
#    (...)
#     261     reset_num_timesteps: bool = True,
#     262 ) -> OffPolicyAlgorithm:
# --> 264     return super().learn(
#     265         total_timesteps=total_timesteps,
#     266         callback=callback,
#     267         log_interval=log_interval,
#     268         eval_env=eval_env,
#     269         eval_freq=eval_freq,
#     270         n_eval_episodes=n_eval_episodes,
#     271         tb_log_name=tb_log_name,
#     272         eval_log_path=eval_log_path,
#     273         reset_num_timesteps=reset_num_timesteps,
#     274     )
#
# File /usr/local/lib/python3.9/site-packages/stable_baselines3/common/off_policy_algorithm.py:346, in OffPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     343 callback.on_training_start(locals(), globals())
#     345 while self.num_timesteps < total_timesteps:
# --> 346     rollout = self.collect_rollouts(
#     347         self.env,
#     348         train_freq=self.train_freq,
#     349         action_noise=self.action_noise,
#     350         callback=callback,
#     351         learning_starts=self.learning_starts,
#     352         replay_buffer=self.replay_buffer,
#     353         log_interval=log_interval,
#     354     )
#     356     if rollout.continue_training is False:
#     357         break
#
# File /usr/local/lib/python3.9/site-packages/stable_baselines3/common/off_policy_algorithm.py:587, in OffPolicyAlgorithm.collect_rollouts(self, env, callback, train_freq, replay_buffer, action_noise, learning_starts, log_interval)
#     585 callback.update_locals(locals())
#     586 # Only stop training if return value is False, not when it is None.
# --> 587 if callback.on_step() is False:
#     588     return RolloutReturn(num_collected_steps * env.num_envs, num_collected_episodes, continue_training=False)
#     590 # Retrieve reward and episode length if using Monitor wrapper
#
# File /usr/local/lib/python3.9/site-packages/stable_baselines3/common/callbacks.py:88, in BaseCallback.on_step(self)
#      85 # timesteps start at zero
#      86 self.num_timesteps = self.model.num_timesteps
# ---> 88 return self._on_step()
#
# File /usr/local/lib/python3.9/site-packages/stable_baselines3/common/callbacks.py:393, in EvalCallback._on_step(self)
#     390 # Reset success rate buffer
#     391 self._is_success_buffer = []
# --> 393 episode_rewards, episode_lengths = evaluate_policy(
#     394     self.model,
#     395     self.eval_env,
#     396     n_eval_episodes=self.n_eval_episodes,
#     397     render=self.render,
#     398     deterministic=self.deterministic,
#     399     return_episode_rewards=True,
#     400     warn=self.warn,
#     401     callback=self._log_success_callback,
#     402 )
#     404 if self.log_path is not None:
#     405     self.evaluations_timesteps.append(self.num_timesteps)
#
# File /usr/local/lib/python3.9/site-packages/stable_baselines3/common/evaluation.py:86, in evaluate_policy(model, env, n_eval_episodes, deterministic, render, callback, reward_threshold, return_episode_rewards, warn)
#      84 episode_starts = np.ones((env.num_envs,), dtype=bool)
#      85 while (episode_counts < episode_count_targets).any():
# ---> 86     actions, states = model.predict(observations, state=states, episode_start=episode_starts, deterministic=deterministic)
#      87     observations, rewards, dones, infos = env.step(actions)
#      88     current_rewards += rewards
#
# File /usr/local/lib/python3.9/site-packages/stable_baselines3/dqn/dqn.py:248, in DQN.predict(self, observation, state, episode_start, deterministic)
#     246         action = np.array(self.action_space.sample())
#     247 else:
# --> 248     action, state = self.policy.predict(observation, state, episode_start, deterministic)
#     249 return action, state
#
# File /usr/local/lib/python3.9/site-packages/stable_baselines3/common/policies.py:338, in BasePolicy.predict(self, observation, state, episode_start, deterministic)
#     335 observation, vectorized_env = self.obs_to_tensor(observation)
#     337 with th.no_grad():
# --> 338     actions = self._predict(observation, deterministic=deterministic)
#     339 # Convert to numpy
#     340 actions = actions.cpu().numpy()
#
# File /usr/local/lib/python3.9/site-packages/stable_baselines3/dqn/policies.py:178, in DQNPolicy._predict(self, obs, deterministic)
#     177 def _predict(self, obs: th.Tensor, deterministic: bool = True) -> th.Tensor:
# --> 178     return self.q_net._predict(obs, deterministic=deterministic)
#
# File /usr/local/lib/python3.9/site-packages/stable_baselines3/dqn/policies.py:69, in QNetwork._predict(self, observation, deterministic)
#      68 def _predict(self, observation: th.Tensor, deterministic: bool = True) -> th.Tensor:
# ---> 69     q_values = self(observation)
#      70     # Greedy action
#      71     action = q_values.argmax(dim=1).reshape(-1)
#
# File /usr/local/lib/python3.9/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /usr/local/lib/python3.9/site-packages/stable_baselines3/dqn/policies.py:66, in QNetwork.forward(self, obs)
#      59 def forward(self, obs: th.Tensor) -> th.Tensor:
#      60     """
#      61     Predict the q-values.
#      62
#      63     :param obs: Observation
#      64     :return: The estimated Q-Value for each action.
#      65     """
# ---> 66     return self.q_net(self.extract_features(obs))
#
# File /usr/local/lib/python3.9/site-packages/stable_baselines3/common/policies.py:129, in BaseModel.extract_features(self, obs)
#     127 assert self.features_extractor is not None, "No features extractor was set"
#     128 preprocessed_obs = preprocess_obs(obs, self.observation_space, normalize_images=self.normalize_images)
# --> 129 return self.features_extractor(preprocessed_obs)
#
# File /usr/local/lib/python3.9/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /usr/local/lib/python3.9/site-packages/stable_baselines3/common/torch_layers.py:93, in NatureCNN.forward(self, observations)
#      92 def forward(self, observations: th.Tensor) -> th.Tensor:
# ---> 93     return self.linear(self.cnn(observations))
#
# File /usr/local/lib/python3.9/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /usr/local/lib/python3.9/site-packages/torch/nn/modules/container.py:139, in Sequential.forward(self, input)
#     137 def forward(self, input):
#     138     for module in self:
# --> 139         input = module(input)
#     140     return input
#
# File /usr/local/lib/python3.9/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /usr/local/lib/python3.9/site-packages/torch/nn/modules/conv.py:457, in Conv2d.forward(self, input)
#     456 def forward(self, input: Tensor) -> Tensor:
# --> 457     return self._conv_forward(input, self.weight, self.bias)
#
# File /usr/local/lib/python3.9/site-packages/torch/nn/modules/conv.py:453, in Conv2d._conv_forward(self, input, weight, bias)
#     449 if self.padding_mode != 'zeros':
#     450     return F.conv2d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     451                     weight, bias, self.stride,
#     452                     _pair(0), self.dilation, self.groups)
# --> 453 return F.conv2d(input, weight, bias, self.stride,
#     454                 self.padding, self.dilation, self.groups)
#
# KeyboardInterrupt:

# %%
save_path = os.path.join('Training', 'Saved Models', 'Env4_Full_1M')
#load_path = os.path.join('Training', 'Saved Models', 'DQN_model_GridWorld')
model.save(save_path)

# %%
evaluate_policy(model, env, n_eval_episodes=30, render=True)

# %%
env.close()

# %%
del model
